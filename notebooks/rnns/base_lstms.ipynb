# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --epochs=25 \
    --model LSTM \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 200 \
    --nhid 200 \
    --save ../../models/rnns/basemodels/lstm_200.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 66.67s | valid loss  7.36 | valid ppl  1567.95
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 84.25s | valid loss  7.08 | valid ppl  1190.43
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --save ../../models/rnns/basemodels/lstm_300.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 116.07s | valid loss  7.29 | valid ppl  1468.49
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 113.20s | valid loss  7.11 | valid ppl  1229.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/lstm_200.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/lstm_200.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/lstm_200.txt

# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/lstm_300.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/lstm_300.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/lstm_300.txt
# Out:
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 868.3462079588779
# Adjusted Perplexity: 868.3462079588779
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 827.6799327583085
# Adjusted Perplexity: 827.6799327583085
