# %% [markdown]
# GRU LR 5 nlayers 1

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 200 \
    --nhid 200 \
    --save ../../models/rnns/basemodels/gru_200.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 44.45s | valid loss  7.26 | valid ppl  1424.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 78.30s | valid loss  7.10 | valid ppl  1208.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --save ../../models/rnns/basemodels/gru_300.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 108.82s | valid loss  7.36 | valid ppl  1578.80
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 108.53s | valid loss  7.14 | valid ppl  1262.62
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 200 \
    --nhid 200 \
    --save ../../models/rnns/basemodels/gru_200_05.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 77.36s | valid loss  7.24 | valid ppl  1400.80
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 78.04s | valid loss  7.04 | valid ppl  1146.38
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 2 \
    --lr 5 \
    --emsize 200 \
    --nhid 200 \
    --save ../../models/rnns/basemodels/gru_200_05_l2.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 71.06s | valid loss  7.68 | valid ppl  2173.50
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 71.35s | valid loss  7.32 | valid ppl  1509.22
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 71.98s | valid loss  7.08 | valid ppl  1189.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 70.42s | valid loss  7.04 | valid ppl  1136.98
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 200 \
    --nhid 200 \
    --save ../../models/rnns/basemodels/gru_200_05_nt.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 62.55s | valid loss  7.45 | valid ppl  1715.04
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 61.72s | valid loss  7.14 | valid ppl  1258.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --save ../../models/rnns/basemodels/gru_300_05.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 79.85s | valid loss  7.19 | valid ppl  1330.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 80.32s | valid loss  7.08 | valid ppl  1192.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 2 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --save ../../models/rnns/basemodels/gru_300_05_2l.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 99.98s | valid loss  7.74 | valid ppl  2302.97
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 75.28s | valid loss  7.17 | valid ppl  1298.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 69.46s | valid loss  7.05 | valid ppl  1149.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 97.14s | valid loss  6.97 | valid ppl  1065.70
# ...

# %%
# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/gru_200.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/gru_200.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/gru_200.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/gru_200_05.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/gru_200_05.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/gru_200_05.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/gru_300.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/gru_300.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/gru_300.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/basemodels/gru_300_05.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/basemodels/gru_300_05.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/basemodels/gru_300_05.txt
# Out:
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 896.4375485809179
# Adjusted Perplexity: 896.4375485809179
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 805.1202834962088
# Adjusted Perplexity: 805.1202834962088
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 862.8096446281172
# Adjusted Perplexity: 862.8096446281172
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# ...
