# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --epochs=25 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 200 \
    --nhid 200 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --save ../../models/rnns/init_models/gru_200_normnorm.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 72.42s | valid loss  7.25 | valid ppl  1409.00
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 75.06s | valid loss  7.07 | valid ppl  1172.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --save ../../models/rnns/init_models/gru_300_normnorm.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 97.93s | valid loss  7.27 | valid ppl  1438.37
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 102.54s | valid loss  7.02 | valid ppl  1118.82
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --epochs=25 \
    --model LSTM \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --save ../../models/rnns/init_models/lstm_300_normnorm.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 112.20s | valid loss  7.24 | valid ppl  1390.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 106.37s | valid loss  7.07 | valid ppl  1177.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 200 \
    --nhid 200 \
    --use_fasttext \
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/mic_skip200 \
    --save ../../models/rnns/init_models/gru_200_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 59.07s | valid loss  7.19 | valid ppl  1326.50
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 59.21s | valid loss  6.77 | valid ppl   872.96
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --use_fasttext \
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/mic_skip300 \
    --save ../../models/rnns/init_models/gru_300_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 79.51s | valid loss  7.19 | valid ppl  1325.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 80.64s | valid loss  6.81 | valid ppl   911.17
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --use_fasttext \
    --embedding_model CBOW \
    --fasttext_save ../../models/embeddings/mic_cbow300 \
    --save ../../models/rnns/init_models/gru_cbow_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 81.72s | valid loss  7.44 | valid ppl  1699.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 80.05s | valid loss  7.10 | valid ppl  1214.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --dropout 0.5 \
    --emsize 300 \
    --nhid 300 \
    --use_fasttext \
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/mic_skip300 \
    --save ../../models/rnns/init_models/lstm_300_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 83.95s | valid loss  7.02 | valid ppl  1114.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 83.55s | valid loss  6.77 | valid ppl   870.81
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/gru_200_normnorm.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/gru_200_normnorm.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/gru_200_normnorm.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/gru_300_normnorm.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/gru_300_normnorm.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/gru_300_normnorm.txt



# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/lstm_300_normnorm.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/lstm_300_normnorm.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/lstm_300_normnorm.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/gru_200_skip.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/gru_200_skip.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/gru_200_skip.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/gru_300_skip.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/gru_300_skip.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/gru_300_skip.txt


# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/gru_cbow_skip.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/gru_300_cbow.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/gru_300_cbow.txt




# !command python ../../src/eval_model.py \
    --model ../../models/rnns/init_models/lstm_300_skip.pt \
    --data ../../data/transformed/micmac/ \
    > ../../data/eval_out/rnns/init_models/lstm_300_skip.txt

# !command python ../../src/eval/perplexity_adj.py \
        ../../data/eval_out/rnns/init_models/lstm_300_skip.txt
# Out:
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 700.3316880583061
# Adjusted Perplexity: 700.3316880583061
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 674.6691418457526
# Adjusted Perplexity: 674.6691418457526
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# Perplexity: 726.4927504345827
# Adjusted Perplexity: 726.4927504345827
# ../../src/eval_model.py:78: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   probs = nn.Softmax()(output_flat[i])
# ...
