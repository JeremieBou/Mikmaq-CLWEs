# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip300 \
    --save ../../models/rnns/basemodels/GRU_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 25.35s | valid loss  7.08 | valid ppl  1188.60
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 26.24s | valid loss  6.82 | valid ppl   912.28
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model CBOW \
    --fasttext_save ../../models/embeddings/micmac2/cbow300 \
    --save ../../models/rnns/basemodels/GRU_cbow.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 34.51s | valid loss  7.27 | valid ppl  1443.31
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 32.54s | valid loss  6.91 | valid ppl  1004.58
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip_wl300 \
    --save ../../models/rnns/basemodels/GRU_skipwl.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 30.88s | valid loss  6.90 | valid ppl   992.34
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 31.41s | valid loss  6.82 | valid ppl   917.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip300_more \
    --save ../../models/rnns/basemodels/GRU_skipmore.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 97.54s | valid loss  7.45 | valid ppl  1713.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 100.26s | valid loss  7.11 | valid ppl  1226.19
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip300 \
    --save ../../models/rnns/basemodels/LSTM_skip.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 57.28s | valid loss  6.97 | valid ppl  1059.72
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 56.79s | valid loss  6.70 | valid ppl   815.31
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model CBOW \
    --fasttext_save ../../models/embeddings/micmac2/cbow300 \
    --save ../../models/rnns/basemodels/LSTM_cbow.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 61.01s | valid loss  7.12 | valid ppl  1232.93
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 59.68s | valid loss  6.86 | valid ppl   955.20
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip_wl300 \
    --save ../../models/rnns/basemodels/LSTM_skipwl.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 30.61s | valid loss  6.95 | valid ppl  1040.86
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 33.70s | valid loss  6.79 | valid ppl   886.02
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model GRU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.75\
    --use_fasttext\
    --embedding_model SKIPGRAM \
    --fasttext_save ../../models/embeddings/micmac2/skip300 \
    --save ../../models/rnns/basemodels/GRU_skip_lotsofdo.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.75 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Starting initializing embeddings
# Finished initializing embeddings
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 26.08s | valid loss  6.97 | valid ppl  1064.98
# -----------------------------------------------------------------------------------------
# ^C
# -----------------------------------------------------------------------------------------
# Exiting from training early
