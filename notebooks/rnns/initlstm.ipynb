# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --save ../../models/rnns/basemodels/lstm_normnom.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 59.32s | valid loss  7.24 | valid ppl  1390.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 57.44s | valid loss  7.07 | valid ppl  1177.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --hin_weights xavier \
    --hr_weights xavier \
    --em_weights xavier \
    --out_weights xavier \
    --save ../../models/rnns/basemodels/lstm_xavier.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 28.70s | valid loss  7.35 | valid ppl  1554.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 28.39s | valid loss  7.16 | valid ppl  1283.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --hin_weights mikolov_uniform \
    --hr_weights mikolov_uniform \
    --em_weights mikolov_uniform \
    --out_weights mikolov_uniform \
    --save ../../models/rnns/basemodels/lstm_mikolovuni.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 33.86s | valid loss  7.70 | valid ppl  2212.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 38.00s | valid loss  7.29 | valid ppl  1464.36
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --hin_weights xavier_normal \
    --hr_weights xavier_normal \
    --em_weights xavier_normal \
    --out_weights xavier_normal \
    --save ../../models/rnns/basemodels/lstm_xaviernormal.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 60.19s | valid loss  7.27 | valid ppl  1439.24
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 57.97s | valid loss  7.11 | valid ppl  1223.98
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model LSTM \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --nlayers 1 \
    --tied \
    --emsize 300 \
    --nhid 300 \
    --dropout 0.5\
    --hin_weights zeroes \
    --hr_weights zeroes \
    --em_weights zeroes \
    --out_weights zeroes \
    --save ../../models/rnns/basemodels/lstm_zeroes.pt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 56.60s | valid loss  7.92 | valid ppl  2753.00
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 55.94s | valid loss  7.76 | valid ppl  2342.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# ...
