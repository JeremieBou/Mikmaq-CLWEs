# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model RNN_TANH \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --save ../../models/rnns/basemodels/rnn_200.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 58.61s | valid loss  7.35 | valid ppl  1549.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 65.08s | valid loss  7.20 | valid ppl  1335.98
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 59.77s | valid loss  7.10 | valid ppl  1209.95
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 57.71s | valid loss  7.06 | valid ppl  1165.08
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model RNN_TANH \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --tied \
    --save ../../models/rnns/basemodels/rnn_200_tied.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 56.23s | valid loss  8.18 | valid ppl  3564.42
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 56.85s | valid loss  7.46 | valid ppl  1728.54
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 55.77s | valid loss  7.13 | valid ppl  1253.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 55.78s | valid loss  7.16 | valid ppl  1285.55
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model RNN_RELU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --save ../../models/rnns/basemodels/rnnrelu_200.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 77.84s | valid loss  7.42 | valid ppl  1677.04
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 74.41s | valid loss  7.26 | valid ppl  1429.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 73.03s | valid loss  7.16 | valid ppl  1283.22
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 70.76s | valid loss  7.15 | valid ppl  1271.74
# ...

# %%
# !command python ../../src/main.py \
    --data ../../data/transformed/micmac \
    --model RNN_RELU \
    --epochs=25 \
    --log-interval 25 \
    --lr 5 \
    --tied \
    --save ../../models/rnns/basemodels/rnnrelu_200_tied.pt
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 55.19s | valid loss  7.69 | valid ppl  2184.47
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 56.58s | valid loss  7.26 | valid ppl  1417.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 55.40s | valid loss  7.18 | valid ppl  1318.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 56.76s | valid loss  7.10 | valid ppl  1216.67
# ...
