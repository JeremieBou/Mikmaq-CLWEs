# %% [markdown]
# # Base RNN Language Models for English and Mi'kmaq

# %%
import os
import time
import math

import torch
import torch.nn as nn

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# %%
bptt = 35

# %% [markdown]
# ## Corpus Processing

# %%
class Dictionary():
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []
        
    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]
    
    def __len__(self):
        return len(self.idx2word)

# %%
class Corpus():
    def __init__(self, path):
        self.dictionary = Dictionary()
        
        try:
            self.train = self.tokenize(os.path.join(path, 'train.txt'))
        except FileNotFoundError:
            print("train.txt not found")
            
        
        try:
            self.dev = self.tokenize(os.path.join(path, 'dev.txt'))
        except FileNotFoundError:
            print("dev.txt not found")
        
        try:
            self.test = self.tokenize(os.path.join(path, 'test.txt'))
        except FileNotFoundError:
            print("test.txt not found")
        
    def tokenize(self, path):        
        with open(path, 'r', encoding="utf8") as f:
            tokens = 0
            for line in f:
                words = line.split()
                
                for word in words:
                    tokens += 1
                    self.dictionary.add_word(word)
                        
        with open(path, 'r', encoding="utf8") as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for line in f:
                words = line.split()
                for word in words:
                    ids[token] = self.dictionary.word2idx[word]
                    token += 1            
                    
        return ids

# %% [markdown]
# ## Reuters Corpus

# %%
reuters_corpus = Corpus('data/reuters')
# Out:
# test.txt not found

# %% [markdown]
# Arrange the data into batches, we won't learn the relation between the start and end of a batch, but it'll be a lot easier to batch

# %%
def batchify(data, bsz):
    nbatch = data.size(0) // bsz
    
    data = data.narrow(0, 0, nbatch * bsz)
    
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

# %% [markdown]
# ## Mi'kmaq Corpus

# %%
mic_corpus = Corpus('data/micmac')

# %% [markdown]
# ## Model Definition

# %%
class RNNModel(nn.Module):
    def __init__(self, rnn_type, ntoken, ninput, nhidden, nlayers, 
                 dropout=0.5, tie_weights=False):
        super(RNNModel, self).__init__()
        
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninput)
        
        if rnn_type == 'LSTM':
            self.rnn = nn.LSTM(ninput, nhidden, nlayers, dropout=dropout)
        elif rnn_type == 'GRU':
            self.rnn = nn.GRU(ninput, nhidden, nlayers, dropout=dropout)
        elif rnn_type == "RNN_TANH":
            self.rnn = nn.RNN(ninput, nhidden, nlayers, nonlinearity='tanh', 
                              dropout=dropout)
        elif rnn_type == "RNN_RELU":
            self.rnn = nn.RNN(ninput, nhidden, nlayers, nonlinearity='relu', 
                              dropout=dropout)
        else:
            print("{} is an invalid rnn type".format(rnn_type))
            
        self.decoder = nn.Linear(nhidden, ntoken)
        
        if tie_weights:
            if nhidden != ninput:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight
            
        self.init_weights()
        
        self.rnn_type = rnn_type
        self.nhidden = nhidden
        self.nlayers = nlayers
    
    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)
    
    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0) * output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden
    
    def init_hidden(self, bsz):
        weight = next(self.parameters())
        if self.rnn_type == 'LSTM':
            return (weight.new_zeros(self.nlayers, bsz, self.nhidden),
                    weight.new_zeros(self.nlayers, bsz, self.nhidden))
        else:
            return weight.new_zeros(self.nlayers, bsz, self.nhidden)

# %% [markdown]
# ## Models and Loss

# %%
def make_model(corpus, rnn_type, emsize, nhidden, nlayers, dropout, tied):
    model = RNNModel(rnn_type, len(corpus.dictionary), emsize, nhidden, 
                     nlayers, dropout, tied)\
                .to(device)
    
    return model

# %%
criterion = nn.CrossEntropyLoss()

# %%
def repackage_hidden(h):
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

# %% [markdown]
# ## Define training

# %%
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

# %%
def evaluate(data_source, corpus, model):
    model.eval()
    total_loss = 0
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(10)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output, hidden = model(data, hidden)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
            hidden = repackage_hidden(hidden)
    return total_loss / len(data_source)

# %%
def train_iter(model, corpus, train_data, epoch, lr):
    model.train()
    total_loss = 0.
    start_time = time.time()    
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(20)
    
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        
        nn.utils.clip_grad_norm_(model.parameters(), lr)
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)
            
        total_loss += loss.item()
        
        if batch % 25 == 0 and batch > 0:
            cur_loss = total_loss / 25
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'\
                  .format(epoch, batch, len(train_data) // bptt, lr,
                elapsed * 1000 / 25, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# %%
def train(model, corpus, lr, epochs, path):
    train_data = batchify(corpus.train, 20)
    dev_data = batchify(corpus.dev, 10)
    #test_data = batchify(corpus.test, 10)
    best_val_loss = None
    
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train_iter(model, corpus, train_data, epoch, lr)
        val_loss = evaluate(dev_data, corpus, model)
        
        print('-' * 89)
        try:
            print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        except MathRangeError:
            print('| end of epoch {:3d} | time: {:5.2f}s'.format(epoch, (time.time() - epoch_start_time)))
            print("PPL is uuugggeeeee")
            
        print('-' * 89)
            
        if not best_val_loss or val_loss < best_val_loss:
            with open(os.path.join(path, 'model.txt'), 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            lr /= 4

# %% [markdown]
# ## Reuters Models

# %%
reuters_lstm = make_model(reuters_corpus, "LSTM", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

reuters_gru = make_model(reuters_corpus, "GRU", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

reuters_thanh = make_model(reuters_corpus, "TANH", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

reuters_relu = make_model(reuters_corpus, "RELU", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)
# Out:
# TANH is an invalid rnn type
# RELU is an invalid rnn type

# %%
train(reuters_lstm, reuters_corpus, 20, 20, 'data/reuters')
# Out:
# | epoch   1 |    25/  100 batches | lr 20.00 | ms/batch 1469.38 | loss 15.72 | ppl 6736333.43
# | epoch   1 |    50/  100 batches | lr 20.00 | ms/batch 1414.18 | loss 11.88 | ppl 144484.70
# | epoch   1 |    75/  100 batches | lr 20.00 | ms/batch 1403.50 | loss 11.42 | ppl 91004.84
# | epoch   1 |   100/  100 batches | lr 20.00 | ms/batch 1380.89 | loss 14.12 | ppl 1360690.08
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 145.35s | valid loss 12.46 | valid ppl 257077.08
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  100 batches | lr 20.00 | ms/batch 1467.18 | loss 12.35 | ppl 231996.35
# | epoch   2 |    50/  100 batches | lr 20.00 | ms/batch 1446.70 | loss 10.05 | ppl 23202.12
# | epoch   2 |    75/  100 batches | lr 20.00 | ms/batch 1442.50 | loss 11.30 | ppl 81179.96
# | epoch   2 |   100/  100 batches | lr 20.00 | ms/batch 1416.38 | loss 10.93 | ppl 56042.08
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 147.93s | valid loss 11.72 | valid ppl 122493.63
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  100 batches | lr 20.00 | ms/batch 1460.98 | loss 10.13 | ppl 25186.39
# | epoch   3 |    50/  100 batches | lr 20.00 | ms/batch 1419.47 | loss 11.16 | ppl 70345.09
# | epoch   3 |    75/  100 batches | lr 20.00 | ms/batch 1418.17 | loss 11.00 | ppl 59709.16
# | epoch   3 |   100/  100 batches | lr 20.00 | ms/batch 1432.34 | loss  9.94 | ppl 20682.31
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 146.89s | valid loss  9.58 | valid ppl 14435.02
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  100 batches | lr 20.00 | ms/batch 1475.66 | loss 10.61 | ppl 40337.80
# | epoch   4 |    50/  100 batches | lr 20.00 | ms/batch 1417.29 | loss 10.19 | ppl 26545.77
# | epoch   4 |    75/  100 batches | lr 20.00 | ms/batch 1421.50 | loss  9.74 | ppl 17012.75
# | epoch   4 |   100/  100 batches | lr 20.00 | ms/batch 1460.97 | loss  9.43 | ppl 12468.61
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 148.11s | valid loss  9.41 | valid ppl 12182.23
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  100 batches | lr 20.00 | ms/batch 1541.58 | loss  9.83 | ppl 18569.64
# | epoch   5 |    50/  100 batches | lr 20.00 | ms/batch 1485.77 | loss  9.23 | ppl 10172.41
# | epoch   5 |    75/  100 batches | lr 20.00 | ms/batch 1516.53 | loss 10.82 | ppl 49891.55
# | epoch   5 |   100/  100 batches | lr 20.00 | ms/batch 1606.83 | loss 10.10 | ppl 24275.68
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 157.60s | valid loss 10.08 | valid ppl 23763.76
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  100 batches | lr 5.00 | ms/batch 1579.09 | loss  8.18 | ppl  3573.05
# | epoch   6 |    50/  100 batches | lr 5.00 | ms/batch 1539.98 | loss  6.51 | ppl   670.17
# | epoch   6 |    75/  100 batches | lr 5.00 | ms/batch 1524.98 | loss  6.49 | ppl   656.58
# | epoch   6 |   100/  100 batches | lr 5.00 | ms/batch 1466.10 | loss  6.42 | ppl   616.13
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 156.46s | valid loss  6.48 | valid ppl   654.68
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  100 batches | lr 5.00 | ms/batch 1519.47 | loss  6.69 | ppl   805.76
# | epoch   7 |    50/  100 batches | lr 5.00 | ms/batch 1461.00 | loss  6.40 | ppl   602.24
# | epoch   7 |    75/  100 batches | lr 5.00 | ms/batch 1506.31 | loss  6.38 | ppl   587.41
# | epoch   7 |   100/  100 batches | lr 5.00 | ms/batch 1451.62 | loss  6.34 | ppl   568.81
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 152.17s | valid loss  6.37 | valid ppl   581.98
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  100 batches | lr 5.00 | ms/batch 1542.78 | loss  6.59 | ppl   725.10
# | epoch   8 |    50/  100 batches | lr 5.00 | ms/batch 1472.69 | loss  6.31 | ppl   551.22
# | epoch   8 |    75/  100 batches | lr 5.00 | ms/batch 1456.16 | loss  6.32 | ppl   554.06
# | epoch   8 |   100/  100 batches | lr 5.00 | ms/batch 1455.50 | loss  6.28 | ppl   531.89
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 151.88s | valid loss  6.31 | valid ppl   551.58
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  100 batches | lr 5.00 | ms/batch 1515.42 | loss  6.52 | ppl   678.54
# | epoch   9 |    50/  100 batches | lr 5.00 | ms/batch 1471.35 | loss  6.27 | ppl   526.88
# | epoch   9 |    75/  100 batches | lr 5.00 | ms/batch 1536.09 | loss  6.26 | ppl   525.41
# | epoch   9 |   100/  100 batches | lr 5.00 | ms/batch 1472.48 | loss  6.23 | ppl   509.29
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 153.80s | valid loss  6.26 | valid ppl   522.39
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  100 batches | lr 5.00 | ms/batch 1545.48 | loss  6.47 | ppl   647.39
# | epoch  10 |    50/  100 batches | lr 5.00 | ms/batch 1474.29 | loss  6.23 | ppl   506.73
# | epoch  10 |    75/  100 batches | lr 5.00 | ms/batch 1466.56 | loss  6.22 | ppl   504.91
# | epoch  10 |   100/  100 batches | lr 5.00 | ms/batch 1478.57 | loss  6.19 | ppl   486.76
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 153.03s | valid loss  6.21 | valid ppl   497.31
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  100 batches | lr 5.00 | ms/batch 1555.63 | loss  6.42 | ppl   614.28
# | epoch  11 |    50/  100 batches | lr 5.00 | ms/batch 1509.39 | loss  6.17 | ppl   478.84
# | epoch  11 |    75/  100 batches | lr 5.00 | ms/batch 1452.49 | loss  6.19 | ppl   486.46
# | epoch  11 |   100/  100 batches | lr 5.00 | ms/batch 1450.20 | loss  6.16 | ppl   471.55
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 152.92s | valid loss  6.17 | valid ppl   480.05
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  100 batches | lr 5.00 | ms/batch 1510.80 | loss  6.38 | ppl   587.65
# | epoch  12 |    50/  100 batches | lr 5.00 | ms/batch 1456.33 | loss  6.14 | ppl   465.52
# | epoch  12 |    75/  100 batches | lr 5.00 | ms/batch 1511.53 | loss  6.14 | ppl   464.51
# | epoch  12 |   100/  100 batches | lr 5.00 | ms/batch 1455.35 | loss  6.12 | ppl   455.85
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 152.04s | valid loss  6.14 | valid ppl   462.69
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  100 batches | lr 5.00 | ms/batch 1514.46 | loss  6.34 | ppl   568.02
# | epoch  13 |    50/  100 batches | lr 5.00 | ms/batch 1458.48 | loss  6.11 | ppl   452.22
# | epoch  13 |    75/  100 batches | lr 5.00 | ms/batch 1464.64 | loss  6.10 | ppl   446.20
# | epoch  13 |   100/  100 batches | lr 5.00 | ms/batch 1466.15 | loss  6.09 | ppl   442.47
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 151.34s | valid loss  6.11 | valid ppl   450.42
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  100 batches | lr 5.00 | ms/batch 1510.49 | loss  6.30 | ppl   543.80
# | epoch  14 |    50/  100 batches | lr 5.00 | ms/batch 1472.13 | loss  6.07 | ppl   432.10
# | epoch  14 |    75/  100 batches | lr 5.00 | ms/batch 1449.54 | loss  6.06 | ppl   430.43
# | epoch  14 |   100/  100 batches | lr 5.00 | ms/batch 1402.18 | loss  6.04 | ppl   420.01
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 149.44s | valid loss  6.11 | valid ppl   450.49
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  100 batches | lr 1.25 | ms/batch 1481.46 | loss  6.21 | ppl   497.68
# | epoch  15 |    50/  100 batches | lr 1.25 | ms/batch 1412.29 | loss  5.97 | ppl   390.96
# | epoch  15 |    75/  100 batches | lr 1.25 | ms/batch 1402.11 | loss  5.98 | ppl   394.74
# | epoch  15 |   100/  100 batches | lr 1.25 | ms/batch 1394.84 | loss  5.95 | ppl   383.51
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 145.85s | valid loss  6.03 | valid ppl   414.35
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  100 batches | lr 1.25 | ms/batch 1456.60 | loss  6.19 | ppl   487.79
# | epoch  16 |    50/  100 batches | lr 1.25 | ms/batch 1429.94 | loss  5.96 | ppl   386.12
# | epoch  16 |    75/  100 batches | lr 1.25 | ms/batch 1403.82 | loss  5.96 | ppl   385.81
# | epoch  16 |   100/  100 batches | lr 1.25 | ms/batch 1417.98 | loss  5.94 | ppl   381.72
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 146.58s | valid loss  6.02 | valid ppl   410.05
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  100 batches | lr 1.25 | ms/batch 1514.45 | loss  6.17 | ppl   476.92
# | epoch  17 |    50/  100 batches | lr 1.25 | ms/batch 1434.15 | loss  5.94 | ppl   379.58
# | epoch  17 |    75/  100 batches | lr 1.25 | ms/batch 1458.55 | loss  5.95 | ppl   383.73
# | epoch  17 |   100/  100 batches | lr 1.25 | ms/batch 1435.82 | loss  5.93 | ppl   377.77
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 149.80s | valid loss  6.00 | valid ppl   404.33
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  100 batches | lr 1.25 | ms/batch 1521.05 | loss  6.15 | ppl   468.75
# | epoch  18 |    50/  100 batches | lr 1.25 | ms/batch 1441.57 | loss  5.92 | ppl   374.06
# | epoch  18 |    75/  100 batches | lr 1.25 | ms/batch 1441.31 | loss  5.93 | ppl   375.54
# | epoch  18 |   100/  100 batches | lr 1.25 | ms/batch 1434.16 | loss  5.91 | ppl   370.40
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 149.62s | valid loss  5.99 | valid ppl   399.42
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  100 batches | lr 1.25 | ms/batch 1484.02 | loss  6.13 | ppl   461.65
# | epoch  19 |    50/  100 batches | lr 1.25 | ms/batch 1436.69 | loss  5.91 | ppl   369.24
# | epoch  19 |    75/  100 batches | lr 1.25 | ms/batch 1438.79 | loss  5.92 | ppl   372.57
# | epoch  19 |   100/  100 batches | lr 1.25 | ms/batch 1433.26 | loss  5.91 | ppl   369.53
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 148.48s | valid loss  5.98 | valid ppl   396.02
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  100 batches | lr 1.25 | ms/batch 1500.78 | loss  6.12 | ppl   455.97
# | epoch  20 |    50/  100 batches | lr 1.25 | ms/batch 1435.60 | loss  5.90 | ppl   366.47
# | epoch  20 |    75/  100 batches | lr 1.25 | ms/batch 1428.42 | loss  5.91 | ppl   369.03
# | epoch  20 |   100/  100 batches | lr 1.25 | ms/batch 1417.44 | loss  5.90 | ppl   364.84
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 148.20s | valid loss  5.97 | valid ppl   391.54
# -----------------------------------------------------------------------------------------

# %%
train(reuters_gru, reuters_corpus, 20, 40, 'data/reuters')
# Out:
# | epoch   1 |    25/  100 batches | lr 20.00 | ms/batch 290.66 | loss 99.19 | ppl 11958323269483587711212976867115459642654720.00
# | epoch   1 |    50/  100 batches | lr 20.00 | ms/batch 214.57 | loss 50.84 | ppl 12022794092571099398144.00
# | epoch   1 |    75/  100 batches | lr 20.00 | ms/batch 215.15 | loss 41.05 | ppl 675646400923478400.00
# | epoch   1 |   100/  100 batches | lr 20.00 | ms/batch 226.84 | loss 53.95 | ppl 270350617514995236208640.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 24.20s | valid loss 90.58 | valid ppl 2171007146916599533901433112177284218880.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  100 batches | lr 20.00 | ms/batch 242.55 | loss 70.02 | ppl 2560673317974902853734825459712.00
# | epoch   2 |    50/  100 batches | lr 20.00 | ms/batch 252.84 | loss 81.09 | ppl 164865578941804859627737401689899008.00
# | epoch   2 |    75/  100 batches | lr 20.00 | ms/batch 251.49 | loss 111.41 | ppl 2431496189800417072564232087686835095718953222144.00
# | epoch   2 |   100/  100 batches | lr 20.00 | ms/batch 240.42 | loss 59.93 | ppl 106585789893529783859412992.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 25.23s | valid loss 37.89 | valid ppl 28534908916207624.00
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  100 batches | lr 20.00 | ms/batch 263.83 | loss 61.75 | ppl 654236020937971089021075456.00
# | epoch   3 |    50/  100 batches | lr 20.00 | ms/batch 254.78 | loss 75.97 | ppl 984086872239938248185859809476608.00
# | epoch   3 |    75/  100 batches | lr 20.00 | ms/batch 251.66 | loss 89.12 | ppl 505553179883555966257523958839643209728.00
# | epoch   3 |   100/  100 batches | lr 20.00 | ms/batch 249.68 | loss 62.92 | ppl 2126884771885333338537328640.00
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 26.05s | valid loss 50.19 | valid ppl 6257314064334248214528.00
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  100 batches | lr 5.00 | ms/batch 236.22 | loss 53.56 | ppl 181734392276332763414528.00
# | epoch   4 |    50/  100 batches | lr 5.00 | ms/batch 224.83 | loss 52.04 | ppl 39831287194144785563648.00
# | epoch   4 |    75/  100 batches | lr 5.00 | ms/batch 233.20 | loss 49.23 | ppl 2402806122305408729088.00
# | epoch   4 |   100/  100 batches | lr 5.00 | ms/batch 226.65 | loss 48.20 | ppl 858651130275584671744.00
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 23.57s | valid loss 37.92 | valid ppl 29277013694118584.00
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  100 batches | lr 1.25 | ms/batch 254.12 | loss 47.33 | ppl 360595106651081408512.00
# | epoch   5 |    50/  100 batches | lr 1.25 | ms/batch 226.69 | loss 47.41 | ppl 388735681646957297664.00
# | epoch   5 |    75/  100 batches | lr 1.25 | ms/batch 223.94 | loss 46.53 | ppl 161395698401801601024.00
# | epoch   5 |   100/  100 batches | lr 1.25 | ms/batch 225.65 | loss 47.14 | ppl 298038659786920165376.00
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 23.82s | valid loss 37.31 | valid ppl 15996990951920604.00
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  100 batches | lr 1.25 | ms/batch 247.55 | loss 47.21 | ppl 317161373469264052224.00
# | epoch   6 |    50/  100 batches | lr 1.25 | ms/batch 224.58 | loss 47.29 | ppl 343587299537543561216.00
# | epoch   6 |    75/  100 batches | lr 1.25 | ms/batch 218.07 | loss 45.93 | ppl 88624574440475934720.00
# | epoch   6 |   100/  100 batches | lr 1.25 | ms/batch 216.79 | loss 46.58 | ppl 168931646494609899520.00
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 23.22s | valid loss 37.13 | valid ppl 13412252951241888.00
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  100 batches | lr 1.25 | ms/batch 245.38 | loss 46.70 | ppl 192064591483047149568.00
# | epoch   7 |    50/  100 batches | lr 1.25 | ms/batch 227.29 | loss 47.22 | ppl 321334539935580356608.00
# | epoch   7 |    75/  100 batches | lr 1.25 | ms/batch 228.25 | loss 45.98 | ppl 93353136491109269504.00
# | epoch   7 |   100/  100 batches | lr 1.25 | ms/batch 226.43 | loss 46.49 | ppl 155485943451400962048.00
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 23.77s | valid loss 36.26 | valid ppl 5609713387100537.00
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  100 batches | lr 1.25 | ms/batch 251.42 | loss 45.63 | ppl 65436627595867832320.00
# | epoch   8 |    50/  100 batches | lr 1.25 | ms/batch 226.04 | loss 46.65 | ppl 181562849323467440128.00
# | epoch   8 |    75/  100 batches | lr 1.25 | ms/batch 218.26 | loss 45.26 | ppl 45297995869481197568.00
# | epoch   8 |   100/  100 batches | lr 1.25 | ms/batch 216.03 | loss 46.06 | ppl 100883745010692341760.00
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 23.48s | valid loss 35.81 | valid ppl 3575899985949779.00
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  100 batches | lr 1.25 | ms/batch 254.83 | loss 45.70 | ppl 70358225853571809280.00
# | epoch   9 |    50/  100 batches | lr 1.25 | ms/batch 225.42 | loss 46.29 | ppl 126308261218023768064.00
# | epoch   9 |    75/  100 batches | lr 1.25 | ms/batch 224.03 | loss 45.26 | ppl 45180721236904509440.00
# | epoch   9 |   100/  100 batches | lr 1.25 | ms/batch 219.98 | loss 46.11 | ppl 106413111717187092480.00
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 23.70s | valid loss 35.42 | valid ppl 2409104262763653.50
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  100 batches | lr 1.25 | ms/batch 248.50 | loss 44.94 | ppl 32777044150630838272.00
# | epoch  10 |    50/  100 batches | lr 1.25 | ms/batch 225.65 | loss 45.29 | ppl 46867338132511956992.00
# | epoch  10 |    75/  100 batches | lr 1.25 | ms/batch 221.85 | loss 44.64 | ppl 24274118705867010048.00
# | epoch  10 |   100/  100 batches | lr 1.25 | ms/batch 213.21 | loss 44.79 | ppl 28388441106237407232.00
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 23.36s | valid loss 35.52 | valid ppl 2663175821812580.50
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  100 batches | lr 0.31 | ms/batch 246.68 | loss 44.72 | ppl 26277432292803428352.00
# | epoch  11 |    50/  100 batches | lr 0.31 | ms/batch 232.75 | loss 45.89 | ppl 85362148312530534400.00
# | epoch  11 |    75/  100 batches | lr 0.31 | ms/batch 223.77 | loss 44.85 | ppl 30009247617251725312.00
# | epoch  11 |   100/  100 batches | lr 0.31 | ms/batch 221.89 | loss 45.78 | ppl 76305372642360049664.00
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 23.66s | valid loss 35.46 | valid ppl 2517338303906315.00
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  100 batches | lr 0.08 | ms/batch 242.45 | loss 44.69 | ppl 25645046567814234112.00
# | epoch  12 |    50/  100 batches | lr 0.08 | ms/batch 220.29 | loss 45.57 | ppl 61928001614946672640.00
# | epoch  12 |    75/  100 batches | lr 0.08 | ms/batch 222.61 | loss 44.66 | ppl 24829788231196532736.00
# | epoch  12 |   100/  100 batches | lr 0.08 | ms/batch 220.89 | loss 45.46 | ppl 55376624573707272192.00
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 23.34s | valid loss 35.46 | valid ppl 2512271846441097.50
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  100 batches | lr 0.02 | ms/batch 262.71 | loss 46.13 | ppl 107753054314295132160.00
# | epoch  13 |    50/  100 batches | lr 0.02 | ms/batch 234.71 | loss 46.02 | ppl 96862686830681210880.00
# | epoch  13 |    75/  100 batches | lr 0.02 | ms/batch 227.43 | loss 44.66 | ppl 24879967487980834816.00
# | epoch  13 |   100/  100 batches | lr 0.02 | ms/batch 212.66 | loss 45.40 | ppl 52300044726078709760.00
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 23.97s | valid loss 35.46 | valid ppl 2514654078119299.50
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  100 batches | lr 0.00 | ms/batch 254.12 | loss 45.22 | ppl 43473483931235713024.00
# | epoch  14 |    50/  100 batches | lr 0.00 | ms/batch 227.63 | loss 45.39 | ppl 51789733176861859840.00
# | epoch  14 |    75/  100 batches | lr 0.00 | ms/batch 227.71 | loss 44.91 | ppl 32071956804162093056.00
# | epoch  14 |   100/  100 batches | lr 0.00 | ms/batch 223.59 | loss 45.83 | ppl 80001700078821408768.00
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 23.93s | valid loss 35.46 | valid ppl 2514504625465238.00
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  100 batches | lr 0.00 | ms/batch 250.42 | loss 44.79 | ppl 28216280745625427968.00
# | epoch  15 |    50/  100 batches | lr 0.00 | ms/batch 231.32 | loss 45.57 | ppl 61542759620787699712.00
# | epoch  15 |    75/  100 batches | lr 0.00 | ms/batch 229.70 | loss 44.93 | ppl 32692405234479091712.00
# | epoch  15 |   100/  100 batches | lr 0.00 | ms/batch 227.95 | loss 45.37 | ppl 50324619902277410816.00
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 24.03s | valid loss 35.46 | valid ppl 2514502672096177.00
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  100 batches | lr 0.00 | ms/batch 245.41 | loss 44.48 | ppl 20727883041693347840.00
# | epoch  16 |    50/  100 batches | lr 0.00 | ms/batch 224.99 | loss 45.34 | ppl 49124748417788207104.00
# | epoch  16 |    75/  100 batches | lr 0.00 | ms/batch 224.19 | loss 44.92 | ppl 32314766577660829696.00
# | epoch  16 |   100/  100 batches | lr 0.00 | ms/batch 221.54 | loss 45.21 | ppl 43092402848582696960.00
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 23.59s | valid loss 35.46 | valid ppl 2514503031927206.00
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  100 batches | lr 0.00 | ms/batch 249.98 | loss 45.13 | ppl 39821533542076776448.00
# | epoch  17 |    50/  100 batches | lr 0.00 | ms/batch 223.27 | loss 45.61 | ppl 64250046244820598784.00
# | epoch  17 |    75/  100 batches | lr 0.00 | ms/batch 217.18 | loss 44.76 | ppl 27573377996286726144.00
# | epoch  17 |   100/  100 batches | lr 0.00 | ms/batch 215.77 | loss 45.30 | ppl 47253788955887525888.00
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 23.34s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  100 batches | lr 0.00 | ms/batch 245.86 | loss 44.77 | ppl 27797556564500770816.00
# | epoch  18 |    50/  100 batches | lr 0.00 | ms/batch 227.95 | loss 45.35 | ppl 49534461188316790784.00
# | epoch  18 |    75/  100 batches | lr 0.00 | ms/batch 221.79 | loss 44.23 | ppl 16140507333310885888.00
# | epoch  18 |   100/  100 batches | lr 0.00 | ms/batch 210.35 | loss 45.02 | ppl 35523492839613607936.00
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 23.22s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  100 batches | lr 0.00 | ms/batch 248.08 | loss 44.73 | ppl 26600987445063139328.00
# | epoch  19 |    50/  100 batches | lr 0.00 | ms/batch 224.26 | loss 45.64 | ppl 66360070212272406528.00
# | epoch  19 |    75/  100 batches | lr 0.00 | ms/batch 224.43 | loss 44.96 | ppl 33713527734798503936.00
# | epoch  19 |   100/  100 batches | lr 0.00 | ms/batch 214.71 | loss 45.43 | ppl 53525241917896138752.00
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 23.46s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  100 batches | lr 0.00 | ms/batch 246.92 | loss 45.38 | ppl 51321420502750076928.00
# | epoch  20 |    50/  100 batches | lr 0.00 | ms/batch 217.13 | loss 46.01 | ppl 95566038223754149888.00
# | epoch  20 |    75/  100 batches | lr 0.00 | ms/batch 215.79 | loss 44.67 | ppl 24989833672105857024.00
# | epoch  20 |   100/  100 batches | lr 0.00 | ms/batch 218.22 | loss 45.22 | ppl 43713341552139534336.00
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 23.00s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  100 batches | lr 0.00 | ms/batch 247.76 | loss 44.80 | ppl 28744624576208961536.00
# | epoch  21 |    50/  100 batches | lr 0.00 | ms/batch 229.06 | loss 45.18 | ppl 41638819837344571392.00
# | epoch  21 |    75/  100 batches | lr 0.00 | ms/batch 224.67 | loss 44.31 | ppl 17527478330415751168.00
# | epoch  21 |   100/  100 batches | lr 0.00 | ms/batch 216.88 | loss 45.27 | ppl 45768400424836579328.00
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 23.64s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  100 batches | lr 0.00 | ms/batch 247.66 | loss 45.25 | ppl 44785050655202410496.00
# | epoch  22 |    50/  100 batches | lr 0.00 | ms/batch 226.54 | loss 45.15 | ppl 40581008013796286464.00
# | epoch  22 |    75/  100 batches | lr 0.00 | ms/batch 220.50 | loss 44.66 | ppl 24950779474382200832.00
# | epoch  22 |   100/  100 batches | lr 0.00 | ms/batch 212.29 | loss 45.38 | ppl 51295083686915186688.00
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 23.36s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  100 batches | lr 0.00 | ms/batch 246.83 | loss 44.68 | ppl 25388154010046922752.00
# | epoch  23 |    50/  100 batches | lr 0.00 | ms/batch 222.16 | loss 45.74 | ppl 73506520630391603200.00
# | epoch  23 |    75/  100 batches | lr 0.00 | ms/batch 224.60 | loss 44.74 | ppl 27032255350279159808.00
# | epoch  23 |   100/  100 batches | lr 0.00 | ms/batch 219.42 | loss 45.50 | ppl 57716013845320384512.00
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 23.39s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  100 batches | lr 0.00 | ms/batch 243.67 | loss 44.64 | ppl 24327610547228909568.00
# | epoch  24 |    50/  100 batches | lr 0.00 | ms/batch 235.14 | loss 46.33 | ppl 132387979522599829504.00
# | epoch  24 |    75/  100 batches | lr 0.00 | ms/batch 223.94 | loss 44.56 | ppl 22474653349886189568.00
# | epoch  24 |   100/  100 batches | lr 0.00 | ms/batch 216.70 | loss 45.45 | ppl 54801463060451934208.00
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 23.57s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  100 batches | lr 0.00 | ms/batch 250.37 | loss 45.58 | ppl 62637494190803132416.00
# | epoch  25 |    50/  100 batches | lr 0.00 | ms/batch 230.20 | loss 46.40 | ppl 141357323924542799872.00
# | epoch  25 |    75/  100 batches | lr 0.00 | ms/batch 221.87 | loss 44.81 | ppl 28811194539947634688.00
# | epoch  25 |   100/  100 batches | lr 0.00 | ms/batch 225.51 | loss 45.39 | ppl 51805026745205506048.00
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 23.76s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  100 batches | lr 0.00 | ms/batch 239.91 | loss 44.82 | ppl 29115577764126003200.00
# | epoch  26 |    50/  100 batches | lr 0.00 | ms/batch 229.28 | loss 45.38 | ppl 51294684511028609024.00
# | epoch  26 |    75/  100 batches | lr 0.00 | ms/batch 219.04 | loss 44.51 | ppl 21352943062788415488.00
# | epoch  26 |   100/  100 batches | lr 0.00 | ms/batch 213.86 | loss 45.41 | ppl 52477893338087702528.00
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 23.12s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  100 batches | lr 0.00 | ms/batch 252.79 | loss 45.05 | ppl 36871463319541415936.00
# | epoch  27 |    50/  100 batches | lr 0.00 | ms/batch 226.84 | loss 45.66 | ppl 67481253025724620800.00
# | epoch  27 |    75/  100 batches | lr 0.00 | ms/batch 225.99 | loss 44.39 | ppl 19038376539495194624.00
# | epoch  27 |   100/  100 batches | lr 0.00 | ms/batch 224.53 | loss 44.86 | ppl 30378442199648075776.00
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 23.87s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  100 batches | lr 0.00 | ms/batch 252.55 | loss 45.13 | ppl 39799585979092836352.00
# | epoch  28 |    50/  100 batches | lr 0.00 | ms/batch 233.28 | loss 46.14 | ppl 109456030651602845696.00
# | epoch  28 |    75/  100 batches | lr 0.00 | ms/batch 232.44 | loss 45.20 | ppl 42540940677277343744.00
# | epoch  28 |   100/  100 batches | lr 0.00 | ms/batch 230.49 | loss 46.06 | ppl 101179396573491560448.00
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 24.25s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/  100 batches | lr 0.00 | ms/batch 241.09 | loss 45.29 | ppl 46840042083962380288.00
# | epoch  29 |    50/  100 batches | lr 0.00 | ms/batch 223.31 | loss 45.44 | ppl 54512657680232947712.00
# | epoch  29 |    75/  100 batches | lr 0.00 | ms/batch 220.81 | loss 44.40 | ppl 19182629007287074816.00
# | epoch  29 |   100/  100 batches | lr 0.00 | ms/batch 221.15 | loss 45.29 | ppl 46891523214236737536.00
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 23.31s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/  100 batches | lr 0.00 | ms/batch 246.66 | loss 45.11 | ppl 38997592435480068096.00
# | epoch  30 |    50/  100 batches | lr 0.00 | ms/batch 231.96 | loss 45.44 | ppl 54011249862215081984.00
# | epoch  30 |    75/  100 batches | lr 0.00 | ms/batch 229.55 | loss 44.58 | ppl 22906172275886735360.00
# | epoch  30 |   100/  100 batches | lr 0.00 | ms/batch 223.75 | loss 45.22 | ppl 43644113822416101376.00
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 23.87s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/  100 batches | lr 0.00 | ms/batch 245.99 | loss 45.27 | ppl 45566522088422760448.00
# | epoch  31 |    50/  100 batches | lr 0.00 | ms/batch 227.02 | loss 46.10 | ppl 104861014990103707648.00
# | epoch  31 |    75/  100 batches | lr 0.00 | ms/batch 215.51 | loss 44.68 | ppl 25345615253215494144.00
# | epoch  31 |   100/  100 batches | lr 0.00 | ms/batch 215.81 | loss 45.56 | ppl 61420576853517090816.00
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 23.24s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/  100 batches | lr 0.00 | ms/batch 246.44 | loss 44.96 | ppl 33508403831136980992.00
# | epoch  32 |    50/  100 batches | lr 0.00 | ms/batch 227.91 | loss 45.20 | ppl 42756957246079901696.00
# | epoch  32 |    75/  100 batches | lr 0.00 | ms/batch 224.61 | loss 44.95 | ppl 33378041970411167744.00
# | epoch  32 |   100/  100 batches | lr 0.00 | ms/batch 222.42 | loss 45.63 | ppl 65563357888971087872.00
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 23.61s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/  100 batches | lr 0.00 | ms/batch 240.90 | loss 45.72 | ppl 71605455700756971520.00
# | epoch  33 |    50/  100 batches | lr 0.00 | ms/batch 217.14 | loss 45.69 | ppl 69820164303332220928.00
# | epoch  33 |    75/  100 batches | lr 0.00 | ms/batch 228.00 | loss 44.97 | ppl 33865930828460130304.00
# | epoch  33 |   100/  100 batches | lr 0.00 | ms/batch 218.17 | loss 46.03 | ppl 98002335090766905344.00
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 23.15s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/  100 batches | lr 0.00 | ms/batch 239.41 | loss 44.49 | ppl 20966022277014204416.00
# | epoch  34 |    50/  100 batches | lr 0.00 | ms/batch 224.89 | loss 45.25 | ppl 44771624533267431424.00
# | epoch  34 |    75/  100 batches | lr 0.00 | ms/batch 223.53 | loss 45.14 | ppl 40340402855493615616.00
# | epoch  34 |   100/  100 batches | lr 0.00 | ms/batch 220.53 | loss 45.97 | ppl 92349274782898257920.00
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 23.35s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/  100 batches | lr 0.00 | ms/batch 250.99 | loss 45.19 | ppl 42134035945689702400.00
# | epoch  35 |    50/  100 batches | lr 0.00 | ms/batch 230.31 | loss 45.73 | ppl 72209428139932385280.00
# | epoch  35 |    75/  100 batches | lr 0.00 | ms/batch 221.61 | loss 44.61 | ppl 23595483136791150592.00
# | epoch  35 |   100/  100 batches | lr 0.00 | ms/batch 210.24 | loss 45.60 | ppl 63641630614471909376.00
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 23.36s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/  100 batches | lr 0.00 | ms/batch 247.96 | loss 44.91 | ppl 31786313386005643264.00
# | epoch  36 |    50/  100 batches | lr 0.00 | ms/batch 219.70 | loss 45.59 | ppl 62910156070801711104.00
# | epoch  36 |    75/  100 batches | lr 0.00 | ms/batch 222.90 | loss 44.90 | ppl 31714998466153189376.00
# | epoch  36 |   100/  100 batches | lr 0.00 | ms/batch 217.39 | loss 45.13 | ppl 39740340056678187008.00
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 23.26s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/  100 batches | lr 0.00 | ms/batch 246.11 | loss 45.62 | ppl 64621453366076882944.00
# | epoch  37 |    50/  100 batches | lr 0.00 | ms/batch 235.59 | loss 45.58 | ppl 62385944380558958592.00
# | epoch  37 |    75/  100 batches | lr 0.00 | ms/batch 230.62 | loss 44.76 | ppl 27525968154937229312.00
# | epoch  37 |   100/  100 batches | lr 0.00 | ms/batch 219.77 | loss 45.23 | ppl 44183615829664456704.00
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 23.92s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/  100 batches | lr 0.00 | ms/batch 242.25 | loss 45.16 | ppl 40893341815184203776.00
# | epoch  38 |    50/  100 batches | lr 0.00 | ms/batch 225.19 | loss 45.41 | ppl 52761256000047144960.00
# | epoch  38 |    75/  100 batches | lr 0.00 | ms/batch 233.39 | loss 45.36 | ppl 50195955292821921792.00
# | epoch  38 |   100/  100 batches | lr 0.00 | ms/batch 219.33 | loss 45.18 | ppl 41939874511882682368.00
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 23.51s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/  100 batches | lr 0.00 | ms/batch 245.38 | loss 44.96 | ppl 33593894299750977536.00
# | epoch  39 |    50/  100 batches | lr 0.00 | ms/batch 227.32 | loss 45.27 | ppl 45547850426957791232.00
# | epoch  39 |    75/  100 batches | lr 0.00 | ms/batch 225.80 | loss 44.95 | ppl 33096190519896694784.00
# | epoch  39 |   100/  100 batches | lr 0.00 | ms/batch 221.93 | loss 45.57 | ppl 62024641003852898304.00
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 23.69s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/  100 batches | lr 0.00 | ms/batch 242.34 | loss 44.89 | ppl 31273544775985868800.00
# | epoch  40 |    50/  100 batches | lr 0.00 | ms/batch 225.82 | loss 45.20 | ppl 42475688973911957504.00
# | epoch  40 |    75/  100 batches | lr 0.00 | ms/batch 228.88 | loss 44.04 | ppl 13339204430482583552.00
# | epoch  40 |   100/  100 batches | lr 0.00 | ms/batch 221.07 | loss 44.47 | ppl 20466861607260966912.00
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 23.52s | valid loss 35.46 | valid ppl 2514503391758287.00
# -----------------------------------------------------------------------------------------

# %%
train(reuters_thanh, reuters_corpus, 20, 40, 'data/reuters')

# %%
train(reuters_relu, reuters_corpus, 20, 40, 'data/reuters')

# %% [markdown]
# ## Mi'kmaq Models

# %%
micmac_lstm = make_model(mic_corpus, "LSTM", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

micmac_gru = make_model(mic_corpus, "GRU", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

# %%
train(micmac_lstm, mic_corpus, 20, 40, 'data/micmac')
# Out:
# | epoch   1 |    25/  201 batches | lr 20.00 | ms/batch 1609.65 | loss 70.19 | ppl 3043738862814376850439020740608.00
# | epoch   1 |    50/  201 batches | lr 20.00 | ms/batch 2049.27 | loss 57.42 | ppl 8633555709618255153856512.00
# | epoch   1 |    75/  201 batches | lr 20.00 | ms/batch 2196.81 | loss 58.45 | ppl 24133229564286347568480256.00
# | epoch   1 |   100/  201 batches | lr 20.00 | ms/batch 2221.97 | loss 62.20 | ppl 1029556726208738552923029504.00
# | epoch   1 |   125/  201 batches | lr 20.00 | ms/batch 2374.86 | loss 54.87 | ppl 673240170147547222900736.00
# | epoch   1 |   150/  201 batches | lr 20.00 | ms/batch 2067.02 | loss 59.13 | ppl 47682828660910310324961280.00
# | epoch   1 |   175/  201 batches | lr 20.00 | ms/batch 2168.70 | loss 63.63 | ppl 4290550424691789843157483520.00
# | epoch   1 |   200/  201 batches | lr 20.00 | ms/batch 2298.34 | loss 60.79 | ppl 250987635192146525648060416.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 438.37s | valid loss 26.51 | valid ppl 325874541099.26
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  201 batches | lr 20.00 | ms/batch 2493.69 | loss 58.99 | ppl 41514064006599425031929856.00
# | epoch   2 |    50/  201 batches | lr 20.00 | ms/batch 2456.06 | loss 51.96 | ppl 36917842022464095256576.00
# | epoch   2 |    75/  201 batches | lr 20.00 | ms/batch 2214.51 | loss 53.74 | ppl 218099954503891978027008.00
# | epoch   2 |   100/  201 batches | lr 20.00 | ms/batch 2301.45 | loss 58.10 | ppl 17042106041392794448166912.00
# | epoch   2 |   125/  201 batches | lr 20.00 | ms/batch 2403.14 | loss 54.10 | ppl 313627947049649321279488.00
# | epoch   2 |   150/  201 batches | lr 20.00 | ms/batch 2319.81 | loss 54.79 | ppl 624217458263695743254528.00
# | epoch   2 |   175/  201 batches | lr 20.00 | ms/batch 2333.23 | loss 55.34 | ppl 1078418616800742081560576.00
# | epoch   2 |   200/  201 batches | lr 20.00 | ms/batch 2479.89 | loss 50.87 | ppl 12351874522107627962368.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 489.09s | valid loss 19.70 | valid ppl 359520194.86
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  201 batches | lr 20.00 | ms/batch 2600.82 | loss 57.45 | ppl 8956916934465619492864000.00
# | epoch   3 |    50/  201 batches | lr 20.00 | ms/batch 2317.00 | loss 56.02 | ppl 2135304625927771056504832.00
# | epoch   3 |    75/  201 batches | lr 20.00 | ms/batch 2169.29 | loss 55.62 | ppl 1427596532206620555345920.00
# | epoch   3 |   100/  201 batches | lr 20.00 | ms/batch 2336.87 | loss 51.04 | ppl 14662669854962647826432.00
# | epoch   3 |   125/  201 batches | lr 20.00 | ms/batch 2295.07 | loss 50.94 | ppl 13220665352055060168704.00
# | epoch   3 |   150/  201 batches | lr 20.00 | ms/batch 2354.41 | loss 60.20 | ppl 139476169334178306230059008.00
# | epoch   3 |   175/  201 batches | lr 20.00 | ms/batch 2360.51 | loss 56.91 | ppl 5204784055938954653859840.00
# | epoch   3 |   200/  201 batches | lr 20.00 | ms/batch 2459.35 | loss 55.49 | ppl 1257010006366998946119680.00
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 487.72s | valid loss 68.12 | valid ppl 381936553655857524987861663744.00
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  201 batches | lr 5.00 | ms/batch 2625.33 | loss 25.62 | ppl 133349375356.18
# | epoch   4 |    50/  201 batches | lr 5.00 | ms/batch 2491.48 | loss 18.86 | ppl 155103695.44
# | epoch   4 |    75/  201 batches | lr 5.00 | ms/batch 2460.58 | loss 16.52 | ppl 14973774.98
# | epoch   4 |   100/  201 batches | lr 5.00 | ms/batch 2499.43 | loss 13.22 | ppl 549960.14
# | epoch   4 |   125/  201 batches | lr 5.00 | ms/batch 2416.10 | loss 13.78 | ppl 961993.99
# | epoch   4 |   150/  201 batches | lr 5.00 | ms/batch 2466.48 | loss 13.20 | ppl 541352.68
# | epoch   4 |   175/  201 batches | lr 5.00 | ms/batch 2461.62 | loss 13.50 | ppl 728865.99
# | epoch   4 |   200/  201 batches | lr 5.00 | ms/batch 2428.57 | loss 12.86 | ppl 383672.11
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 511.00s | valid loss  8.80 | valid ppl  6654.38
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  201 batches | lr 5.00 | ms/batch 2547.39 | loss 12.84 | ppl 376849.83
# | epoch   5 |    50/  201 batches | lr 5.00 | ms/batch 2430.54 | loss 13.26 | ppl 573302.28
# | epoch   5 |    75/  201 batches | lr 5.00 | ms/batch 2563.29 | loss 13.13 | ppl 501876.55
# | epoch   5 |   100/  201 batches | lr 5.00 | ms/batch 2332.85 | loss 12.41 | ppl 245682.02
# | epoch   5 |   125/  201 batches | lr 5.00 | ms/batch 2441.99 | loss 13.64 | ppl 838982.71
# | epoch   5 |   150/  201 batches | lr 5.00 | ms/batch 2476.65 | loss 12.98 | ppl 434718.68
# | epoch   5 |   175/  201 batches | lr 5.00 | ms/batch 2460.06 | loss 12.33 | ppl 225479.23
# | epoch   5 |   200/  201 batches | lr 5.00 | ms/batch 2339.01 | loss 13.02 | ppl 450011.15
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 505.21s | valid loss 14.54 | valid ppl 2055429.22
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  201 batches | lr 1.25 | ms/batch 2608.00 | loss  6.31 | ppl   550.37
# | epoch   6 |    50/  201 batches | lr 1.25 | ms/batch 2643.70 | loss  5.03 | ppl   152.31
# | epoch   6 |    75/  201 batches | lr 1.25 | ms/batch 2669.08 | loss  5.03 | ppl   152.98
# | epoch   6 |   100/  201 batches | lr 1.25 | ms/batch 2641.28 | loss  4.95 | ppl   141.13
# | epoch   6 |   125/  201 batches | lr 1.25 | ms/batch 2638.50 | loss  4.99 | ppl   147.53
# | epoch   6 |   150/  201 batches | lr 1.25 | ms/batch 2642.99 | loss  4.96 | ppl   142.49
# | epoch   6 |   175/  201 batches | lr 1.25 | ms/batch 2661.76 | loss  4.98 | ppl   144.98
# | epoch   6 |   200/  201 batches | lr 1.25 | ms/batch 2656.10 | loss  4.96 | ppl   142.32
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 544.31s | valid loss  4.87 | valid ppl   130.50
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  201 batches | lr 1.25 | ms/batch 2807.31 | loss  5.28 | ppl   196.13
# | epoch   7 |    50/  201 batches | lr 1.25 | ms/batch 2710.52 | loss  5.02 | ppl   151.02
# | epoch   7 |    75/  201 batches | lr 1.25 | ms/batch 2710.03 | loss  5.01 | ppl   149.78
# | epoch   7 |   100/  201 batches | lr 1.25 | ms/batch 2692.20 | loss  4.95 | ppl   141.23
# | epoch   7 |   125/  201 batches | lr 1.25 | ms/batch 2701.42 | loss  4.97 | ppl   144.30
# | epoch   7 |   150/  201 batches | lr 1.25 | ms/batch 2689.77 | loss  4.95 | ppl   141.63
# | epoch   7 |   175/  201 batches | lr 1.25 | ms/batch 2693.94 | loss  4.96 | ppl   143.01
# | epoch   7 |   200/  201 batches | lr 1.25 | ms/batch 2742.21 | loss  4.96 | ppl   142.14
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 558.96s | valid loss  4.91 | valid ppl   135.90
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  201 batches | lr 0.31 | ms/batch 2865.57 | loss  4.54 | ppl    93.43
# | epoch   8 |    50/  201 batches | lr 0.31 | ms/batch 2714.28 | loss  4.22 | ppl    68.36
# | epoch   8 |    75/  201 batches | lr 0.31 | ms/batch 2713.61 | loss  4.21 | ppl    67.15
# | epoch   8 |   100/  201 batches | lr 0.31 | ms/batch 2718.53 | loss  4.16 | ppl    64.22
# | epoch   8 |   125/  201 batches | lr 0.31 | ms/batch 2716.63 | loss  4.18 | ppl    65.10
# | epoch   8 |   150/  201 batches | lr 0.31 | ms/batch 2729.20 | loss  4.17 | ppl    64.55
# | epoch   8 |   175/  201 batches | lr 0.31 | ms/batch 2719.28 | loss  4.16 | ppl    63.84
# | epoch   8 |   200/  201 batches | lr 0.31 | ms/batch 2709.36 | loss  4.17 | ppl    64.85
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 562.80s | valid loss  4.28 | valid ppl    71.91
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  201 batches | lr 0.31 | ms/batch 2842.69 | loss  4.45 | ppl    85.87
# | epoch   9 |    50/  201 batches | lr 0.31 | ms/batch 2725.48 | loss  4.22 | ppl    68.34
# | epoch   9 |    75/  201 batches | lr 0.31 | ms/batch 2741.43 | loss  4.21 | ppl    67.12
# | epoch   9 |   100/  201 batches | lr 0.31 | ms/batch 2715.11 | loss  4.16 | ppl    64.19
# | epoch   9 |   125/  201 batches | lr 0.31 | ms/batch 2735.28 | loss  4.17 | ppl    65.02
# | epoch   9 |   150/  201 batches | lr 0.31 | ms/batch 2725.00 | loss  4.16 | ppl    64.01
# | epoch   9 |   175/  201 batches | lr 0.31 | ms/batch 2733.56 | loss  4.15 | ppl    63.51
# | epoch   9 |   200/  201 batches | lr 0.31 | ms/batch 2705.18 | loss  4.17 | ppl    64.80
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 563.42s | valid loss  4.28 | valid ppl    71.93
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  201 batches | lr 0.08 | ms/batch 2871.15 | loss  4.45 | ppl    85.69
# | epoch  10 |    50/  201 batches | lr 0.08 | ms/batch 2717.36 | loss  4.22 | ppl    68.25
# | epoch  10 |    75/  201 batches | lr 0.08 | ms/batch 2720.16 | loss  4.20 | ppl    66.87
# | epoch  10 |   100/  201 batches | lr 0.08 | ms/batch 2730.96 | loss  4.15 | ppl    63.73
# | epoch  10 |   125/  201 batches | lr 0.08 | ms/batch 2717.26 | loss  4.17 | ppl    64.81
# | epoch  10 |   150/  201 batches | lr 0.08 | ms/batch 2729.21 | loss  4.16 | ppl    63.95
# | epoch  10 |   175/  201 batches | lr 0.08 | ms/batch 2735.38 | loss  4.15 | ppl    63.63
# | epoch  10 |   200/  201 batches | lr 0.08 | ms/batch 2709.56 | loss  4.17 | ppl    64.74
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 563.63s | valid loss  4.27 | valid ppl    71.87
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  201 batches | lr 0.08 | ms/batch 2836.66 | loss  4.45 | ppl    86.05
# | epoch  11 |    50/  201 batches | lr 0.08 | ms/batch 2734.38 | loss  4.22 | ppl    67.93
# | epoch  11 |    75/  201 batches | lr 0.08 | ms/batch 2714.02 | loss  4.20 | ppl    66.97
# | epoch  11 |   100/  201 batches | lr 0.08 | ms/batch 2702.40 | loss  4.16 | ppl    63.76
# | epoch  11 |   125/  201 batches | lr 0.08 | ms/batch 2704.89 | loss  4.17 | ppl    64.73
# | epoch  11 |   150/  201 batches | lr 0.08 | ms/batch 2700.90 | loss  4.16 | ppl    64.22
# | epoch  11 |   175/  201 batches | lr 0.08 | ms/batch 2701.22 | loss  4.15 | ppl    63.52
# | epoch  11 |   200/  201 batches | lr 0.08 | ms/batch 2710.30 | loss  4.17 | ppl    64.80
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 560.58s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  201 batches | lr 0.08 | ms/batch 2843.03 | loss  4.45 | ppl    85.66
# | epoch  12 |    50/  201 batches | lr 0.08 | ms/batch 2711.16 | loss  4.22 | ppl    67.96
# | epoch  12 |    75/  201 batches | lr 0.08 | ms/batch 2740.24 | loss  4.20 | ppl    66.92
# | epoch  12 |   100/  201 batches | lr 0.08 | ms/batch 2720.08 | loss  4.16 | ppl    63.94
# | epoch  12 |   125/  201 batches | lr 0.08 | ms/batch 2730.03 | loss  4.17 | ppl    64.81
# | epoch  12 |   150/  201 batches | lr 0.08 | ms/batch 2735.46 | loss  4.16 | ppl    63.99
# | epoch  12 |   175/  201 batches | lr 0.08 | ms/batch 2710.48 | loss  4.15 | ppl    63.55
# | epoch  12 |   200/  201 batches | lr 0.08 | ms/batch 2715.42 | loss  4.17 | ppl    64.80
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 563.27s | valid loss  4.27 | valid ppl    71.87
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  201 batches | lr 0.02 | ms/batch 2832.65 | loss  4.45 | ppl    85.98
# | epoch  13 |    50/  201 batches | lr 0.02 | ms/batch 2722.95 | loss  4.22 | ppl    68.18
# | epoch  13 |    75/  201 batches | lr 0.02 | ms/batch 2721.50 | loss  4.20 | ppl    66.73
# | epoch  13 |   100/  201 batches | lr 0.02 | ms/batch 2729.93 | loss  4.15 | ppl    63.70
# | epoch  13 |   125/  201 batches | lr 0.02 | ms/batch 2701.36 | loss  4.17 | ppl    64.63
# | epoch  13 |   150/  201 batches | lr 0.02 | ms/batch 2734.82 | loss  4.16 | ppl    63.86
# | epoch  13 |   175/  201 batches | lr 0.02 | ms/batch 2736.70 | loss  4.15 | ppl    63.31
# | epoch  13 |   200/  201 batches | lr 0.02 | ms/batch 2721.94 | loss  4.17 | ppl    64.84
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 563.12s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  201 batches | lr 0.00 | ms/batch 2822.21 | loss  4.45 | ppl    85.93
# | epoch  14 |    50/  201 batches | lr 0.00 | ms/batch 2715.96 | loss  4.22 | ppl    67.79
# | epoch  14 |    75/  201 batches | lr 0.00 | ms/batch 2707.27 | loss  4.21 | ppl    67.09
# | epoch  14 |   100/  201 batches | lr 0.00 | ms/batch 2741.92 | loss  4.16 | ppl    63.81
# | epoch  14 |   125/  201 batches | lr 0.00 | ms/batch 2747.41 | loss  4.17 | ppl    64.64
# | epoch  14 |   150/  201 batches | lr 0.00 | ms/batch 2723.83 | loss  4.16 | ppl    64.06
# | epoch  14 |   175/  201 batches | lr 0.00 | ms/batch 2716.95 | loss  4.15 | ppl    63.60
# | epoch  14 |   200/  201 batches | lr 0.00 | ms/batch 2726.34 | loss  4.17 | ppl    64.84
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 562.85s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  201 batches | lr 0.00 | ms/batch 2824.32 | loss  4.45 | ppl    85.79
# | epoch  15 |    50/  201 batches | lr 0.00 | ms/batch 2736.21 | loss  4.22 | ppl    67.96
# | epoch  15 |    75/  201 batches | lr 0.00 | ms/batch 2713.58 | loss  4.20 | ppl    66.94
# | epoch  15 |   100/  201 batches | lr 0.00 | ms/batch 2750.59 | loss  4.16 | ppl    63.90
# | epoch  15 |   125/  201 batches | lr 0.00 | ms/batch 2715.47 | loss  4.17 | ppl    64.65
# | epoch  15 |   150/  201 batches | lr 0.00 | ms/batch 2705.18 | loss  4.16 | ppl    64.14
# | epoch  15 |   175/  201 batches | lr 0.00 | ms/batch 2739.18 | loss  4.15 | ppl    63.65
# | epoch  15 |   200/  201 batches | lr 0.00 | ms/batch 2727.47 | loss  4.17 | ppl    64.75
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 563.19s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  201 batches | lr 0.00 | ms/batch 2880.72 | loss  4.45 | ppl    85.87
# | epoch  16 |    50/  201 batches | lr 0.00 | ms/batch 2750.86 | loss  4.22 | ppl    67.97
# | epoch  16 |    75/  201 batches | lr 0.00 | ms/batch 2697.84 | loss  4.20 | ppl    66.87
# | epoch  16 |   100/  201 batches | lr 0.00 | ms/batch 2719.63 | loss  4.16 | ppl    63.79
# | epoch  16 |   125/  201 batches | lr 0.00 | ms/batch 2728.64 | loss  4.17 | ppl    64.65
# | epoch  16 |   150/  201 batches | lr 0.00 | ms/batch 2737.54 | loss  4.16 | ppl    64.33
# | epoch  16 |   175/  201 batches | lr 0.00 | ms/batch 2714.33 | loss  4.15 | ppl    63.34
# | epoch  16 |   200/  201 batches | lr 0.00 | ms/batch 2728.43 | loss  4.17 | ppl    64.89
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 564.23s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  201 batches | lr 0.00 | ms/batch 2839.35 | loss  4.45 | ppl    85.81
# | epoch  17 |    50/  201 batches | lr 0.00 | ms/batch 2729.58 | loss  4.22 | ppl    68.04
# | epoch  17 |    75/  201 batches | lr 0.00 | ms/batch 2728.38 | loss  4.20 | ppl    66.81
# | epoch  17 |   100/  201 batches | lr 0.00 | ms/batch 2734.90 | loss  4.15 | ppl    63.66
# | epoch  17 |   125/  201 batches | lr 0.00 | ms/batch 2718.04 | loss  4.17 | ppl    64.59
# | epoch  17 |   150/  201 batches | lr 0.00 | ms/batch 2735.32 | loss  4.16 | ppl    64.10
# | epoch  17 |   175/  201 batches | lr 0.00 | ms/batch 2725.12 | loss  4.15 | ppl    63.53
# | epoch  17 |   200/  201 batches | lr 0.00 | ms/batch 2740.86 | loss  4.17 | ppl    64.81
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 564.09s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  201 batches | lr 0.00 | ms/batch 2848.09 | loss  4.45 | ppl    85.80
# | epoch  18 |    50/  201 batches | lr 0.00 | ms/batch 2734.89 | loss  4.22 | ppl    68.12
# | epoch  18 |    75/  201 batches | lr 0.00 | ms/batch 2736.07 | loss  4.20 | ppl    66.81
# | epoch  18 |   100/  201 batches | lr 0.00 | ms/batch 2716.74 | loss  4.15 | ppl    63.60
# | epoch  18 |   125/  201 batches | lr 0.00 | ms/batch 2740.65 | loss  4.17 | ppl    64.91
# | epoch  18 |   150/  201 batches | lr 0.00 | ms/batch 2713.06 | loss  4.16 | ppl    64.36
# | epoch  18 |   175/  201 batches | lr 0.00 | ms/batch 2742.89 | loss  4.15 | ppl    63.49
# | epoch  18 |   200/  201 batches | lr 0.00 | ms/batch 2735.05 | loss  4.17 | ppl    64.63
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 564.76s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  201 batches | lr 0.00 | ms/batch 2850.18 | loss  4.45 | ppl    86.01
# | epoch  19 |    50/  201 batches | lr 0.00 | ms/batch 2726.85 | loss  4.22 | ppl    67.93
# | epoch  19 |    75/  201 batches | lr 0.00 | ms/batch 2747.48 | loss  4.20 | ppl    66.80
# | epoch  19 |   100/  201 batches | lr 0.00 | ms/batch 2720.52 | loss  4.16 | ppl    63.96
# | epoch  19 |   125/  201 batches | lr 0.00 | ms/batch 2715.95 | loss  4.17 | ppl    64.94
# | epoch  19 |   150/  201 batches | lr 0.00 | ms/batch 2712.77 | loss  4.16 | ppl    64.16
# | epoch  19 |   175/  201 batches | lr 0.00 | ms/batch 2731.98 | loss  4.15 | ppl    63.47
# | epoch  19 |   200/  201 batches | lr 0.00 | ms/batch 2732.93 | loss  4.17 | ppl    64.60
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 563.92s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  201 batches | lr 0.00 | ms/batch 2841.67 | loss  4.45 | ppl    85.75
# | epoch  20 |    50/  201 batches | lr 0.00 | ms/batch 2719.08 | loss  4.22 | ppl    68.18
# | epoch  20 |    75/  201 batches | lr 0.00 | ms/batch 2730.99 | loss  4.20 | ppl    66.70
# | epoch  20 |   100/  201 batches | lr 0.00 | ms/batch 2726.96 | loss  4.16 | ppl    64.05
# | epoch  20 |   125/  201 batches | lr 0.00 | ms/batch 2726.66 | loss  4.17 | ppl    64.64
# | epoch  20 |   150/  201 batches | lr 0.00 | ms/batch 2705.30 | loss  4.16 | ppl    64.22
# | epoch  20 |   175/  201 batches | lr 0.00 | ms/batch 2730.25 | loss  4.15 | ppl    63.53
# | epoch  20 |   200/  201 batches | lr 0.00 | ms/batch 2737.54 | loss  4.17 | ppl    64.67
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 563.25s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  201 batches | lr 0.00 | ms/batch 2837.47 | loss  4.45 | ppl    85.74
# | epoch  21 |    50/  201 batches | lr 0.00 | ms/batch 2721.65 | loss  4.22 | ppl    68.21
# | epoch  21 |    75/  201 batches | lr 0.00 | ms/batch 2710.54 | loss  4.20 | ppl    66.91
# | epoch  21 |   100/  201 batches | lr 0.00 | ms/batch 2714.87 | loss  4.15 | ppl    63.73
# | epoch  21 |   125/  201 batches | lr 0.00 | ms/batch 2735.79 | loss  4.17 | ppl    64.69
# | epoch  21 |   150/  201 batches | lr 0.00 | ms/batch 2711.73 | loss  4.16 | ppl    64.06
# | epoch  21 |   175/  201 batches | lr 0.00 | ms/batch 2738.10 | loss  4.15 | ppl    63.47
# | epoch  21 |   200/  201 batches | lr 0.00 | ms/batch 2716.76 | loss  4.17 | ppl    64.66
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 563.14s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  201 batches | lr 0.00 | ms/batch 2830.57 | loss  4.45 | ppl    85.64
# | epoch  22 |    50/  201 batches | lr 0.00 | ms/batch 2733.03 | loss  4.22 | ppl    68.22
# | epoch  22 |    75/  201 batches | lr 0.00 | ms/batch 2710.22 | loss  4.21 | ppl    67.06
# | epoch  22 |   100/  201 batches | lr 0.00 | ms/batch 2731.63 | loss  4.15 | ppl    63.68
# | epoch  22 |   125/  201 batches | lr 0.00 | ms/batch 2709.81 | loss  4.17 | ppl    64.99
# | epoch  22 |   150/  201 batches | lr 0.00 | ms/batch 2708.57 | loss  4.16 | ppl    64.16
# | epoch  22 |   175/  201 batches | lr 0.00 | ms/batch 2728.83 | loss  4.15 | ppl    63.45
# | epoch  22 |   200/  201 batches | lr 0.00 | ms/batch 2729.08 | loss  4.17 | ppl    64.71
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 562.38s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  201 batches | lr 0.00 | ms/batch 2850.69 | loss  4.45 | ppl    85.88
# | epoch  23 |    50/  201 batches | lr 0.00 | ms/batch 2731.25 | loss  4.22 | ppl    68.02
# | epoch  23 |    75/  201 batches | lr 0.00 | ms/batch 2768.49 | loss  4.20 | ppl    66.97
# | epoch  23 |   100/  201 batches | lr 0.00 | ms/batch 2739.87 | loss  4.16 | ppl    63.81
# | epoch  23 |   125/  201 batches | lr 0.00 | ms/batch 2741.91 | loss  4.17 | ppl    64.47
# | epoch  23 |   150/  201 batches | lr 0.00 | ms/batch 2713.41 | loss  4.16 | ppl    64.09
# | epoch  23 |   175/  201 batches | lr 0.00 | ms/batch 2708.88 | loss  4.15 | ppl    63.42
# | epoch  23 |   200/  201 batches | lr 0.00 | ms/batch 2712.50 | loss  4.17 | ppl    64.66
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 564.52s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  201 batches | lr 0.00 | ms/batch 2839.45 | loss  4.45 | ppl    86.00
# | epoch  24 |    50/  201 batches | lr 0.00 | ms/batch 2711.34 | loss  4.22 | ppl    68.19
# | epoch  24 |    75/  201 batches | lr 0.00 | ms/batch 2721.53 | loss  4.20 | ppl    66.84
# | epoch  24 |   100/  201 batches | lr 0.00 | ms/batch 2728.01 | loss  4.15 | ppl    63.73
# | epoch  24 |   125/  201 batches | lr 0.00 | ms/batch 2728.80 | loss  4.17 | ppl    64.53
# | epoch  24 |   150/  201 batches | lr 0.00 | ms/batch 2734.35 | loss  4.16 | ppl    64.26
# | epoch  24 |   175/  201 batches | lr 0.00 | ms/batch 2763.08 | loss  4.15 | ppl    63.68
# | epoch  24 |   200/  201 batches | lr 0.00 | ms/batch 2719.79 | loss  4.17 | ppl    64.55
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 564.10s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  201 batches | lr 0.00 | ms/batch 2827.59 | loss  4.45 | ppl    85.62
# | epoch  25 |    50/  201 batches | lr 0.00 | ms/batch 2715.02 | loss  4.22 | ppl    68.00
# | epoch  25 |    75/  201 batches | lr 0.00 | ms/batch 2725.89 | loss  4.20 | ppl    66.80
# | epoch  25 |   100/  201 batches | lr 0.00 | ms/batch 2733.42 | loss  4.15 | ppl    63.75
# | epoch  25 |   125/  201 batches | lr 0.00 | ms/batch 2730.72 | loss  4.17 | ppl    64.76
# | epoch  25 |   150/  201 batches | lr 0.00 | ms/batch 2747.84 | loss  4.16 | ppl    64.25
# | epoch  25 |   175/  201 batches | lr 0.00 | ms/batch 2736.83 | loss  4.15 | ppl    63.41
# | epoch  25 |   200/  201 batches | lr 0.00 | ms/batch 2715.08 | loss  4.18 | ppl    65.07
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 563.72s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  201 batches | lr 0.00 | ms/batch 2829.15 | loss  4.45 | ppl    85.94
# | epoch  26 |    50/  201 batches | lr 0.00 | ms/batch 2753.09 | loss  4.22 | ppl    68.33
# | epoch  26 |    75/  201 batches | lr 0.00 | ms/batch 2737.22 | loss  4.20 | ppl    66.75
# | epoch  26 |   100/  201 batches | lr 0.00 | ms/batch 2739.58 | loss  4.16 | ppl    63.78
# | epoch  26 |   125/  201 batches | lr 0.00 | ms/batch 2716.78 | loss  4.17 | ppl    64.74
# | epoch  26 |   150/  201 batches | lr 0.00 | ms/batch 2718.78 | loss  4.16 | ppl    64.02
# | epoch  26 |   175/  201 batches | lr 0.00 | ms/batch 2721.76 | loss  4.15 | ppl    63.52
# | epoch  26 |   200/  201 batches | lr 0.00 | ms/batch 2719.97 | loss  4.17 | ppl    64.94
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 563.79s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  201 batches | lr 0.00 | ms/batch 2843.66 | loss  4.45 | ppl    85.75
# | epoch  27 |    50/  201 batches | lr 0.00 | ms/batch 2728.93 | loss  4.22 | ppl    68.11
# | epoch  27 |    75/  201 batches | lr 0.00 | ms/batch 2717.16 | loss  4.20 | ppl    66.84
# | epoch  27 |   100/  201 batches | lr 0.00 | ms/batch 2728.67 | loss  4.16 | ppl    63.98
# | epoch  27 |   125/  201 batches | lr 0.00 | ms/batch 2718.19 | loss  4.17 | ppl    64.58
# | epoch  27 |   150/  201 batches | lr 0.00 | ms/batch 2726.95 | loss  4.16 | ppl    64.16
# | epoch  27 |   175/  201 batches | lr 0.00 | ms/batch 2744.71 | loss  4.15 | ppl    63.37
# | epoch  27 |   200/  201 batches | lr 0.00 | ms/batch 2739.82 | loss  4.17 | ppl    64.77
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 563.99s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  201 batches | lr 0.00 | ms/batch 2835.50 | loss  4.46 | ppl    86.07
# | epoch  28 |    50/  201 batches | lr 0.00 | ms/batch 2731.20 | loss  4.22 | ppl    67.83
# | epoch  28 |    75/  201 batches | lr 0.00 | ms/batch 2725.81 | loss  4.20 | ppl    66.80
# | epoch  28 |   100/  201 batches | lr 0.00 | ms/batch 2733.97 | loss  4.16 | ppl    63.98
# | epoch  28 |   125/  201 batches | lr 0.00 | ms/batch 2709.14 | loss  4.17 | ppl    64.98
# | epoch  28 |   150/  201 batches | lr 0.00 | ms/batch 2736.57 | loss  4.16 | ppl    64.22
# | epoch  28 |   175/  201 batches | lr 0.00 | ms/batch 2714.51 | loss  4.15 | ppl    63.61
# | epoch  28 |   200/  201 batches | lr 0.00 | ms/batch 2741.89 | loss  4.17 | ppl    64.63
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 563.60s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/  201 batches | lr 0.00 | ms/batch 2852.49 | loss  4.45 | ppl    85.83
# | epoch  29 |    50/  201 batches | lr 0.00 | ms/batch 2736.48 | loss  4.22 | ppl    68.10
# | epoch  29 |    75/  201 batches | lr 0.00 | ms/batch 2701.98 | loss  4.21 | ppl    67.09
# | epoch  29 |   100/  201 batches | lr 0.00 | ms/batch 2728.41 | loss  4.15 | ppl    63.58
# | epoch  29 |   125/  201 batches | lr 0.00 | ms/batch 2733.65 | loss  4.17 | ppl    64.66
# | epoch  29 |   150/  201 batches | lr 0.00 | ms/batch 2735.69 | loss  4.16 | ppl    64.07
# | epoch  29 |   175/  201 batches | lr 0.00 | ms/batch 2738.50 | loss  4.15 | ppl    63.60
# | epoch  29 |   200/  201 batches | lr 0.00 | ms/batch 2757.40 | loss  4.17 | ppl    64.55
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 565.05s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/  201 batches | lr 0.00 | ms/batch 2821.65 | loss  4.45 | ppl    85.71
# | epoch  30 |    50/  201 batches | lr 0.00 | ms/batch 2723.25 | loss  4.22 | ppl    68.15
# | epoch  30 |    75/  201 batches | lr 0.00 | ms/batch 2730.11 | loss  4.20 | ppl    66.82
# | epoch  30 |   100/  201 batches | lr 0.00 | ms/batch 2729.71 | loss  4.16 | ppl    63.90
# | epoch  30 |   125/  201 batches | lr 0.00 | ms/batch 2708.84 | loss  4.17 | ppl    64.72
# | epoch  30 |   150/  201 batches | lr 0.00 | ms/batch 2762.09 | loss  4.16 | ppl    64.03
# | epoch  30 |   175/  201 batches | lr 0.00 | ms/batch 2732.32 | loss  4.15 | ppl    63.44
# | epoch  30 |   200/  201 batches | lr 0.00 | ms/batch 2731.76 | loss  4.17 | ppl    64.60
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 564.08s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/  201 batches | lr 0.00 | ms/batch 2841.48 | loss  4.46 | ppl    86.11
# | epoch  31 |    50/  201 batches | lr 0.00 | ms/batch 2715.66 | loss  4.22 | ppl    67.96
# | epoch  31 |    75/  201 batches | lr 0.00 | ms/batch 2757.68 | loss  4.20 | ppl    66.66
# | epoch  31 |   100/  201 batches | lr 0.00 | ms/batch 2738.05 | loss  4.15 | ppl    63.74
# | epoch  31 |   125/  201 batches | lr 0.00 | ms/batch 2729.13 | loss  4.17 | ppl    64.56
# | epoch  31 |   150/  201 batches | lr 0.00 | ms/batch 2719.98 | loss  4.16 | ppl    64.24
# | epoch  31 |   175/  201 batches | lr 0.00 | ms/batch 2741.71 | loss  4.15 | ppl    63.15
# | epoch  31 |   200/  201 batches | lr 0.00 | ms/batch 2758.06 | loss  4.17 | ppl    64.63
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 565.48s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/  201 batches | lr 0.00 | ms/batch 2862.03 | loss  4.45 | ppl    85.69
# | epoch  32 |    50/  201 batches | lr 0.00 | ms/batch 2736.57 | loss  4.22 | ppl    67.89
# | epoch  32 |    75/  201 batches | lr 0.00 | ms/batch 2732.66 | loss  4.20 | ppl    66.45
# | epoch  32 |   100/  201 batches | lr 0.00 | ms/batch 2713.70 | loss  4.15 | ppl    63.65
# | epoch  32 |   125/  201 batches | lr 0.00 | ms/batch 2712.44 | loss  4.17 | ppl    65.02
# | epoch  32 |   150/  201 batches | lr 0.00 | ms/batch 2720.86 | loss  4.16 | ppl    64.31
# | epoch  32 |   175/  201 batches | lr 0.00 | ms/batch 2730.83 | loss  4.15 | ppl    63.38
# | epoch  32 |   200/  201 batches | lr 0.00 | ms/batch 2730.29 | loss  4.17 | ppl    64.82
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 563.86s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/  201 batches | lr 0.00 | ms/batch 2874.00 | loss  4.46 | ppl    86.06
# | epoch  33 |    50/  201 batches | lr 0.00 | ms/batch 2729.11 | loss  4.22 | ppl    68.25
# | epoch  33 |    75/  201 batches | lr 0.00 | ms/batch 2731.43 | loss  4.21 | ppl    67.05
# | epoch  33 |   100/  201 batches | lr 0.00 | ms/batch 2742.37 | loss  4.16 | ppl    63.81
# | epoch  33 |   125/  201 batches | lr 0.00 | ms/batch 2735.87 | loss  4.17 | ppl    64.74
# | epoch  33 |   150/  201 batches | lr 0.00 | ms/batch 2731.38 | loss  4.16 | ppl    64.08
# | epoch  33 |   175/  201 batches | lr 0.00 | ms/batch 2709.64 | loss  4.15 | ppl    63.59
# | epoch  33 |   200/  201 batches | lr 0.00 | ms/batch 2720.53 | loss  4.17 | ppl    64.93
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 564.66s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/  201 batches | lr 0.00 | ms/batch 2846.05 | loss  4.45 | ppl    85.53
# | epoch  34 |    50/  201 batches | lr 0.00 | ms/batch 2742.01 | loss  4.22 | ppl    67.97
# | epoch  34 |    75/  201 batches | lr 0.00 | ms/batch 2748.64 | loss  4.21 | ppl    67.08
# | epoch  34 |   100/  201 batches | lr 0.00 | ms/batch 2773.51 | loss  4.15 | ppl    63.68
# | epoch  34 |   125/  201 batches | lr 0.00 | ms/batch 2718.09 | loss  4.17 | ppl    64.95
# | epoch  34 |   150/  201 batches | lr 0.00 | ms/batch 2767.46 | loss  4.17 | ppl    64.40
# | epoch  34 |   175/  201 batches | lr 0.00 | ms/batch 2724.77 | loss  4.15 | ppl    63.29
# | epoch  34 |   200/  201 batches | lr 0.00 | ms/batch 2704.79 | loss  4.17 | ppl    64.60
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 566.24s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/  201 batches | lr 0.00 | ms/batch 2846.21 | loss  4.45 | ppl    85.88
# | epoch  35 |    50/  201 batches | lr 0.00 | ms/batch 2740.30 | loss  4.22 | ppl    68.33
# | epoch  35 |    75/  201 batches | lr 0.00 | ms/batch 2743.29 | loss  4.20 | ppl    66.85
# | epoch  35 |   100/  201 batches | lr 0.00 | ms/batch 2720.01 | loss  4.16 | ppl    63.79
# | epoch  35 |   125/  201 batches | lr 0.00 | ms/batch 2707.12 | loss  4.17 | ppl    64.60
# | epoch  35 |   150/  201 batches | lr 0.00 | ms/batch 2714.44 | loss  4.16 | ppl    64.17
# | epoch  35 |   175/  201 batches | lr 0.00 | ms/batch 2772.92 | loss  4.15 | ppl    63.46
# | epoch  35 |   200/  201 batches | lr 0.00 | ms/batch 2713.24 | loss  4.17 | ppl    64.83
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 564.79s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/  201 batches | lr 0.00 | ms/batch 2849.14 | loss  4.45 | ppl    85.74
# | epoch  36 |    50/  201 batches | lr 0.00 | ms/batch 2752.66 | loss  4.22 | ppl    67.98
# | epoch  36 |    75/  201 batches | lr 0.00 | ms/batch 2733.31 | loss  4.20 | ppl    66.71
# | epoch  36 |   100/  201 batches | lr 0.00 | ms/batch 2707.06 | loss  4.16 | ppl    63.88
# | epoch  36 |   125/  201 batches | lr 0.00 | ms/batch 2748.07 | loss  4.17 | ppl    64.85
# | epoch  36 |   150/  201 batches | lr 0.00 | ms/batch 2739.51 | loss  4.16 | ppl    64.06
# | epoch  36 |   175/  201 batches | lr 0.00 | ms/batch 2717.08 | loss  4.15 | ppl    63.27
# | epoch  36 |   200/  201 batches | lr 0.00 | ms/batch 2741.97 | loss  4.17 | ppl    64.81
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 565.02s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/  201 batches | lr 0.00 | ms/batch 2846.38 | loss  4.45 | ppl    85.76
# | epoch  37 |    50/  201 batches | lr 0.00 | ms/batch 2728.35 | loss  4.22 | ppl    67.93
# | epoch  37 |    75/  201 batches | lr 0.00 | ms/batch 2737.42 | loss  4.20 | ppl    66.96
# | epoch  37 |   100/  201 batches | lr 0.00 | ms/batch 2739.12 | loss  4.16 | ppl    63.79
# | epoch  37 |   125/  201 batches | lr 0.00 | ms/batch 2736.36 | loss  4.17 | ppl    64.61
# | epoch  37 |   150/  201 batches | lr 0.00 | ms/batch 2715.35 | loss  4.16 | ppl    64.03
# | epoch  37 |   175/  201 batches | lr 0.00 | ms/batch 2721.87 | loss  4.15 | ppl    63.54
# | epoch  37 |   200/  201 batches | lr 0.00 | ms/batch 2722.12 | loss  4.17 | ppl    64.77
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 564.03s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/  201 batches | lr 0.00 | ms/batch 2846.31 | loss  4.45 | ppl    85.91
# | epoch  38 |    50/  201 batches | lr 0.00 | ms/batch 2726.21 | loss  4.22 | ppl    68.18
# | epoch  38 |    75/  201 batches | lr 0.00 | ms/batch 2721.75 | loss  4.20 | ppl    66.99
# | epoch  38 |   100/  201 batches | lr 0.00 | ms/batch 2731.47 | loss  4.16 | ppl    63.83
# | epoch  38 |   125/  201 batches | lr 0.00 | ms/batch 2732.58 | loss  4.17 | ppl    64.66
# | epoch  38 |   150/  201 batches | lr 0.00 | ms/batch 2715.69 | loss  4.16 | ppl    63.95
# | epoch  38 |   175/  201 batches | lr 0.00 | ms/batch 2735.84 | loss  4.15 | ppl    63.50
# | epoch  38 |   200/  201 batches | lr 0.00 | ms/batch 2726.05 | loss  4.17 | ppl    64.84
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 563.87s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/  201 batches | lr 0.00 | ms/batch 2864.73 | loss  4.45 | ppl    86.00
# | epoch  39 |    50/  201 batches | lr 0.00 | ms/batch 2739.40 | loss  4.22 | ppl    68.15
# | epoch  39 |    75/  201 batches | lr 0.00 | ms/batch 2744.16 | loss  4.20 | ppl    66.96
# | epoch  39 |   100/  201 batches | lr 0.00 | ms/batch 2728.61 | loss  4.15 | ppl    63.73
# | epoch  39 |   125/  201 batches | lr 0.00 | ms/batch 2752.16 | loss  4.17 | ppl    64.52
# | epoch  39 |   150/  201 batches | lr 0.00 | ms/batch 2738.38 | loss  4.16 | ppl    64.33
# | epoch  39 |   175/  201 batches | lr 0.00 | ms/batch 2723.65 | loss  4.15 | ppl    63.49
# | epoch  39 |   200/  201 batches | lr 0.00 | ms/batch 2709.02 | loss  4.17 | ppl    64.69
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 565.38s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/  201 batches | lr 0.00 | ms/batch 2838.85 | loss  4.45 | ppl    85.88
# | epoch  40 |    50/  201 batches | lr 0.00 | ms/batch 2768.30 | loss  4.22 | ppl    67.98
# | epoch  40 |    75/  201 batches | lr 0.00 | ms/batch 2747.15 | loss  4.20 | ppl    66.75
# | epoch  40 |   100/  201 batches | lr 0.00 | ms/batch 2734.84 | loss  4.15 | ppl    63.74
# | epoch  40 |   125/  201 batches | lr 0.00 | ms/batch 2729.33 | loss  4.17 | ppl    64.75
# | epoch  40 |   150/  201 batches | lr 0.00 | ms/batch 2716.03 | loss  4.16 | ppl    63.88
# | epoch  40 |   175/  201 batches | lr 0.00 | ms/batch 2732.94 | loss  4.15 | ppl    63.53
# | epoch  40 |   200/  201 batches | lr 0.00 | ms/batch 2755.46 | loss  4.17 | ppl    64.46
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 566.11s | valid loss  4.27 | valid ppl    71.86
# -----------------------------------------------------------------------------------------

# %%
micmac_lstm2 = make_model(mic_corpus, "LSTM", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=True)

train(micmac_lstm2, mic_corpus, 20, 40, 'data/micmac')

# %%
micmac_lstm2 = make_model(mic_corpus, "LSTM", emsize=50, nhidden=50, nlayers=2, 
                          dropout=0.2, tied=False)

train(micmac_lstm2, mic_corpus, 20, 40, 'data/micmac')

# %%
train(micmac_gru, mic_corpus, 20, 40, 'data/micmac')
# Out:
# | epoch   1 |    25/  201 batches | lr 20.00 | ms/batch 790.33 | loss 326.89 | ppl 9286266198247115292586519714480277657649473013193173498282081372252742723394780397243182155643171744917138854305214443935897372697198363410432.00
# | epoch   1 |    50/  201 batches | lr 20.00 | ms/batch 479.93 | loss 273.15 | ppl 42394188229441008340469049966062966046933482889558522968608766320888992415400098160918462774944241165698138120287944704.00
# | epoch   1 |    75/  201 batches | lr 20.00 | ms/batch 466.10 | loss 204.91 | ppl 98215617301798750701494364066854155627123860091474860654175577757268408917499737448382464.00
# | epoch   1 |   100/  201 batches | lr 20.00 | ms/batch 500.85 | loss 128.17 | ppl 46160241108581485544008358540208759580292018606111195136.00
# | epoch   1 |   125/  201 batches | lr 20.00 | ms/batch 451.11 | loss 191.61 | ppl 164618502592794908643882645840203344850985135870670475609275640181481542617080528896.00
# | epoch   1 |   150/  201 batches | lr 20.00 | ms/batch 465.36 | loss 194.87 | ppl 4283831783201115855841616792996295437543410225875962177242498739524848279280850829312.00
# | epoch   1 |   175/  201 batches | lr 20.00 | ms/batch 548.88 | loss 76.74 | ppl 2133072289945296240536518400147456.00
# | epoch   1 |   200/  201 batches | lr 20.00 | ms/batch 539.57 | loss 65.84 | ppl 39227165799393784329781903360.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 108.45s | valid loss 33.60 | valid ppl 389557770273355.69
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  201 batches | lr 20.00 | ms/batch 546.52 | loss 118.42 | ppl 2674046435198910427011073606479415377019273283108864.00
# | epoch   2 |    50/  201 batches | lr 20.00 | ms/batch 543.61 | loss 117.16 | ppl 763831820481502110860032884762271792404360077508608.00
# | epoch   2 |    75/  201 batches | lr 20.00 | ms/batch 530.37 | loss 98.15 | ppl 4241268391926362513326612178680952337203200.00
# | epoch   2 |   100/  201 batches | lr 20.00 | ms/batch 558.24 | loss 125.10 | ppl 2147543881964103266890420219741078476945859861840658432.00
# | epoch   2 |   125/  201 batches | lr 20.00 | ms/batch 505.43 | loss 107.19 | ppl 35487638554425572570727838212108152846455668736.00
# | epoch   2 |   150/  201 batches | lr 20.00 | ms/batch 500.71 | loss 66.61 | ppl 84642345749184723229175971840.00
# | epoch   2 |   175/  201 batches | lr 20.00 | ms/batch 499.85 | loss 180.35 | ppl 2110583782988175588572797530225446824623802842008459164048109338925708567642112.00
# | epoch   2 |   200/  201 batches | lr 20.00 | ms/batch 540.86 | loss 163.52 | ppl 104145048001946698318657214601366537274661076605675310153716070728335360.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 107.43s | valid loss 344.92 | valid ppl 629114490383261745877901343056266473702435120093197233770604668723905792221230406955929483329357569340446230420218205203766192512254877709522134106112.00
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  201 batches | lr 5.00 | ms/batch 453.20 | loss 234.82 | ppl 959656284371162695784755811226487921603715213047562964050205439151488818075138991775343520100858724352.00
# | epoch   3 |    50/  201 batches | lr 5.00 | ms/batch 473.45 | loss 38.30 | ppl 42791810615355424.00
# | epoch   3 |    75/  201 batches | lr 5.00 | ms/batch 510.83 | loss 30.24 | ppl 13592096054494.55
# | epoch   3 |   100/  201 batches | lr 5.00 | ms/batch 493.91 | loss 28.35 | ppl 2052089553719.43
# | epoch   3 |   125/  201 batches | lr 5.00 | ms/batch 465.17 | loss 26.28 | ppl 260121581034.97
# | epoch   3 |   150/  201 batches | lr 5.00 | ms/batch 461.35 | loss 25.40 | ppl 107208451819.20
# | epoch   3 |   175/  201 batches | lr 5.00 | ms/batch 476.47 | loss 24.07 | ppl 28539290159.36
# | epoch   3 |   200/  201 batches | lr 5.00 | ms/batch 472.61 | loss 23.27 | ppl 12749943132.13
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 96.95s | valid loss 11.22 | valid ppl 74947.65
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  201 batches | lr 5.00 | ms/batch 490.34 | loss 22.57 | ppl 6308290382.17
# | epoch   4 |    50/  201 batches | lr 5.00 | ms/batch 473.35 | loss 21.10 | ppl 1458481327.71
# | epoch   4 |    75/  201 batches | lr 5.00 | ms/batch 462.42 | loss 20.72 | ppl 997969747.32
# | epoch   4 |   100/  201 batches | lr 5.00 | ms/batch 495.66 | loss 20.46 | ppl 765695878.78
# | epoch   4 |   125/  201 batches | lr 5.00 | ms/batch 488.36 | loss 20.31 | ppl 661492468.04
# | epoch   4 |   150/  201 batches | lr 5.00 | ms/batch 485.90 | loss 19.80 | ppl 397297012.86
# | epoch   4 |   175/  201 batches | lr 5.00 | ms/batch 495.33 | loss 20.07 | ppl 522833590.32
# | epoch   4 |   200/  201 batches | lr 5.00 | ms/batch 465.35 | loss 19.12 | ppl 201952810.50
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 98.69s | valid loss 10.06 | valid ppl 23387.70
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  201 batches | lr 5.00 | ms/batch 497.84 | loss 19.48 | ppl 287720125.54
# | epoch   5 |    50/  201 batches | lr 5.00 | ms/batch 460.79 | loss 18.91 | ppl 163914848.67
# | epoch   5 |    75/  201 batches | lr 5.00 | ms/batch 460.95 | loss 18.24 | ppl 83448326.94
# | epoch   5 |   100/  201 batches | lr 5.00 | ms/batch 441.64 | loss 17.28 | ppl 31820329.03
# | epoch   5 |   125/  201 batches | lr 5.00 | ms/batch 464.54 | loss 17.12 | ppl 27245368.37
# | epoch   5 |   150/  201 batches | lr 5.00 | ms/batch 440.17 | loss 15.71 | ppl 6629560.21
# | epoch   5 |   175/  201 batches | lr 5.00 | ms/batch 483.66 | loss 14.89 | ppl 2931755.61
# | epoch   5 |   200/  201 batches | lr 5.00 | ms/batch 496.21 | loss 15.96 | ppl 8503445.39
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 95.49s | valid loss  9.64 | valid ppl 15380.39
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  201 batches | lr 5.00 | ms/batch 479.58 | loss 15.85 | ppl 7685142.08
# | epoch   6 |    50/  201 batches | lr 5.00 | ms/batch 477.63 | loss 14.79 | ppl 2653731.90
# | epoch   6 |    75/  201 batches | lr 5.00 | ms/batch 479.59 | loss 15.13 | ppl 3714467.95
# | epoch   6 |   100/  201 batches | lr 5.00 | ms/batch 488.80 | loss 14.77 | ppl 2591522.06
# | epoch   6 |   125/  201 batches | lr 5.00 | ms/batch 491.47 | loss 14.33 | ppl 1670665.30
# | epoch   6 |   150/  201 batches | lr 5.00 | ms/batch 463.62 | loss 13.30 | ppl 594693.53
# | epoch   6 |   175/  201 batches | lr 5.00 | ms/batch 451.92 | loss 13.34 | ppl 620506.86
# | epoch   6 |   200/  201 batches | lr 5.00 | ms/batch 483.87 | loss 13.87 | ppl 1053205.19
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 97.34s | valid loss  9.03 | valid ppl  8347.44
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  201 batches | lr 5.00 | ms/batch 464.99 | loss 13.83 | ppl 1019607.51
# | epoch   7 |    50/  201 batches | lr 5.00 | ms/batch 462.18 | loss 12.70 | ppl 326827.11
# | epoch   7 |    75/  201 batches | lr 5.00 | ms/batch 471.99 | loss 12.51 | ppl 271444.82
# | epoch   7 |   100/  201 batches | lr 5.00 | ms/batch 484.35 | loss 13.98 | ppl 1175691.29
# | epoch   7 |   125/  201 batches | lr 5.00 | ms/batch 476.04 | loss 11.81 | ppl 134436.48
# | epoch   7 |   150/  201 batches | lr 5.00 | ms/batch 491.79 | loss 12.90 | ppl 401907.22
# | epoch   7 |   175/  201 batches | lr 5.00 | ms/batch 531.38 | loss 15.24 | ppl 4150554.27
# | epoch   7 |   200/  201 batches | lr 5.00 | ms/batch 554.44 | loss 13.42 | ppl 674428.96
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 100.38s | valid loss 15.81 | valid ppl 7361357.65
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  201 batches | lr 1.25 | ms/batch 547.07 | loss 14.07 | ppl 1296205.05
# | epoch   8 |    50/  201 batches | lr 1.25 | ms/batch 519.00 | loss 11.27 | ppl 78203.91
# | epoch   8 |    75/  201 batches | lr 1.25 | ms/batch 534.33 | loss 10.52 | ppl 37204.52
# | epoch   8 |   100/  201 batches | lr 1.25 | ms/batch 531.63 | loss 10.22 | ppl 27560.75
# | epoch   8 |   125/  201 batches | lr 1.25 | ms/batch 537.69 | loss  9.83 | ppl 18630.13
# | epoch   8 |   150/  201 batches | lr 1.25 | ms/batch 529.30 | loss  9.67 | ppl 15763.43
# | epoch   8 |   175/  201 batches | lr 1.25 | ms/batch 519.83 | loss  9.84 | ppl 18746.87
# | epoch   8 |   200/  201 batches | lr 1.25 | ms/batch 530.30 | loss 10.14 | ppl 25364.92
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 108.55s | valid loss  7.18 | valid ppl  1314.99
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  201 batches | lr 1.25 | ms/batch 533.71 | loss 10.48 | ppl 35667.19
# | epoch   9 |    50/  201 batches | lr 1.25 | ms/batch 533.72 | loss  9.56 | ppl 14151.58
# | epoch   9 |    75/  201 batches | lr 1.25 | ms/batch 515.17 | loss  9.47 | ppl 13017.85
# | epoch   9 |   100/  201 batches | lr 1.25 | ms/batch 524.77 | loss  9.77 | ppl 17443.82
# | epoch   9 |   125/  201 batches | lr 1.25 | ms/batch 569.23 | loss  9.48 | ppl 13089.79
# | epoch   9 |   150/  201 batches | lr 1.25 | ms/batch 513.31 | loss  9.06 | ppl  8615.91
# | epoch   9 |   175/  201 batches | lr 1.25 | ms/batch 534.00 | loss  9.29 | ppl 10780.99
# | epoch   9 |   200/  201 batches | lr 1.25 | ms/batch 546.30 | loss  9.53 | ppl 13725.63
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 108.72s | valid loss  7.08 | valid ppl  1185.73
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  201 batches | lr 1.25 | ms/batch 548.01 | loss  9.91 | ppl 20177.38
# | epoch  10 |    50/  201 batches | lr 1.25 | ms/batch 571.65 | loss  9.12 | ppl  9127.15
# | epoch  10 |    75/  201 batches | lr 1.25 | ms/batch 590.50 | loss  8.93 | ppl  7591.17
# | epoch  10 |   100/  201 batches | lr 1.25 | ms/batch 563.97 | loss  9.07 | ppl  8713.16
# | epoch  10 |   125/  201 batches | lr 1.25 | ms/batch 587.10 | loss  9.16 | ppl  9497.63
# | epoch  10 |   150/  201 batches | lr 1.25 | ms/batch 576.25 | loss  8.88 | ppl  7213.05
# | epoch  10 |   175/  201 batches | lr 1.25 | ms/batch 593.03 | loss  9.20 | ppl  9945.58
# | epoch  10 |   200/  201 batches | lr 1.25 | ms/batch 578.43 | loss  9.29 | ppl 10797.28
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 117.20s | valid loss  7.13 | valid ppl  1248.14
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  201 batches | lr 0.31 | ms/batch 609.96 | loss  9.55 | ppl 14079.10
# | epoch  11 |    50/  201 batches | lr 0.31 | ms/batch 565.66 | loss  8.67 | ppl  5804.40
# | epoch  11 |    75/  201 batches | lr 0.31 | ms/batch 592.90 | loss  8.94 | ppl  7628.98
# | epoch  11 |   100/  201 batches | lr 0.31 | ms/batch 613.33 | loss  8.97 | ppl  7860.49
# | epoch  11 |   125/  201 batches | lr 0.31 | ms/batch 608.92 | loss  9.00 | ppl  8123.77
# | epoch  11 |   150/  201 batches | lr 0.31 | ms/batch 580.79 | loss  8.68 | ppl  5880.39
# | epoch  11 |   175/  201 batches | lr 0.31 | ms/batch 592.01 | loss  8.85 | ppl  6994.93
# | epoch  11 |   200/  201 batches | lr 0.31 | ms/batch 611.47 | loss  9.18 | ppl  9653.17
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 121.51s | valid loss  7.12 | valid ppl  1237.70
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  201 batches | lr 0.08 | ms/batch 578.15 | loss  9.64 | ppl 15346.71
# | epoch  12 |    50/  201 batches | lr 0.08 | ms/batch 576.06 | loss  8.87 | ppl  7137.23
# | epoch  12 |    75/  201 batches | lr 0.08 | ms/batch 575.13 | loss  8.70 | ppl  6020.23
# | epoch  12 |   100/  201 batches | lr 0.08 | ms/batch 600.32 | loss  9.07 | ppl  8717.37
# | epoch  12 |   125/  201 batches | lr 0.08 | ms/batch 580.09 | loss  8.94 | ppl  7623.41
# | epoch  12 |   150/  201 batches | lr 0.08 | ms/batch 590.98 | loss  8.57 | ppl  5246.36
# | epoch  12 |   175/  201 batches | lr 0.08 | ms/batch 596.82 | loss  8.89 | ppl  7270.50
# | epoch  12 |   200/  201 batches | lr 0.08 | ms/batch 592.13 | loss  9.12 | ppl  9171.36
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 119.63s | valid loss  7.12 | valid ppl  1239.53
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  201 batches | lr 0.02 | ms/batch 598.30 | loss  9.42 | ppl 12380.04
# | epoch  13 |    50/  201 batches | lr 0.02 | ms/batch 611.81 | loss  8.72 | ppl  6137.85
# | epoch  13 |    75/  201 batches | lr 0.02 | ms/batch 572.70 | loss  8.81 | ppl  6676.85
# | epoch  13 |   100/  201 batches | lr 0.02 | ms/batch 571.37 | loss  9.03 | ppl  8312.23
# | epoch  13 |   125/  201 batches | lr 0.02 | ms/batch 601.44 | loss  8.91 | ppl  7410.84
# | epoch  13 |   150/  201 batches | lr 0.02 | ms/batch 582.62 | loss  8.62 | ppl  5555.21
# | epoch  13 |   175/  201 batches | lr 0.02 | ms/batch 596.98 | loss  8.77 | ppl  6438.26
# | epoch  13 |   200/  201 batches | lr 0.02 | ms/batch 558.90 | loss  9.30 | ppl 10919.51
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 119.48s | valid loss  7.12 | valid ppl  1239.45
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  201 batches | lr 0.00 | ms/batch 581.66 | loss  9.38 | ppl 11861.14
# | epoch  14 |    50/  201 batches | lr 0.00 | ms/batch 585.97 | loss  8.70 | ppl  6001.03
# | epoch  14 |    75/  201 batches | lr 0.00 | ms/batch 555.11 | loss  8.70 | ppl  6020.85
# | epoch  14 |   100/  201 batches | lr 0.00 | ms/batch 610.62 | loss  8.80 | ppl  6650.31
# | epoch  14 |   125/  201 batches | lr 0.00 | ms/batch 602.64 | loss  8.92 | ppl  7512.27
# | epoch  14 |   150/  201 batches | lr 0.00 | ms/batch 583.26 | loss  8.73 | ppl  6162.52
# | epoch  14 |   175/  201 batches | lr 0.00 | ms/batch 620.57 | loss  8.84 | ppl  6904.10
# | epoch  14 |   200/  201 batches | lr 0.00 | ms/batch 594.61 | loss  9.09 | ppl  8841.81
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 120.70s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  201 batches | lr 0.00 | ms/batch 584.99 | loss  9.58 | ppl 14493.92
# | epoch  15 |    50/  201 batches | lr 0.00 | ms/batch 569.63 | loss  8.65 | ppl  5701.11
# | epoch  15 |    75/  201 batches | lr 0.00 | ms/batch 566.19 | loss  8.97 | ppl  7849.77
# | epoch  15 |   100/  201 batches | lr 0.00 | ms/batch 576.24 | loss  8.88 | ppl  7218.19
# | epoch  15 |   125/  201 batches | lr 0.00 | ms/batch 607.47 | loss  9.01 | ppl  8219.51
# | epoch  15 |   150/  201 batches | lr 0.00 | ms/batch 609.74 | loss  8.85 | ppl  6946.70
# | epoch  15 |   175/  201 batches | lr 0.00 | ms/batch 598.56 | loss  8.98 | ppl  7913.87
# | epoch  15 |   200/  201 batches | lr 0.00 | ms/batch 572.42 | loss  9.45 | ppl 12697.12
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 119.00s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  201 batches | lr 0.00 | ms/batch 582.07 | loss  9.52 | ppl 13693.53
# | epoch  16 |    50/  201 batches | lr 0.00 | ms/batch 580.28 | loss  8.77 | ppl  6417.49
# | epoch  16 |    75/  201 batches | lr 0.00 | ms/batch 598.22 | loss  9.01 | ppl  8165.37
# | epoch  16 |   100/  201 batches | lr 0.00 | ms/batch 567.76 | loss  9.26 | ppl 10498.79
# | epoch  16 |   125/  201 batches | lr 0.00 | ms/batch 589.58 | loss  9.06 | ppl  8630.47
# | epoch  16 |   150/  201 batches | lr 0.00 | ms/batch 569.02 | loss  8.83 | ppl  6836.56
# | epoch  16 |   175/  201 batches | lr 0.00 | ms/batch 620.51 | loss  9.03 | ppl  8353.24
# | epoch  16 |   200/  201 batches | lr 0.00 | ms/batch 597.79 | loss  9.41 | ppl 12257.35
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 119.59s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  201 batches | lr 0.00 | ms/batch 587.28 | loss  9.37 | ppl 11771.22
# | epoch  17 |    50/  201 batches | lr 0.00 | ms/batch 594.21 | loss  8.70 | ppl  6011.48
# | epoch  17 |    75/  201 batches | lr 0.00 | ms/batch 570.16 | loss  8.75 | ppl  6330.79
# | epoch  17 |   100/  201 batches | lr 0.00 | ms/batch 581.17 | loss  9.04 | ppl  8430.19
# | epoch  17 |   125/  201 batches | lr 0.00 | ms/batch 583.59 | loss  9.05 | ppl  8504.92
# | epoch  17 |   150/  201 batches | lr 0.00 | ms/batch 589.44 | loss  8.65 | ppl  5693.40
# | epoch  17 |   175/  201 batches | lr 0.00 | ms/batch 609.37 | loss  8.94 | ppl  7652.67
# | epoch  17 |   200/  201 batches | lr 0.00 | ms/batch 568.50 | loss  9.56 | ppl 14154.63
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 119.02s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  201 batches | lr 0.00 | ms/batch 585.21 | loss  9.59 | ppl 14604.60
# | epoch  18 |    50/  201 batches | lr 0.00 | ms/batch 572.98 | loss  8.83 | ppl  6862.73
# | epoch  18 |    75/  201 batches | lr 0.00 | ms/batch 596.89 | loss  8.80 | ppl  6647.12
# | epoch  18 |   100/  201 batches | lr 0.00 | ms/batch 579.90 | loss  8.88 | ppl  7186.01
# | epoch  18 |   125/  201 batches | lr 0.00 | ms/batch 590.22 | loss  8.90 | ppl  7354.20
# | epoch  18 |   150/  201 batches | lr 0.00 | ms/batch 598.21 | loss  8.69 | ppl  5939.29
# | epoch  18 |   175/  201 batches | lr 0.00 | ms/batch 596.83 | loss  9.06 | ppl  8587.55
# | epoch  18 |   200/  201 batches | lr 0.00 | ms/batch 594.35 | loss  9.13 | ppl  9214.44
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 119.87s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  201 batches | lr 0.00 | ms/batch 587.58 | loss  9.45 | ppl 12705.94
# | epoch  19 |    50/  201 batches | lr 0.00 | ms/batch 583.06 | loss  8.71 | ppl  6047.03
# | epoch  19 |    75/  201 batches | lr 0.00 | ms/batch 589.70 | loss  8.77 | ppl  6429.58
# | epoch  19 |   100/  201 batches | lr 0.00 | ms/batch 588.98 | loss  8.99 | ppl  8012.76
# | epoch  19 |   125/  201 batches | lr 0.00 | ms/batch 606.91 | loss  9.03 | ppl  8351.96
# | epoch  19 |   150/  201 batches | lr 0.00 | ms/batch 600.30 | loss  8.74 | ppl  6270.46
# | epoch  19 |   175/  201 batches | lr 0.00 | ms/batch 613.65 | loss  8.85 | ppl  6972.58
# | epoch  19 |   200/  201 batches | lr 0.00 | ms/batch 580.00 | loss  9.23 | ppl 10224.06
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 120.60s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  201 batches | lr 0.00 | ms/batch 574.52 | loss  9.88 | ppl 19502.32
# | epoch  20 |    50/  201 batches | lr 0.00 | ms/batch 591.04 | loss  8.95 | ppl  7728.69
# | epoch  20 |    75/  201 batches | lr 0.00 | ms/batch 586.61 | loss  9.21 | ppl  9982.00
# | epoch  20 |   100/  201 batches | lr 0.00 | ms/batch 565.18 | loss  9.05 | ppl  8539.11
# | epoch  20 |   125/  201 batches | lr 0.00 | ms/batch 602.09 | loss  9.25 | ppl 10368.69
# | epoch  20 |   150/  201 batches | lr 0.00 | ms/batch 568.87 | loss  9.10 | ppl  8967.90
# | epoch  20 |   175/  201 batches | lr 0.00 | ms/batch 596.67 | loss  9.43 | ppl 12475.40
# | epoch  20 |   200/  201 batches | lr 0.00 | ms/batch 603.27 | loss  9.77 | ppl 17475.84
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 119.26s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  201 batches | lr 0.00 | ms/batch 613.92 | loss  9.27 | ppl 10623.02
# | epoch  21 |    50/  201 batches | lr 0.00 | ms/batch 568.14 | loss  8.63 | ppl  5608.24
# | epoch  21 |    75/  201 batches | lr 0.00 | ms/batch 580.90 | loss  8.77 | ppl  6459.78
# | epoch  21 |   100/  201 batches | lr 0.00 | ms/batch 573.66 | loss  8.98 | ppl  7955.61
# | epoch  21 |   125/  201 batches | lr 0.00 | ms/batch 596.48 | loss  8.89 | ppl  7234.02
# | epoch  21 |   150/  201 batches | lr 0.00 | ms/batch 592.92 | loss  8.83 | ppl  6816.46
# | epoch  21 |   175/  201 batches | lr 0.00 | ms/batch 613.75 | loss  8.88 | ppl  7187.43
# | epoch  21 |   200/  201 batches | lr 0.00 | ms/batch 586.47 | loss  9.17 | ppl  9569.81
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 120.04s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  201 batches | lr 0.00 | ms/batch 622.63 | loss  9.48 | ppl 13109.72
# | epoch  22 |    50/  201 batches | lr 0.00 | ms/batch 560.70 | loss  8.74 | ppl  6229.70
# | epoch  22 |    75/  201 batches | lr 0.00 | ms/batch 592.43 | loss  8.71 | ppl  6089.26
# | epoch  22 |   100/  201 batches | lr 0.00 | ms/batch 596.32 | loss  9.16 | ppl  9544.85
# | epoch  22 |   125/  201 batches | lr 0.00 | ms/batch 594.67 | loss  8.93 | ppl  7534.62
# | epoch  22 |   150/  201 batches | lr 0.00 | ms/batch 597.00 | loss  8.79 | ppl  6587.56
# | epoch  22 |   175/  201 batches | lr 0.00 | ms/batch 559.65 | loss  9.05 | ppl  8487.29
# | epoch  22 |   200/  201 batches | lr 0.00 | ms/batch 596.34 | loss  9.22 | ppl 10057.91
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 119.92s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  201 batches | lr 0.00 | ms/batch 594.19 | loss  9.71 | ppl 16406.66
# | epoch  23 |    50/  201 batches | lr 0.00 | ms/batch 575.42 | loss  8.93 | ppl  7533.18
# | epoch  23 |    75/  201 batches | lr 0.00 | ms/batch 564.43 | loss  9.10 | ppl  8943.86
# | epoch  23 |   100/  201 batches | lr 0.00 | ms/batch 584.97 | loss  9.28 | ppl 10684.94
# | epoch  23 |   125/  201 batches | lr 0.00 | ms/batch 571.57 | loss  9.19 | ppl  9783.45
# | epoch  23 |   150/  201 batches | lr 0.00 | ms/batch 588.58 | loss  8.87 | ppl  7142.36
# | epoch  23 |   175/  201 batches | lr 0.00 | ms/batch 613.61 | loss  9.33 | ppl 11268.79
# | epoch  23 |   200/  201 batches | lr 0.00 | ms/batch 562.49 | loss  9.66 | ppl 15643.06
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 118.28s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  201 batches | lr 0.00 | ms/batch 571.15 | loss  9.75 | ppl 17227.99
# | epoch  24 |    50/  201 batches | lr 0.00 | ms/batch 566.13 | loss  8.99 | ppl  8030.34
# | epoch  24 |    75/  201 batches | lr 0.00 | ms/batch 573.52 | loss  8.96 | ppl  7796.73
# | epoch  24 |   100/  201 batches | lr 0.00 | ms/batch 594.71 | loss  9.47 | ppl 12902.80
# | epoch  24 |   125/  201 batches | lr 0.00 | ms/batch 580.95 | loss  9.40 | ppl 12134.44
# | epoch  24 |   150/  201 batches | lr 0.00 | ms/batch 583.73 | loss  9.07 | ppl  8656.16
# | epoch  24 |   175/  201 batches | lr 0.00 | ms/batch 593.07 | loss  9.27 | ppl 10615.06
# | epoch  24 |   200/  201 batches | lr 0.00 | ms/batch 592.73 | loss  9.55 | ppl 14067.74
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 118.71s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  201 batches | lr 0.00 | ms/batch 601.19 | loss  9.61 | ppl 14933.00
# | epoch  25 |    50/  201 batches | lr 0.00 | ms/batch 601.84 | loss  8.76 | ppl  6352.50
# | epoch  25 |    75/  201 batches | lr 0.00 | ms/batch 593.50 | loss  9.03 | ppl  8348.93
# | epoch  25 |   100/  201 batches | lr 0.00 | ms/batch 588.16 | loss  9.14 | ppl  9318.94
# | epoch  25 |   125/  201 batches | lr 0.00 | ms/batch 615.52 | loss  8.90 | ppl  7313.15
# | epoch  25 |   150/  201 batches | lr 0.00 | ms/batch 589.17 | loss  8.73 | ppl  6184.59
# | epoch  25 |   175/  201 batches | lr 0.00 | ms/batch 565.15 | loss  9.04 | ppl  8475.99
# | epoch  25 |   200/  201 batches | lr 0.00 | ms/batch 607.36 | loss  9.49 | ppl 13184.85
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 121.01s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  201 batches | lr 0.00 | ms/batch 589.70 | loss  9.82 | ppl 18431.37
# | epoch  26 |    50/  201 batches | lr 0.00 | ms/batch 573.34 | loss  8.87 | ppl  7108.19
# | epoch  26 |    75/  201 batches | lr 0.00 | ms/batch 587.51 | loss  8.95 | ppl  7672.32
# | epoch  26 |   100/  201 batches | lr 0.00 | ms/batch 571.71 | loss  8.99 | ppl  8058.26
# | epoch  26 |   125/  201 batches | lr 0.00 | ms/batch 582.79 | loss  9.17 | ppl  9570.28
# | epoch  26 |   150/  201 batches | lr 0.00 | ms/batch 602.25 | loss  8.77 | ppl  6467.88
# | epoch  26 |   175/  201 batches | lr 0.00 | ms/batch 588.95 | loss  8.99 | ppl  8026.30
# | epoch  26 |   200/  201 batches | lr 0.00 | ms/batch 562.57 | loss  9.40 | ppl 12083.79
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 118.34s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  201 batches | lr 0.00 | ms/batch 594.11 | loss  9.70 | ppl 16239.89
# | epoch  27 |    50/  201 batches | lr 0.00 | ms/batch 571.62 | loss  8.95 | ppl  7672.44
# | epoch  27 |    75/  201 batches | lr 0.00 | ms/batch 568.93 | loss  9.04 | ppl  8411.22
# | epoch  27 |   100/  201 batches | lr 0.00 | ms/batch 590.46 | loss  9.23 | ppl 10194.04
# | epoch  27 |   125/  201 batches | lr 0.00 | ms/batch 604.18 | loss  9.12 | ppl  9137.61
# | epoch  27 |   150/  201 batches | lr 0.00 | ms/batch 601.49 | loss  8.93 | ppl  7583.31
# | epoch  27 |   175/  201 batches | lr 0.00 | ms/batch 584.44 | loss  9.00 | ppl  8101.82
# | epoch  27 |   200/  201 batches | lr 0.00 | ms/batch 585.74 | loss  9.22 | ppl 10105.27
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 119.35s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  201 batches | lr 0.00 | ms/batch 595.00 | loss  9.27 | ppl 10624.25
# | epoch  28 |    50/  201 batches | lr 0.00 | ms/batch 587.71 | loss  8.77 | ppl  6459.78
# | epoch  28 |    75/  201 batches | lr 0.00 | ms/batch 574.47 | loss  8.67 | ppl  5821.49
# | epoch  28 |   100/  201 batches | lr 0.00 | ms/batch 590.87 | loss  9.06 | ppl  8637.67
# | epoch  28 |   125/  201 batches | lr 0.00 | ms/batch 575.03 | loss  9.07 | ppl  8676.96
# | epoch  28 |   150/  201 batches | lr 0.00 | ms/batch 599.15 | loss  8.60 | ppl  5438.92
# | epoch  28 |   175/  201 batches | lr 0.00 | ms/batch 592.17 | loss  8.96 | ppl  7783.87
# | epoch  28 |   200/  201 batches | lr 0.00 | ms/batch 577.20 | loss  9.35 | ppl 11517.35
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 119.19s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/  201 batches | lr 0.00 | ms/batch 572.78 | loss  9.57 | ppl 14377.64
# | epoch  29 |    50/  201 batches | lr 0.00 | ms/batch 568.89 | loss  8.85 | ppl  7005.52
# | epoch  29 |    75/  201 batches | lr 0.00 | ms/batch 585.39 | loss  9.02 | ppl  8254.45
# | epoch  29 |   100/  201 batches | lr 0.00 | ms/batch 594.17 | loss  9.22 | ppl 10127.01
# | epoch  29 |   125/  201 batches | lr 0.00 | ms/batch 583.67 | loss  9.22 | ppl 10126.52
# | epoch  29 |   150/  201 batches | lr 0.00 | ms/batch 595.26 | loss  8.98 | ppl  7933.32
# | epoch  29 |   175/  201 batches | lr 0.00 | ms/batch 591.25 | loss  9.09 | ppl  8841.07
# | epoch  29 |   200/  201 batches | lr 0.00 | ms/batch 612.12 | loss  9.50 | ppl 13335.94
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 119.92s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/  201 batches | lr 0.00 | ms/batch 589.01 | loss  9.59 | ppl 14614.34
# | epoch  30 |    50/  201 batches | lr 0.00 | ms/batch 556.75 | loss  8.81 | ppl  6694.03
# | epoch  30 |    75/  201 batches | lr 0.00 | ms/batch 575.64 | loss  8.92 | ppl  7456.11
# | epoch  30 |   100/  201 batches | lr 0.00 | ms/batch 573.66 | loss  8.92 | ppl  7513.32
# | epoch  30 |   125/  201 batches | lr 0.00 | ms/batch 582.81 | loss  8.93 | ppl  7528.03
# | epoch  30 |   150/  201 batches | lr 0.00 | ms/batch 584.29 | loss  8.94 | ppl  7614.01
# | epoch  30 |   175/  201 batches | lr 0.00 | ms/batch 572.45 | loss  8.95 | ppl  7706.80
# | epoch  30 |   200/  201 batches | lr 0.00 | ms/batch 592.19 | loss  9.40 | ppl 12140.48
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 117.49s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/  201 batches | lr 0.00 | ms/batch 589.66 | loss  9.64 | ppl 15291.85
# | epoch  31 |    50/  201 batches | lr 0.00 | ms/batch 569.62 | loss  8.59 | ppl  5391.11
# | epoch  31 |    75/  201 batches | lr 0.00 | ms/batch 574.67 | loss  8.80 | ppl  6660.70
# | epoch  31 |   100/  201 batches | lr 0.00 | ms/batch 566.76 | loss  9.09 | ppl  8870.78
# | epoch  31 |   125/  201 batches | lr 0.00 | ms/batch 587.08 | loss  8.86 | ppl  7079.48
# | epoch  31 |   150/  201 batches | lr 0.00 | ms/batch 577.97 | loss  8.66 | ppl  5752.24
# | epoch  31 |   175/  201 batches | lr 0.00 | ms/batch 593.39 | loss  8.68 | ppl  5867.19
# | epoch  31 |   200/  201 batches | lr 0.00 | ms/batch 577.07 | loss  9.16 | ppl  9506.54
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 118.30s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/  201 batches | lr 0.00 | ms/batch 571.92 | loss  9.54 | ppl 13859.90
# | epoch  32 |    50/  201 batches | lr 0.00 | ms/batch 598.80 | loss  8.90 | ppl  7352.38
# | epoch  32 |    75/  201 batches | lr 0.00 | ms/batch 580.87 | loss  8.87 | ppl  7088.30
# | epoch  32 |   100/  201 batches | lr 0.00 | ms/batch 572.09 | loss  9.14 | ppl  9325.53
# | epoch  32 |   125/  201 batches | lr 0.00 | ms/batch 607.17 | loss  8.97 | ppl  7884.16
# | epoch  32 |   150/  201 batches | lr 0.00 | ms/batch 570.44 | loss  8.70 | ppl  6021.56
# | epoch  32 |   175/  201 batches | lr 0.00 | ms/batch 604.85 | loss  8.95 | ppl  7703.72
# | epoch  32 |   200/  201 batches | lr 0.00 | ms/batch 580.59 | loss  9.42 | ppl 12370.11
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 119.49s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/  201 batches | lr 0.00 | ms/batch 574.88 | loss  9.71 | ppl 16477.83
# | epoch  33 |    50/  201 batches | lr 0.00 | ms/batch 587.38 | loss  8.93 | ppl  7520.26
# | epoch  33 |    75/  201 batches | lr 0.00 | ms/batch 548.28 | loss  8.90 | ppl  7317.31
# | epoch  33 |   100/  201 batches | lr 0.00 | ms/batch 557.93 | loss  9.21 | ppl  9997.93
# | epoch  33 |   125/  201 batches | lr 0.00 | ms/batch 587.36 | loss  8.97 | ppl  7900.02
# | epoch  33 |   150/  201 batches | lr 0.00 | ms/batch 577.26 | loss  8.73 | ppl  6195.43
# | epoch  33 |   175/  201 batches | lr 0.00 | ms/batch 565.30 | loss  9.00 | ppl  8076.97
# | epoch  33 |   200/  201 batches | lr 0.00 | ms/batch 597.45 | loss  9.46 | ppl 12801.64
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 116.86s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/  201 batches | lr 0.00 | ms/batch 585.71 | loss  9.48 | ppl 13032.07
# | epoch  34 |    50/  201 batches | lr 0.00 | ms/batch 547.59 | loss  8.71 | ppl  6044.78
# | epoch  34 |    75/  201 batches | lr 0.00 | ms/batch 578.92 | loss  8.98 | ppl  7961.73
# | epoch  34 |   100/  201 batches | lr 0.00 | ms/batch 577.68 | loss  9.09 | ppl  8876.68
# | epoch  34 |   125/  201 batches | lr 0.00 | ms/batch 582.64 | loss  9.29 | ppl 10869.33
# | epoch  34 |   150/  201 batches | lr 0.00 | ms/batch 586.51 | loss  8.93 | ppl  7530.59
# | epoch  34 |   175/  201 batches | lr 0.00 | ms/batch 608.85 | loss  8.99 | ppl  8057.10
# | epoch  34 |   200/  201 batches | lr 0.00 | ms/batch 588.88 | loss  9.42 | ppl 12347.08
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 118.47s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/  201 batches | lr 0.00 | ms/batch 583.94 | loss  9.80 | ppl 18061.98
# | epoch  35 |    50/  201 batches | lr 0.00 | ms/batch 580.82 | loss  9.10 | ppl  8928.66
# | epoch  35 |    75/  201 batches | lr 0.00 | ms/batch 562.13 | loss  9.09 | ppl  8877.18
# | epoch  35 |   100/  201 batches | lr 0.00 | ms/batch 590.60 | loss  9.42 | ppl 12327.46
# | epoch  35 |   125/  201 batches | lr 0.00 | ms/batch 594.74 | loss  9.34 | ppl 11369.14
# | epoch  35 |   150/  201 batches | lr 0.00 | ms/batch 573.97 | loss  8.95 | ppl  7739.56
# | epoch  35 |   175/  201 batches | lr 0.00 | ms/batch 585.64 | loss  9.19 | ppl  9764.49
# | epoch  35 |   200/  201 batches | lr 0.00 | ms/batch 621.75 | loss  9.41 | ppl 12155.92
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 119.44s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/  201 batches | lr 0.00 | ms/batch 580.86 | loss  9.54 | ppl 13954.27
# | epoch  36 |    50/  201 batches | lr 0.00 | ms/batch 611.67 | loss  8.75 | ppl  6320.99
# | epoch  36 |    75/  201 batches | lr 0.00 | ms/batch 601.88 | loss  9.01 | ppl  8196.64
# | epoch  36 |   100/  201 batches | lr 0.00 | ms/batch 600.64 | loss  9.21 | ppl  9960.09
# | epoch  36 |   125/  201 batches | lr 0.00 | ms/batch 595.05 | loss  9.24 | ppl 10331.58
# | epoch  36 |   150/  201 batches | lr 0.00 | ms/batch 559.88 | loss  8.89 | ppl  7262.71
# | epoch  36 |   175/  201 batches | lr 0.00 | ms/batch 573.31 | loss  9.00 | ppl  8106.98
# | epoch  36 |   200/  201 batches | lr 0.00 | ms/batch 589.27 | loss  9.32 | ppl 11132.89
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 119.79s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/  201 batches | lr 0.00 | ms/batch 589.05 | loss  9.40 | ppl 12073.28
# | epoch  37 |    50/  201 batches | lr 0.00 | ms/batch 601.81 | loss  8.66 | ppl  5784.45
# | epoch  37 |    75/  201 batches | lr 0.00 | ms/batch 598.21 | loss  8.65 | ppl  5697.08
# | epoch  37 |   100/  201 batches | lr 0.00 | ms/batch 574.96 | loss  8.82 | ppl  6788.85
# | epoch  37 |   125/  201 batches | lr 0.00 | ms/batch 608.79 | loss  8.89 | ppl  7224.04
# | epoch  37 |   150/  201 batches | lr 0.00 | ms/batch 578.79 | loss  8.56 | ppl  5194.21
# | epoch  37 |   175/  201 batches | lr 0.00 | ms/batch 569.87 | loss  9.00 | ppl  8128.41
# | epoch  37 |   200/  201 batches | lr 0.00 | ms/batch 563.53 | loss  9.19 | ppl  9813.36
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 119.11s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/  201 batches | lr 0.00 | ms/batch 575.99 | loss  9.54 | ppl 13937.87
# | epoch  38 |    50/  201 batches | lr 0.00 | ms/batch 541.75 | loss  8.84 | ppl  6884.26
# | epoch  38 |    75/  201 batches | lr 0.00 | ms/batch 588.39 | loss  8.81 | ppl  6703.11
# | epoch  38 |   100/  201 batches | lr 0.00 | ms/batch 572.34 | loss  9.01 | ppl  8215.07
# | epoch  38 |   125/  201 batches | lr 0.00 | ms/batch 575.42 | loss  8.96 | ppl  7781.52
# | epoch  38 |   150/  201 batches | lr 0.00 | ms/batch 576.27 | loss  8.62 | ppl  5547.53
# | epoch  38 |   175/  201 batches | lr 0.00 | ms/batch 569.82 | loss  8.95 | ppl  7692.93
# | epoch  38 |   200/  201 batches | lr 0.00 | ms/batch 580.82 | loss  9.14 | ppl  9323.55
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 116.46s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/  201 batches | lr 0.00 | ms/batch 599.17 | loss  9.56 | ppl 14201.52
# | epoch  39 |    50/  201 batches | lr 0.00 | ms/batch 586.91 | loss  9.05 | ppl  8477.15
# | epoch  39 |    75/  201 batches | lr 0.00 | ms/batch 598.15 | loss  8.89 | ppl  7237.59
# | epoch  39 |   100/  201 batches | lr 0.00 | ms/batch 576.11 | loss  9.14 | ppl  9357.49
# | epoch  39 |   125/  201 batches | lr 0.00 | ms/batch 581.94 | loss  9.03 | ppl  8378.47
# | epoch  39 |   150/  201 batches | lr 0.00 | ms/batch 598.62 | loss  8.49 | ppl  4885.95
# | epoch  39 |   175/  201 batches | lr 0.00 | ms/batch 588.49 | loss  8.85 | ppl  7005.66
# | epoch  39 |   200/  201 batches | lr 0.00 | ms/batch 595.31 | loss  9.30 | ppl 10919.26
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 120.03s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/  201 batches | lr 0.00 | ms/batch 553.62 | loss  9.62 | ppl 15034.46
# | epoch  40 |    50/  201 batches | lr 0.00 | ms/batch 564.63 | loss  8.77 | ppl  6466.11
# | epoch  40 |    75/  201 batches | lr 0.00 | ms/batch 542.97 | loss  9.01 | ppl  8157.57
# | epoch  40 |   100/  201 batches | lr 0.00 | ms/batch 568.78 | loss  8.96 | ppl  7804.20
# | epoch  40 |   125/  201 batches | lr 0.00 | ms/batch 594.12 | loss  8.91 | ppl  7368.81
# | epoch  40 |   150/  201 batches | lr 0.00 | ms/batch 595.55 | loss  8.67 | ppl  5824.94
# | epoch  40 |   175/  201 batches | lr 0.00 | ms/batch 619.22 | loss  8.84 | ppl  6912.97
# | epoch  40 |   200/  201 batches | lr 0.00 | ms/batch 605.94 | loss  9.36 | ppl 11611.68
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 118.01s | valid loss  7.12 | valid ppl  1239.43
# -----------------------------------------------------------------------------------------

# %%
micmac_tanh = make_model(mic_corpus, "RNN_TANH", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

# %%
train(micmac_tanh, mic_corpus, 20, 40, 'data/micmac')
# Out:
# | epoch   1 |    25/  201 batches | lr 20.00 | ms/batch 736.38 | loss 111.85 | ppl 3749259989727947814465805423753716685849373966336.00
# | epoch   1 |    50/  201 batches | lr 20.00 | ms/batch 379.20 | loss 109.49 | ppl 355308240430623094834143746127675079124047626240.00
# | epoch   1 |    75/  201 batches | lr 20.00 | ms/batch 354.28 | loss 97.58 | ppl 2391027848102916344237111316278949342871552.00
# | epoch   1 |   100/  201 batches | lr 20.00 | ms/batch 337.72 | loss 79.97 | ppl 53966953842370299752225249591033856.00
# | epoch   1 |   125/  201 batches | lr 20.00 | ms/batch 308.39 | loss 68.88 | ppl 819209373263647827058472517632.00
# | epoch   1 |   150/  201 batches | lr 20.00 | ms/batch 311.85 | loss 77.50 | ppl 4540143106259459597248125074407424.00
# | epoch   1 |   175/  201 batches | lr 20.00 | ms/batch 330.11 | loss 70.23 | ppl 3174866259668741762463911903232.00
# | epoch   1 |   200/  201 batches | lr 20.00 | ms/batch 299.50 | loss 70.67 | ppl 4934853283224804067800508268544.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 77.93s | valid loss 49.25 | valid ppl 2450356922203564408832.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  201 batches | lr 20.00 | ms/batch 333.14 | loss 61.99 | ppl 831626174697775007912689664.00
# | epoch   2 |    50/  201 batches | lr 20.00 | ms/batch 345.43 | loss 73.25 | ppl 65086689623729502377175146299392.00
# | epoch   2 |    75/  201 batches | lr 20.00 | ms/batch 332.53 | loss 71.30 | ppl 9232354299879672938508599689216.00
# | epoch   2 |   100/  201 batches | lr 20.00 | ms/batch 367.16 | loss 73.23 | ppl 63651478413943117758553934266368.00
# | epoch   2 |   125/  201 batches | lr 20.00 | ms/batch 325.67 | loss 71.85 | ppl 16020876856690009114527827755008.00
# | epoch   2 |   150/  201 batches | lr 20.00 | ms/batch 308.56 | loss 62.88 | ppl 2026105079383378035933708288.00
# | epoch   2 |   175/  201 batches | lr 20.00 | ms/batch 330.47 | loss 65.62 | ppl 31389144048559161644731596800.00
# | epoch   2 |   200/  201 batches | lr 20.00 | ms/batch 306.68 | loss 60.41 | ppl 171579418080051145037840384.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 67.63s | valid loss 55.32 | valid ppl 1061537085306290428706816.00
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  201 batches | lr 5.00 | ms/batch 313.53 | loss 35.90 | ppl 3908569262496868.00
# | epoch   3 |    50/  201 batches | lr 5.00 | ms/batch 322.47 | loss 23.87 | ppl 23285817141.00
# | epoch   3 |    75/  201 batches | lr 5.00 | ms/batch 307.92 | loss 22.18 | ppl 4300945320.63
# | epoch   3 |   100/  201 batches | lr 5.00 | ms/batch 308.65 | loss 21.75 | ppl 2803285824.77
# | epoch   3 |   125/  201 batches | lr 5.00 | ms/batch 300.87 | loss 21.24 | ppl 1682875347.64
# | epoch   3 |   150/  201 batches | lr 5.00 | ms/batch 315.45 | loss 20.93 | ppl 1228063594.66
# | epoch   3 |   175/  201 batches | lr 5.00 | ms/batch 331.94 | loss 20.89 | ppl 1180250496.96
# | epoch   3 |   200/  201 batches | lr 5.00 | ms/batch 310.05 | loss 19.92 | ppl 448098761.43
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 64.18s | valid loss 17.20 | valid ppl 29510729.15
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  201 batches | lr 5.00 | ms/batch 311.69 | loss 21.26 | ppl 1705270252.38
# | epoch   4 |    50/  201 batches | lr 5.00 | ms/batch 324.62 | loss 19.97 | ppl 472886012.57
# | epoch   4 |    75/  201 batches | lr 5.00 | ms/batch 330.18 | loss 19.62 | ppl 333009699.34
# | epoch   4 |   100/  201 batches | lr 5.00 | ms/batch 323.85 | loss 20.06 | ppl 514657831.34
# | epoch   4 |   125/  201 batches | lr 5.00 | ms/batch 327.86 | loss 20.01 | ppl 491873059.34
# | epoch   4 |   150/  201 batches | lr 5.00 | ms/batch 329.08 | loss 20.58 | ppl 869820557.84
# | epoch   4 |   175/  201 batches | lr 5.00 | ms/batch 325.60 | loss 20.24 | ppl 616687029.50
# | epoch   4 |   200/  201 batches | lr 5.00 | ms/batch 317.52 | loss 18.92 | ppl 165188922.99
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 66.39s | valid loss 20.42 | valid ppl 740660783.99
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  201 batches | lr 1.25 | ms/batch 318.23 | loss 20.62 | ppl 899082380.00
# | epoch   5 |    50/  201 batches | lr 1.25 | ms/batch 331.59 | loss 15.90 | ppl 8035971.95
# | epoch   5 |    75/  201 batches | lr 1.25 | ms/batch 319.36 | loss 14.83 | ppl 2749865.53
# | epoch   5 |   100/  201 batches | lr 1.25 | ms/batch 329.87 | loss 15.01 | ppl 3313470.79
# | epoch   5 |   125/  201 batches | lr 1.25 | ms/batch 326.80 | loss 14.33 | ppl 1676899.20
# | epoch   5 |   150/  201 batches | lr 1.25 | ms/batch 330.71 | loss 14.50 | ppl 1982536.22
# | epoch   5 |   175/  201 batches | lr 1.25 | ms/batch 340.64 | loss 14.85 | ppl 2812125.34
# | epoch   5 |   200/  201 batches | lr 1.25 | ms/batch 327.33 | loss 14.97 | ppl 3183159.76
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 67.12s | valid loss 11.86 | valid ppl 141900.09
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  201 batches | lr 1.25 | ms/batch 315.07 | loss 15.80 | ppl 7271259.76
# | epoch   6 |    50/  201 batches | lr 1.25 | ms/batch 312.82 | loss 14.72 | ppl 2481725.79
# | epoch   6 |    75/  201 batches | lr 1.25 | ms/batch 334.74 | loss 14.10 | ppl 1329092.00
# | epoch   6 |   100/  201 batches | lr 1.25 | ms/batch 320.03 | loss 14.20 | ppl 1472729.53
# | epoch   6 |   125/  201 batches | lr 1.25 | ms/batch 327.27 | loss 13.63 | ppl 833603.66
# | epoch   6 |   150/  201 batches | lr 1.25 | ms/batch 328.87 | loss 14.15 | ppl 1402254.48
# | epoch   6 |   175/  201 batches | lr 1.25 | ms/batch 330.65 | loss 14.40 | ppl 1794066.42
# | epoch   6 |   200/  201 batches | lr 1.25 | ms/batch 300.09 | loss 14.34 | ppl 1695267.17
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 65.66s | valid loss 11.34 | valid ppl 84515.61
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  201 batches | lr 1.25 | ms/batch 321.01 | loss 15.42 | ppl 4987692.90
# | epoch   7 |    50/  201 batches | lr 1.25 | ms/batch 335.02 | loss 14.31 | ppl 1644102.74
# | epoch   7 |    75/  201 batches | lr 1.25 | ms/batch 320.42 | loss 13.73 | ppl 915513.38
# | epoch   7 |   100/  201 batches | lr 1.25 | ms/batch 337.51 | loss 13.81 | ppl 990939.96
# | epoch   7 |   125/  201 batches | lr 1.25 | ms/batch 341.25 | loss 13.30 | ppl 599167.39
# | epoch   7 |   150/  201 batches | lr 1.25 | ms/batch 318.69 | loss 13.67 | ppl 861005.34
# | epoch   7 |   175/  201 batches | lr 1.25 | ms/batch 329.57 | loss 13.85 | ppl 1034984.61
# | epoch   7 |   200/  201 batches | lr 1.25 | ms/batch 317.89 | loss 14.06 | ppl 1278727.94
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 66.90s | valid loss 11.20 | valid ppl 73395.89
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  201 batches | lr 1.25 | ms/batch 332.03 | loss 15.03 | ppl 3361180.63
# | epoch   8 |    50/  201 batches | lr 1.25 | ms/batch 334.46 | loss 13.75 | ppl 940686.35
# | epoch   8 |    75/  201 batches | lr 1.25 | ms/batch 321.50 | loss 13.31 | ppl 601871.10
# | epoch   8 |   100/  201 batches | lr 1.25 | ms/batch 316.93 | loss 13.34 | ppl 621421.68
# | epoch   8 |   125/  201 batches | lr 1.25 | ms/batch 314.76 | loss 12.77 | ppl 352452.51
# | epoch   8 |   150/  201 batches | lr 1.25 | ms/batch 337.96 | loss 13.14 | ppl 508325.42
# | epoch   8 |   175/  201 batches | lr 1.25 | ms/batch 312.75 | loss 13.31 | ppl 600650.29
# | epoch   8 |   200/  201 batches | lr 1.25 | ms/batch 327.08 | loss 13.72 | ppl 909420.08
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 66.31s | valid loss 10.83 | valid ppl 50755.09
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  201 batches | lr 1.25 | ms/batch 316.11 | loss 14.66 | ppl 2331313.96
# | epoch   9 |    50/  201 batches | lr 1.25 | ms/batch 307.41 | loss 13.59 | ppl 798131.19
# | epoch   9 |    75/  201 batches | lr 1.25 | ms/batch 302.84 | loss 12.86 | ppl 382751.86
# | epoch   9 |   100/  201 batches | lr 1.25 | ms/batch 320.67 | loss 13.05 | ppl 467409.96
# | epoch   9 |   125/  201 batches | lr 1.25 | ms/batch 317.57 | loss 12.58 | ppl 290340.95
# | epoch   9 |   150/  201 batches | lr 1.25 | ms/batch 303.96 | loss 12.90 | ppl 401445.08
# | epoch   9 |   175/  201 batches | lr 1.25 | ms/batch 334.08 | loss 13.13 | ppl 505230.15
# | epoch   9 |   200/  201 batches | lr 1.25 | ms/batch 310.57 | loss 13.34 | ppl 620264.92
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 64.22s | valid loss 10.54 | valid ppl 37764.96
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  201 batches | lr 1.25 | ms/batch 324.97 | loss 14.18 | ppl 1436980.81
# | epoch  10 |    50/  201 batches | lr 1.25 | ms/batch 310.84 | loss 13.11 | ppl 492176.52
# | epoch  10 |    75/  201 batches | lr 1.25 | ms/batch 307.92 | loss 12.45 | ppl 255897.59
# | epoch  10 |   100/  201 batches | lr 1.25 | ms/batch 335.06 | loss 12.67 | ppl 319214.69
# | epoch  10 |   125/  201 batches | lr 1.25 | ms/batch 312.59 | loss 12.21 | ppl 200793.17
# | epoch  10 |   150/  201 batches | lr 1.25 | ms/batch 319.37 | loss 12.49 | ppl 265483.43
# | epoch  10 |   175/  201 batches | lr 1.25 | ms/batch 316.25 | loss 12.46 | ppl 258479.36
# | epoch  10 |   200/  201 batches | lr 1.25 | ms/batch 317.73 | loss 12.89 | ppl 396525.41
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 65.13s | valid loss 10.25 | valid ppl 28253.78
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  201 batches | lr 1.25 | ms/batch 342.45 | loss 13.68 | ppl 874604.93
# | epoch  11 |    50/  201 batches | lr 1.25 | ms/batch 328.11 | loss 12.87 | ppl 389222.44
# | epoch  11 |    75/  201 batches | lr 1.25 | ms/batch 319.59 | loss 11.89 | ppl 145287.18
# | epoch  11 |   100/  201 batches | lr 1.25 | ms/batch 332.67 | loss 12.29 | ppl 217246.91
# | epoch  11 |   125/  201 batches | lr 1.25 | ms/batch 325.14 | loss 11.86 | ppl 141055.24
# | epoch  11 |   150/  201 batches | lr 1.25 | ms/batch 331.26 | loss 12.02 | ppl 165344.98
# | epoch  11 |   175/  201 batches | lr 1.25 | ms/batch 333.70 | loss 12.25 | ppl 208057.94
# | epoch  11 |   200/  201 batches | lr 1.25 | ms/batch 318.30 | loss 12.62 | ppl 303793.20
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 67.50s | valid loss  9.96 | valid ppl 21179.73
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  201 batches | lr 1.25 | ms/batch 334.29 | loss 13.35 | ppl 629408.84
# | epoch  12 |    50/  201 batches | lr 1.25 | ms/batch 327.26 | loss 12.36 | ppl 232165.23
# | epoch  12 |    75/  201 batches | lr 1.25 | ms/batch 328.18 | loss 11.73 | ppl 124448.78
# | epoch  12 |   100/  201 batches | lr 1.25 | ms/batch 326.77 | loss 11.75 | ppl 126990.33
# | epoch  12 |   125/  201 batches | lr 1.25 | ms/batch 327.52 | loss 11.41 | ppl 90336.09
# | epoch  12 |   150/  201 batches | lr 1.25 | ms/batch 347.00 | loss 11.67 | ppl 117415.94
# | epoch  12 |   175/  201 batches | lr 1.25 | ms/batch 324.59 | loss 11.77 | ppl 129300.04
# | epoch  12 |   200/  201 batches | lr 1.25 | ms/batch 333.18 | loss 12.18 | ppl 195081.47
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 67.76s | valid loss 10.07 | valid ppl 23565.33
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  201 batches | lr 0.31 | ms/batch 362.02 | loss 12.85 | ppl 381199.33
# | epoch  13 |    50/  201 batches | lr 0.31 | ms/batch 326.26 | loss 11.67 | ppl 116552.16
# | epoch  13 |    75/  201 batches | lr 0.31 | ms/batch 345.80 | loss 10.91 | ppl 54682.20
# | epoch  13 |   100/  201 batches | lr 0.31 | ms/batch 340.41 | loss 11.17 | ppl 71063.61
# | epoch  13 |   125/  201 batches | lr 0.31 | ms/batch 315.72 | loss 10.65 | ppl 42236.31
# | epoch  13 |   150/  201 batches | lr 0.31 | ms/batch 340.25 | loss 11.03 | ppl 61504.40
# | epoch  13 |   175/  201 batches | lr 0.31 | ms/batch 364.10 | loss 11.13 | ppl 68502.41
# | epoch  13 |   200/  201 batches | lr 0.31 | ms/batch 337.04 | loss 11.62 | ppl 111141.64
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 69.74s | valid loss  9.63 | valid ppl 15193.86
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  201 batches | lr 0.31 | ms/batch 337.99 | loss 12.68 | ppl 321617.91
# | epoch  14 |    50/  201 batches | lr 0.31 | ms/batch 339.03 | loss 11.52 | ppl 100343.77
# | epoch  14 |    75/  201 batches | lr 0.31 | ms/batch 340.34 | loss 10.75 | ppl 46710.12
# | epoch  14 |   100/  201 batches | lr 0.31 | ms/batch 330.96 | loss 11.01 | ppl 60652.89
# | epoch  14 |   125/  201 batches | lr 0.31 | ms/batch 340.24 | loss 10.54 | ppl 37776.09
# | epoch  14 |   150/  201 batches | lr 0.31 | ms/batch 329.44 | loss 10.93 | ppl 55776.45
# | epoch  14 |   175/  201 batches | lr 0.31 | ms/batch 324.20 | loss 11.01 | ppl 60735.50
# | epoch  14 |   200/  201 batches | lr 0.31 | ms/batch 344.11 | loss 11.42 | ppl 91365.04
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 68.53s | valid loss  9.61 | valid ppl 14874.77
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  201 batches | lr 0.31 | ms/batch 341.84 | loss 12.52 | ppl 274854.81
# | epoch  15 |    50/  201 batches | lr 0.31 | ms/batch 341.69 | loss 11.44 | ppl 92601.93
# | epoch  15 |    75/  201 batches | lr 0.31 | ms/batch 324.13 | loss 10.83 | ppl 50590.26
# | epoch  15 |   100/  201 batches | lr 0.31 | ms/batch 338.69 | loss 11.00 | ppl 59670.65
# | epoch  15 |   125/  201 batches | lr 0.31 | ms/batch 336.13 | loss 10.51 | ppl 36669.77
# | epoch  15 |   150/  201 batches | lr 0.31 | ms/batch 320.60 | loss 10.80 | ppl 48814.26
# | epoch  15 |   175/  201 batches | lr 0.31 | ms/batch 333.41 | loss 10.98 | ppl 58765.42
# | epoch  15 |   200/  201 batches | lr 0.31 | ms/batch 343.67 | loss 11.36 | ppl 86079.16
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 68.44s | valid loss  9.55 | valid ppl 14018.03
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  201 batches | lr 0.31 | ms/batch 348.84 | loss 12.67 | ppl 319415.06
# | epoch  16 |    50/  201 batches | lr 0.31 | ms/batch 332.38 | loss 11.35 | ppl 85188.81
# | epoch  16 |    75/  201 batches | lr 0.31 | ms/batch 333.52 | loss 10.69 | ppl 43861.73
# | epoch  16 |   100/  201 batches | lr 0.31 | ms/batch 329.23 | loss 10.92 | ppl 55497.63
# | epoch  16 |   125/  201 batches | lr 0.31 | ms/batch 351.89 | loss 10.57 | ppl 39090.01
# | epoch  16 |   150/  201 batches | lr 0.31 | ms/batch 325.05 | loss 10.83 | ppl 50755.53
# | epoch  16 |   175/  201 batches | lr 0.31 | ms/batch 320.44 | loss 11.06 | ppl 63757.43
# | epoch  16 |   200/  201 batches | lr 0.31 | ms/batch 331.11 | loss 11.33 | ppl 83145.36
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 68.19s | valid loss  9.54 | valid ppl 13954.29
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  201 batches | lr 0.31 | ms/batch 352.33 | loss 12.50 | ppl 268810.17
# | epoch  17 |    50/  201 batches | lr 0.31 | ms/batch 331.06 | loss 11.34 | ppl 84043.97
# | epoch  17 |    75/  201 batches | lr 0.31 | ms/batch 328.15 | loss 10.58 | ppl 39469.01
# | epoch  17 |   100/  201 batches | lr 0.31 | ms/batch 325.85 | loss 10.97 | ppl 58173.86
# | epoch  17 |   125/  201 batches | lr 0.31 | ms/batch 331.69 | loss 10.45 | ppl 34524.69
# | epoch  17 |   150/  201 batches | lr 0.31 | ms/batch 336.65 | loss 10.75 | ppl 46832.18
# | epoch  17 |   175/  201 batches | lr 0.31 | ms/batch 342.27 | loss 10.87 | ppl 52612.12
# | epoch  17 |   200/  201 batches | lr 0.31 | ms/batch 336.96 | loss 11.27 | ppl 78774.33
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 68.57s | valid loss  9.51 | valid ppl 13477.13
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  201 batches | lr 0.31 | ms/batch 350.82 | loss 12.30 | ppl 220031.88
# | epoch  18 |    50/  201 batches | lr 0.31 | ms/batch 315.47 | loss 11.39 | ppl 88038.95
# | epoch  18 |    75/  201 batches | lr 0.31 | ms/batch 353.35 | loss 10.58 | ppl 39265.73
# | epoch  18 |   100/  201 batches | lr 0.31 | ms/batch 340.43 | loss 10.84 | ppl 51234.64
# | epoch  18 |   125/  201 batches | lr 0.31 | ms/batch 345.23 | loss 10.39 | ppl 32661.03
# | epoch  18 |   150/  201 batches | lr 0.31 | ms/batch 334.57 | loss 10.71 | ppl 45011.79
# | epoch  18 |   175/  201 batches | lr 0.31 | ms/batch 333.19 | loss 10.88 | ppl 53245.90
# | epoch  18 |   200/  201 batches | lr 0.31 | ms/batch 345.84 | loss 11.31 | ppl 81624.97
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 69.41s | valid loss  9.46 | valid ppl 12879.01
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  201 batches | lr 0.31 | ms/batch 341.84 | loss 12.25 | ppl 208964.42
# | epoch  19 |    50/  201 batches | lr 0.31 | ms/batch 344.28 | loss 11.27 | ppl 78796.15
# | epoch  19 |    75/  201 batches | lr 0.31 | ms/batch 344.56 | loss 10.45 | ppl 34414.76
# | epoch  19 |   100/  201 batches | lr 0.31 | ms/batch 348.36 | loss 10.84 | ppl 51056.28
# | epoch  19 |   125/  201 batches | lr 0.31 | ms/batch 343.89 | loss 10.47 | ppl 35203.62
# | epoch  19 |   150/  201 batches | lr 0.31 | ms/batch 362.56 | loss 10.71 | ppl 44597.88
# | epoch  19 |   175/  201 batches | lr 0.31 | ms/batch 367.36 | loss 10.86 | ppl 52209.58
# | epoch  19 |   200/  201 batches | lr 0.31 | ms/batch 329.72 | loss 11.24 | ppl 76006.24
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 71.13s | valid loss  9.44 | valid ppl 12594.23
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  201 batches | lr 0.31 | ms/batch 362.80 | loss 12.21 | ppl 200832.00
# | epoch  20 |    50/  201 batches | lr 0.31 | ms/batch 360.15 | loss 11.20 | ppl 73357.41
# | epoch  20 |    75/  201 batches | lr 0.31 | ms/batch 373.48 | loss 10.50 | ppl 36290.74
# | epoch  20 |   100/  201 batches | lr 0.31 | ms/batch 354.83 | loss 10.70 | ppl 44250.75
# | epoch  20 |   125/  201 batches | lr 0.31 | ms/batch 341.40 | loss 10.29 | ppl 29389.89
# | epoch  20 |   150/  201 batches | lr 0.31 | ms/batch 334.38 | loss 10.60 | ppl 40126.31
# | epoch  20 |   175/  201 batches | lr 0.31 | ms/batch 337.18 | loss 10.83 | ppl 50728.43
# | epoch  20 |   200/  201 batches | lr 0.31 | ms/batch 330.22 | loss 11.27 | ppl 78438.40
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 71.26s | valid loss  9.40 | valid ppl 12066.05
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  201 batches | lr 0.31 | ms/batch 330.23 | loss 12.20 | ppl 199381.77
# | epoch  21 |    50/  201 batches | lr 0.31 | ms/batch 331.17 | loss 11.16 | ppl 70057.49
# | epoch  21 |    75/  201 batches | lr 0.31 | ms/batch 322.03 | loss 10.53 | ppl 37412.02
# | epoch  21 |   100/  201 batches | lr 0.31 | ms/batch 329.02 | loss 10.73 | ppl 45679.27
# | epoch  21 |   125/  201 batches | lr 0.31 | ms/batch 333.89 | loss 10.34 | ppl 30826.76
# | epoch  21 |   150/  201 batches | lr 0.31 | ms/batch 332.09 | loss 10.62 | ppl 40996.34
# | epoch  21 |   175/  201 batches | lr 0.31 | ms/batch 324.16 | loss 10.71 | ppl 44969.43
# | epoch  21 |   200/  201 batches | lr 0.31 | ms/batch 332.75 | loss 11.24 | ppl 75957.36
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 67.38s | valid loss  9.36 | valid ppl 11608.00
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  201 batches | lr 0.31 | ms/batch 342.60 | loss 12.26 | ppl 210832.28
# | epoch  22 |    50/  201 batches | lr 0.31 | ms/batch 322.33 | loss 11.20 | ppl 73178.07
# | epoch  22 |    75/  201 batches | lr 0.31 | ms/batch 329.49 | loss 10.47 | ppl 35219.94
# | epoch  22 |   100/  201 batches | lr 0.31 | ms/batch 347.95 | loss 10.69 | ppl 44009.92
# | epoch  22 |   125/  201 batches | lr 0.31 | ms/batch 324.38 | loss 10.25 | ppl 28258.48
# | epoch  22 |   150/  201 batches | lr 0.31 | ms/batch 329.90 | loss 10.59 | ppl 39762.64
# | epoch  22 |   175/  201 batches | lr 0.31 | ms/batch 345.29 | loss 10.75 | ppl 46458.95
# | epoch  22 |   200/  201 batches | lr 0.31 | ms/batch 352.01 | loss 11.18 | ppl 71875.14
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 68.97s | valid loss  9.33 | valid ppl 11258.04
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  201 batches | lr 0.31 | ms/batch 347.34 | loss 12.25 | ppl 208720.42
# | epoch  23 |    50/  201 batches | lr 0.31 | ms/batch 327.15 | loss 11.15 | ppl 69276.32
# | epoch  23 |    75/  201 batches | lr 0.31 | ms/batch 343.45 | loss 10.41 | ppl 33076.22
# | epoch  23 |   100/  201 batches | lr 0.31 | ms/batch 342.22 | loss 10.66 | ppl 42420.16
# | epoch  23 |   125/  201 batches | lr 0.31 | ms/batch 321.46 | loss 10.03 | ppl 22728.45
# | epoch  23 |   150/  201 batches | lr 0.31 | ms/batch 333.86 | loss 10.59 | ppl 39639.99
# | epoch  23 |   175/  201 batches | lr 0.31 | ms/batch 332.07 | loss 10.65 | ppl 42076.18
# | epoch  23 |   200/  201 batches | lr 0.31 | ms/batch 331.59 | loss 11.10 | ppl 66159.52
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 68.47s | valid loss  9.30 | valid ppl 10961.24
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  201 batches | lr 0.31 | ms/batch 334.49 | loss 12.05 | ppl 170396.57
# | epoch  24 |    50/  201 batches | lr 0.31 | ms/batch 324.30 | loss 11.11 | ppl 66721.06
# | epoch  24 |    75/  201 batches | lr 0.31 | ms/batch 347.53 | loss 10.43 | ppl 33818.89
# | epoch  24 |   100/  201 batches | lr 0.31 | ms/batch 342.40 | loss 10.60 | ppl 40153.50
# | epoch  24 |   125/  201 batches | lr 0.31 | ms/batch 326.73 | loss 10.12 | ppl 24826.88
# | epoch  24 |   150/  201 batches | lr 0.31 | ms/batch 335.26 | loss 10.59 | ppl 39766.68
# | epoch  24 |   175/  201 batches | lr 0.31 | ms/batch 337.64 | loss 10.65 | ppl 42008.11
# | epoch  24 |   200/  201 batches | lr 0.31 | ms/batch 314.20 | loss 11.02 | ppl 61056.19
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 68.10s | valid loss  9.28 | valid ppl 10753.01
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  201 batches | lr 0.31 | ms/batch 341.75 | loss 12.13 | ppl 185802.66
# | epoch  25 |    50/  201 batches | lr 0.31 | ms/batch 326.79 | loss 11.08 | ppl 64779.22
# | epoch  25 |    75/  201 batches | lr 0.31 | ms/batch 334.23 | loss 10.40 | ppl 32881.36
# | epoch  25 |   100/  201 batches | lr 0.31 | ms/batch 332.88 | loss 10.59 | ppl 39744.32
# | epoch  25 |   125/  201 batches | lr 0.31 | ms/batch 335.51 | loss 10.11 | ppl 24599.21
# | epoch  25 |   150/  201 batches | lr 0.31 | ms/batch 329.26 | loss 10.44 | ppl 34131.80
# | epoch  25 |   175/  201 batches | lr 0.31 | ms/batch 324.97 | loss 10.67 | ppl 42913.61
# | epoch  25 |   200/  201 batches | lr 0.31 | ms/batch 333.46 | loss 11.07 | ppl 64187.05
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 67.95s | valid loss  9.27 | valid ppl 10607.21
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  201 batches | lr 0.31 | ms/batch 355.12 | loss 12.00 | ppl 162819.63
# | epoch  26 |    50/  201 batches | lr 0.31 | ms/batch 347.21 | loss 10.98 | ppl 58589.38
# | epoch  26 |    75/  201 batches | lr 0.31 | ms/batch 334.24 | loss 10.27 | ppl 28724.09
# | epoch  26 |   100/  201 batches | lr 0.31 | ms/batch 343.46 | loss 10.58 | ppl 39173.90
# | epoch  26 |   125/  201 batches | lr 0.31 | ms/batch 351.17 | loss 10.07 | ppl 23637.10
# | epoch  26 |   150/  201 batches | lr 0.31 | ms/batch 341.93 | loss 10.34 | ppl 30864.48
# | epoch  26 |   175/  201 batches | lr 0.31 | ms/batch 325.37 | loss 10.52 | ppl 37153.45
# | epoch  26 |   200/  201 batches | lr 0.31 | ms/batch 333.10 | loss 11.01 | ppl 60692.51
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 69.61s | valid loss  9.24 | valid ppl 10292.49
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  201 batches | lr 0.31 | ms/batch 343.33 | loss 12.02 | ppl 166177.95
# | epoch  27 |    50/  201 batches | lr 0.31 | ms/batch 325.45 | loss 10.95 | ppl 57173.79
# | epoch  27 |    75/  201 batches | lr 0.31 | ms/batch 332.33 | loss 10.16 | ppl 25820.28
# | epoch  27 |   100/  201 batches | lr 0.31 | ms/batch 346.90 | loss 10.49 | ppl 35800.23
# | epoch  27 |   125/  201 batches | lr 0.31 | ms/batch 353.52 | loss 10.23 | ppl 27822.99
# | epoch  27 |   150/  201 batches | lr 0.31 | ms/batch 340.09 | loss 10.43 | ppl 33922.01
# | epoch  27 |   175/  201 batches | lr 0.31 | ms/batch 356.60 | loss 10.59 | ppl 39775.97
# | epoch  27 |   200/  201 batches | lr 0.31 | ms/batch 334.76 | loss 11.06 | ppl 63666.80
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 69.88s | valid loss  9.22 | valid ppl 10143.79
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  201 batches | lr 0.31 | ms/batch 339.46 | loss 11.99 | ppl 161469.92
# | epoch  28 |    50/  201 batches | lr 0.31 | ms/batch 332.58 | loss 10.93 | ppl 55804.20
# | epoch  28 |    75/  201 batches | lr 0.31 | ms/batch 339.45 | loss 10.22 | ppl 27540.26
# | epoch  28 |   100/  201 batches | lr 0.31 | ms/batch 348.09 | loss 10.56 | ppl 38728.48
# | epoch  28 |   125/  201 batches | lr 0.31 | ms/batch 340.93 | loss 10.08 | ppl 23878.49
# | epoch  28 |   150/  201 batches | lr 0.31 | ms/batch 339.15 | loss 10.36 | ppl 31536.70
# | epoch  28 |   175/  201 batches | lr 0.31 | ms/batch 334.54 | loss 10.49 | ppl 35859.04
# | epoch  28 |   200/  201 batches | lr 0.31 | ms/batch 324.72 | loss 11.08 | ppl 64720.03
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 69.09s | valid loss  9.19 | valid ppl  9801.65
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/  201 batches | lr 0.31 | ms/batch 338.45 | loss 11.92 | ppl 150657.46
# | epoch  29 |    50/  201 batches | lr 0.31 | ms/batch 345.73 | loss 10.94 | ppl 56181.84
# | epoch  29 |    75/  201 batches | lr 0.31 | ms/batch 333.54 | loss 10.22 | ppl 27549.04
# | epoch  29 |   100/  201 batches | lr 0.31 | ms/batch 334.38 | loss 10.51 | ppl 36811.92
# | epoch  29 |   125/  201 batches | lr 0.31 | ms/batch 335.43 | loss  9.97 | ppl 21322.13
# | epoch  29 |   150/  201 batches | lr 0.31 | ms/batch 335.56 | loss 10.43 | ppl 33931.70
# | epoch  29 |   175/  201 batches | lr 0.31 | ms/batch 338.68 | loss 10.46 | ppl 34977.93
# | epoch  29 |   200/  201 batches | lr 0.31 | ms/batch 316.97 | loss 11.00 | ppl 59881.29
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 68.45s | valid loss  9.17 | valid ppl  9649.41
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/  201 batches | lr 0.31 | ms/batch 354.21 | loss 11.89 | ppl 146004.00
# | epoch  30 |    50/  201 batches | lr 0.31 | ms/batch 336.36 | loss 10.79 | ppl 48390.57
# | epoch  30 |    75/  201 batches | lr 0.31 | ms/batch 347.63 | loss 10.15 | ppl 25640.16
# | epoch  30 |   100/  201 batches | lr 0.31 | ms/batch 349.52 | loss 10.45 | ppl 34452.11
# | epoch  30 |   125/  201 batches | lr 0.31 | ms/batch 335.71 | loss 10.02 | ppl 22381.38
# | epoch  30 |   150/  201 batches | lr 0.31 | ms/batch 334.54 | loss 10.29 | ppl 29396.10
# | epoch  30 |   175/  201 batches | lr 0.31 | ms/batch 340.61 | loss 10.49 | ppl 36012.23
# | epoch  30 |   200/  201 batches | lr 0.31 | ms/batch 342.91 | loss 10.79 | ppl 48559.15
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 70.08s | valid loss  9.14 | valid ppl  9355.74
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/  201 batches | lr 0.31 | ms/batch 352.20 | loss 11.79 | ppl 132433.40
# | epoch  31 |    50/  201 batches | lr 0.31 | ms/batch 344.86 | loss 10.91 | ppl 54525.86
# | epoch  31 |    75/  201 batches | lr 0.31 | ms/batch 341.30 | loss 10.01 | ppl 22356.34
# | epoch  31 |   100/  201 batches | lr 0.31 | ms/batch 357.81 | loss 10.36 | ppl 31660.94
# | epoch  31 |   125/  201 batches | lr 0.31 | ms/batch 336.57 | loss  9.99 | ppl 21726.41
# | epoch  31 |   150/  201 batches | lr 0.31 | ms/batch 331.59 | loss 10.15 | ppl 25611.45
# | epoch  31 |   175/  201 batches | lr 0.31 | ms/batch 339.98 | loss 10.43 | ppl 33725.29
# | epoch  31 |   200/  201 batches | lr 0.31 | ms/batch 332.52 | loss 10.78 | ppl 47958.87
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 69.80s | valid loss  9.11 | valid ppl  9069.46
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/  201 batches | lr 0.31 | ms/batch 345.17 | loss 11.75 | ppl 126838.58
# | epoch  32 |    50/  201 batches | lr 0.31 | ms/batch 340.63 | loss 10.85 | ppl 51333.74
# | epoch  32 |    75/  201 batches | lr 0.31 | ms/batch 329.78 | loss 10.10 | ppl 24423.28
# | epoch  32 |   100/  201 batches | lr 0.31 | ms/batch 352.87 | loss 10.31 | ppl 29985.13
# | epoch  32 |   125/  201 batches | lr 0.31 | ms/batch 342.25 | loss  9.94 | ppl 20798.45
# | epoch  32 |   150/  201 batches | lr 0.31 | ms/batch 339.77 | loss 10.25 | ppl 28226.97
# | epoch  32 |   175/  201 batches | lr 0.31 | ms/batch 344.25 | loss 10.49 | ppl 35966.92
# | epoch  32 |   200/  201 batches | lr 0.31 | ms/batch 352.14 | loss 10.69 | ppl 43842.67
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 70.06s | valid loss  9.09 | valid ppl  8865.65
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/  201 batches | lr 0.31 | ms/batch 342.30 | loss 11.79 | ppl 132167.10
# | epoch  33 |    50/  201 batches | lr 0.31 | ms/batch 332.51 | loss 10.76 | ppl 47103.56
# | epoch  33 |    75/  201 batches | lr 0.31 | ms/batch 346.78 | loss 10.16 | ppl 25759.54
# | epoch  33 |   100/  201 batches | lr 0.31 | ms/batch 341.03 | loss 10.23 | ppl 27724.49
# | epoch  33 |   125/  201 batches | lr 0.31 | ms/batch 338.93 | loss  9.98 | ppl 21511.75
# | epoch  33 |   150/  201 batches | lr 0.31 | ms/batch 342.59 | loss 10.31 | ppl 29888.31
# | epoch  33 |   175/  201 batches | lr 0.31 | ms/batch 351.94 | loss 10.38 | ppl 32251.45
# | epoch  33 |   200/  201 batches | lr 0.31 | ms/batch 337.41 | loss 10.82 | ppl 49771.80
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 69.90s | valid loss  9.07 | valid ppl  8696.35
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/  201 batches | lr 0.31 | ms/batch 349.28 | loss 11.78 | ppl 130811.02
# | epoch  34 |    50/  201 batches | lr 0.31 | ms/batch 348.16 | loss 10.74 | ppl 46389.70
# | epoch  34 |    75/  201 batches | lr 0.31 | ms/batch 335.39 | loss  9.94 | ppl 20714.11
# | epoch  34 |   100/  201 batches | lr 0.31 | ms/batch 358.65 | loss 10.31 | ppl 30081.18
# | epoch  34 |   125/  201 batches | lr 0.31 | ms/batch 351.73 | loss  9.80 | ppl 18003.61
# | epoch  34 |   150/  201 batches | lr 0.31 | ms/batch 336.48 | loss 10.18 | ppl 26371.07
# | epoch  34 |   175/  201 batches | lr 0.31 | ms/batch 329.76 | loss 10.37 | ppl 31965.20
# | epoch  34 |   200/  201 batches | lr 0.31 | ms/batch 346.51 | loss 10.72 | ppl 45192.03
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 70.58s | valid loss  9.04 | valid ppl  8420.03
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/  201 batches | lr 0.31 | ms/batch 342.13 | loss 11.75 | ppl 127137.92
# | epoch  35 |    50/  201 batches | lr 0.31 | ms/batch 329.69 | loss 10.77 | ppl 47450.36
# | epoch  35 |    75/  201 batches | lr 0.31 | ms/batch 338.30 | loss 10.06 | ppl 23272.77
# | epoch  35 |   100/  201 batches | lr 0.31 | ms/batch 331.61 | loss 10.28 | ppl 29148.22
# | epoch  35 |   125/  201 batches | lr 0.31 | ms/batch 346.00 | loss  9.89 | ppl 19766.34
# | epoch  35 |   150/  201 batches | lr 0.31 | ms/batch 353.83 | loss 10.15 | ppl 25636.10
# | epoch  35 |   175/  201 batches | lr 0.31 | ms/batch 356.18 | loss 10.31 | ppl 30026.14
# | epoch  35 |   200/  201 batches | lr 0.31 | ms/batch 351.18 | loss 10.79 | ppl 48371.63
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 70.24s | valid loss  9.04 | valid ppl  8398.25
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/  201 batches | lr 0.31 | ms/batch 348.17 | loss 11.78 | ppl 130356.34
# | epoch  36 |    50/  201 batches | lr 0.31 | ms/batch 358.76 | loss 10.68 | ppl 43405.37
# | epoch  36 |    75/  201 batches | lr 0.31 | ms/batch 334.61 | loss  9.89 | ppl 19793.05
# | epoch  36 |   100/  201 batches | lr 0.31 | ms/batch 348.70 | loss 10.19 | ppl 26688.64
# | epoch  36 |   125/  201 batches | lr 0.31 | ms/batch 359.96 | loss  9.86 | ppl 19058.01
# | epoch  36 |   150/  201 batches | lr 0.31 | ms/batch 331.60 | loss 10.06 | ppl 23293.32
# | epoch  36 |   175/  201 batches | lr 0.31 | ms/batch 356.32 | loss 10.21 | ppl 27211.27
# | epoch  36 |   200/  201 batches | lr 0.31 | ms/batch 338.24 | loss 10.73 | ppl 45579.13
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 70.73s | valid loss  9.01 | valid ppl  8190.09
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/  201 batches | lr 0.31 | ms/batch 347.86 | loss 11.74 | ppl 125120.96
# | epoch  37 |    50/  201 batches | lr 0.31 | ms/batch 359.13 | loss 10.63 | ppl 41451.55
# | epoch  37 |    75/  201 batches | lr 0.31 | ms/batch 336.53 | loss  9.93 | ppl 20456.20
# | epoch  37 |   100/  201 batches | lr 0.31 | ms/batch 348.85 | loss 10.15 | ppl 25670.67
# | epoch  37 |   125/  201 batches | lr 0.31 | ms/batch 349.34 | loss  9.80 | ppl 18006.56
# | epoch  37 |   150/  201 batches | lr 0.31 | ms/batch 337.36 | loss 10.01 | ppl 22266.95
# | epoch  37 |   175/  201 batches | lr 0.31 | ms/batch 347.31 | loss 10.15 | ppl 25623.61
# | epoch  37 |   200/  201 batches | lr 0.31 | ms/batch 353.69 | loss 10.65 | ppl 42223.77
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 71.00s | valid loss  8.97 | valid ppl  7882.07
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/  201 batches | lr 0.31 | ms/batch 346.89 | loss 11.49 | ppl 97933.16
# | epoch  38 |    50/  201 batches | lr 0.31 | ms/batch 345.49 | loss 10.67 | ppl 43240.76
# | epoch  38 |    75/  201 batches | lr 0.31 | ms/batch 346.97 | loss  9.86 | ppl 19213.11
# | epoch  38 |   100/  201 batches | lr 0.31 | ms/batch 340.13 | loss 10.06 | ppl 23428.00
# | epoch  38 |   125/  201 batches | lr 0.31 | ms/batch 332.26 | loss  9.76 | ppl 17259.38
# | epoch  38 |   150/  201 batches | lr 0.31 | ms/batch 363.46 | loss 10.02 | ppl 22384.57
# | epoch  38 |   175/  201 batches | lr 0.31 | ms/batch 362.92 | loss 10.20 | ppl 26941.92
# | epoch  38 |   200/  201 batches | lr 0.31 | ms/batch 337.96 | loss 10.69 | ppl 44070.04
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 70.77s | valid loss  8.98 | valid ppl  7914.11
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/  201 batches | lr 0.08 | ms/batch 349.95 | loss 11.67 | ppl 116788.04
# | epoch  39 |    50/  201 batches | lr 0.08 | ms/batch 334.91 | loss 10.76 | ppl 47123.41
# | epoch  39 |    75/  201 batches | lr 0.08 | ms/batch 350.31 | loss  9.87 | ppl 19401.97
# | epoch  39 |   100/  201 batches | lr 0.08 | ms/batch 360.93 | loss 10.12 | ppl 24806.63
# | epoch  39 |   125/  201 batches | lr 0.08 | ms/batch 329.25 | loss  9.77 | ppl 17439.91
# | epoch  39 |   150/  201 batches | lr 0.08 | ms/batch 345.55 | loss 10.04 | ppl 22952.98
# | epoch  39 |   175/  201 batches | lr 0.08 | ms/batch 354.50 | loss 10.14 | ppl 25310.24
# | epoch  39 |   200/  201 batches | lr 0.08 | ms/batch 348.67 | loss 10.66 | ppl 42696.45
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 70.73s | valid loss  8.98 | valid ppl  7943.12
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/  201 batches | lr 0.02 | ms/batch 351.49 | loss 11.62 | ppl 111038.11
# | epoch  40 |    50/  201 batches | lr 0.02 | ms/batch 348.46 | loss 10.70 | ppl 44247.49
# | epoch  40 |    75/  201 batches | lr 0.02 | ms/batch 343.30 | loss  9.88 | ppl 19566.41
# | epoch  40 |   100/  201 batches | lr 0.02 | ms/batch 325.31 | loss 10.18 | ppl 26401.93
# | epoch  40 |   125/  201 batches | lr 0.02 | ms/batch 347.06 | loss  9.79 | ppl 17777.05
# | epoch  40 |   150/  201 batches | lr 0.02 | ms/batch 352.17 | loss 10.03 | ppl 22805.97
# | epoch  40 |   175/  201 batches | lr 0.02 | ms/batch 347.63 | loss 10.19 | ppl 26736.02
# | epoch  40 |   200/  201 batches | lr 0.02 | ms/batch 342.68 | loss 10.57 | ppl 39104.87
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 70.33s | valid loss  8.98 | valid ppl  7941.86
# -----------------------------------------------------------------------------------------

# %%
micmac_relu = make_model(mic_corpus, "RNN_RELU", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=False)

# %%
train(micmac_relu, mic_corpus, 20, 40, 'data/micmac')
# Out:
# | epoch   1 |    25/  201 batches | lr 20.00 | ms/batch 194.02 | loss   nan | ppl      nan
# | epoch   1 |    50/  201 batches | lr 20.00 | ms/batch 176.88 | loss   nan | ppl      nan
# | epoch   1 |    75/  201 batches | lr 20.00 | ms/batch 186.48 | loss   nan | ppl      nan
# | epoch   1 |   100/  201 batches | lr 20.00 | ms/batch 186.79 | loss   nan | ppl      nan
# | epoch   1 |   125/  201 batches | lr 20.00 | ms/batch 190.20 | loss   nan | ppl      nan
# | epoch   1 |   150/  201 batches | lr 20.00 | ms/batch 189.53 | loss   nan | ppl      nan
# | epoch   1 |   175/  201 batches | lr 20.00 | ms/batch 186.91 | loss   nan | ppl      nan
# | epoch   1 |   200/  201 batches | lr 20.00 | ms/batch 185.47 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 38.66s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  201 batches | lr 20.00 | ms/batch 186.91 | loss   nan | ppl      nan
# | epoch   2 |    50/  201 batches | lr 20.00 | ms/batch 188.92 | loss   nan | ppl      nan
# | epoch   2 |    75/  201 batches | lr 20.00 | ms/batch 190.08 | loss   nan | ppl      nan
# | epoch   2 |   100/  201 batches | lr 20.00 | ms/batch 188.51 | loss   nan | ppl      nan
# | epoch   2 |   125/  201 batches | lr 20.00 | ms/batch 186.44 | loss   nan | ppl      nan
# | epoch   2 |   150/  201 batches | lr 20.00 | ms/batch 189.55 | loss   nan | ppl      nan
# | epoch   2 |   175/  201 batches | lr 20.00 | ms/batch 189.79 | loss   nan | ppl      nan
# | epoch   2 |   200/  201 batches | lr 20.00 | ms/batch 182.49 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 38.97s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  201 batches | lr 5.00 | ms/batch 194.75 | loss   nan | ppl      nan
# | epoch   3 |    50/  201 batches | lr 5.00 | ms/batch 179.52 | loss   nan | ppl      nan
# | epoch   3 |    75/  201 batches | lr 5.00 | ms/batch 188.87 | loss   nan | ppl      nan
# | epoch   3 |   100/  201 batches | lr 5.00 | ms/batch 183.88 | loss   nan | ppl      nan
# | epoch   3 |   125/  201 batches | lr 5.00 | ms/batch 187.84 | loss   nan | ppl      nan
# | epoch   3 |   150/  201 batches | lr 5.00 | ms/batch 189.93 | loss   nan | ppl      nan
# | epoch   3 |   175/  201 batches | lr 5.00 | ms/batch 178.10 | loss   nan | ppl      nan
# | epoch   3 |   200/  201 batches | lr 5.00 | ms/batch 181.59 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 38.62s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  201 batches | lr 1.25 | ms/batch 194.17 | loss   nan | ppl      nan
# | epoch   4 |    50/  201 batches | lr 1.25 | ms/batch 184.48 | loss   nan | ppl      nan
# | epoch   4 |    75/  201 batches | lr 1.25 | ms/batch 188.71 | loss   nan | ppl      nan
# | epoch   4 |   100/  201 batches | lr 1.25 | ms/batch 185.11 | loss   nan | ppl      nan
# | epoch   4 |   125/  201 batches | lr 1.25 | ms/batch 180.41 | loss   nan | ppl      nan
# | epoch   4 |   150/  201 batches | lr 1.25 | ms/batch 182.72 | loss   nan | ppl      nan
# | epoch   4 |   175/  201 batches | lr 1.25 | ms/batch 175.29 | loss   nan | ppl      nan
# | epoch   4 |   200/  201 batches | lr 1.25 | ms/batch 182.48 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 38.44s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  201 batches | lr 0.31 | ms/batch 195.90 | loss   nan | ppl      nan
# | epoch   5 |    50/  201 batches | lr 0.31 | ms/batch 187.41 | loss   nan | ppl      nan
# | epoch   5 |    75/  201 batches | lr 0.31 | ms/batch 188.41 | loss   nan | ppl      nan
# | epoch   5 |   100/  201 batches | lr 0.31 | ms/batch 182.72 | loss   nan | ppl      nan
# | epoch   5 |   125/  201 batches | lr 0.31 | ms/batch 179.65 | loss   nan | ppl      nan
# | epoch   5 |   150/  201 batches | lr 0.31 | ms/batch 186.81 | loss   nan | ppl      nan
# | epoch   5 |   175/  201 batches | lr 0.31 | ms/batch 185.94 | loss   nan | ppl      nan
# | epoch   5 |   200/  201 batches | lr 0.31 | ms/batch 188.48 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 38.68s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  201 batches | lr 0.08 | ms/batch 179.87 | loss   nan | ppl      nan
# | epoch   6 |    50/  201 batches | lr 0.08 | ms/batch 179.96 | loss   nan | ppl      nan
# | epoch   6 |    75/  201 batches | lr 0.08 | ms/batch 172.89 | loss   nan | ppl      nan
# | epoch   6 |   100/  201 batches | lr 0.08 | ms/batch 188.17 | loss   nan | ppl      nan
# | epoch   6 |   125/  201 batches | lr 0.08 | ms/batch 187.47 | loss   nan | ppl      nan
# | epoch   6 |   150/  201 batches | lr 0.08 | ms/batch 181.66 | loss   nan | ppl      nan
# | epoch   6 |   175/  201 batches | lr 0.08 | ms/batch 184.61 | loss   nan | ppl      nan
# | epoch   6 |   200/  201 batches | lr 0.08 | ms/batch 186.87 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 37.79s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  201 batches | lr 0.02 | ms/batch 189.62 | loss   nan | ppl      nan
# | epoch   7 |    50/  201 batches | lr 0.02 | ms/batch 178.00 | loss   nan | ppl      nan
# | epoch   7 |    75/  201 batches | lr 0.02 | ms/batch 184.77 | loss   nan | ppl      nan
# | epoch   7 |   100/  201 batches | lr 0.02 | ms/batch 187.44 | loss   nan | ppl      nan
# | epoch   7 |   125/  201 batches | lr 0.02 | ms/batch 187.67 | loss   nan | ppl      nan
# | epoch   7 |   150/  201 batches | lr 0.02 | ms/batch 188.75 | loss   nan | ppl      nan
# | epoch   7 |   175/  201 batches | lr 0.02 | ms/batch 177.09 | loss   nan | ppl      nan
# | epoch   7 |   200/  201 batches | lr 0.02 | ms/batch 186.60 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 38.25s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  201 batches | lr 0.00 | ms/batch 196.34 | loss   nan | ppl      nan
# | epoch   8 |    50/  201 batches | lr 0.00 | ms/batch 188.85 | loss   nan | ppl      nan
# | epoch   8 |    75/  201 batches | lr 0.00 | ms/batch 182.53 | loss   nan | ppl      nan
# | epoch   8 |   100/  201 batches | lr 0.00 | ms/batch 186.41 | loss   nan | ppl      nan
# | epoch   8 |   125/  201 batches | lr 0.00 | ms/batch 185.36 | loss   nan | ppl      nan
# | epoch   8 |   150/  201 batches | lr 0.00 | ms/batch 180.17 | loss   nan | ppl      nan
# | epoch   8 |   175/  201 batches | lr 0.00 | ms/batch 184.63 | loss   nan | ppl      nan
# | epoch   8 |   200/  201 batches | lr 0.00 | ms/batch 188.83 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 38.76s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  201 batches | lr 0.00 | ms/batch 191.45 | loss   nan | ppl      nan
# | epoch   9 |    50/  201 batches | lr 0.00 | ms/batch 184.96 | loss   nan | ppl      nan
# | epoch   9 |    75/  201 batches | lr 0.00 | ms/batch 185.18 | loss   nan | ppl      nan
# | epoch   9 |   100/  201 batches | lr 0.00 | ms/batch 187.73 | loss   nan | ppl      nan
# | epoch   9 |   125/  201 batches | lr 0.00 | ms/batch 188.65 | loss   nan | ppl      nan
# | epoch   9 |   150/  201 batches | lr 0.00 | ms/batch 179.61 | loss   nan | ppl      nan
# | epoch   9 |   175/  201 batches | lr 0.00 | ms/batch 185.28 | loss   nan | ppl      nan
# | epoch   9 |   200/  201 batches | lr 0.00 | ms/batch 187.48 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 38.53s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  201 batches | lr 0.00 | ms/batch 189.20 | loss   nan | ppl      nan
# | epoch  10 |    50/  201 batches | lr 0.00 | ms/batch 185.67 | loss   nan | ppl      nan
# | epoch  10 |    75/  201 batches | lr 0.00 | ms/batch 186.59 | loss   nan | ppl      nan
# | epoch  10 |   100/  201 batches | lr 0.00 | ms/batch 187.69 | loss   nan | ppl      nan
# | epoch  10 |   125/  201 batches | lr 0.00 | ms/batch 190.59 | loss   nan | ppl      nan
# | epoch  10 |   150/  201 batches | lr 0.00 | ms/batch 190.21 | loss   nan | ppl      nan
# | epoch  10 |   175/  201 batches | lr 0.00 | ms/batch 190.91 | loss   nan | ppl      nan
# | epoch  10 |   200/  201 batches | lr 0.00 | ms/batch 189.54 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 39.37s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  201 batches | lr 0.00 | ms/batch 190.59 | loss   nan | ppl      nan
# | epoch  11 |    50/  201 batches | lr 0.00 | ms/batch 184.62 | loss   nan | ppl      nan
# | epoch  11 |    75/  201 batches | lr 0.00 | ms/batch 185.62 | loss   nan | ppl      nan
# | epoch  11 |   100/  201 batches | lr 0.00 | ms/batch 186.57 | loss   nan | ppl      nan
# | epoch  11 |   125/  201 batches | lr 0.00 | ms/batch 189.50 | loss   nan | ppl      nan
# | epoch  11 |   150/  201 batches | lr 0.00 | ms/batch 182.53 | loss   nan | ppl      nan
# | epoch  11 |   175/  201 batches | lr 0.00 | ms/batch 185.16 | loss   nan | ppl      nan
# | epoch  11 |   200/  201 batches | lr 0.00 | ms/batch 187.74 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 38.91s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  201 batches | lr 0.00 | ms/batch 195.27 | loss   nan | ppl      nan
# | epoch  12 |    50/  201 batches | lr 0.00 | ms/batch 186.19 | loss   nan | ppl      nan
# | epoch  12 |    75/  201 batches | lr 0.00 | ms/batch 189.75 | loss   nan | ppl      nan
# | epoch  12 |   100/  201 batches | lr 0.00 | ms/batch 185.14 | loss   nan | ppl      nan
# | epoch  12 |   125/  201 batches | lr 0.00 | ms/batch 189.74 | loss   nan | ppl      nan
# | epoch  12 |   150/  201 batches | lr 0.00 | ms/batch 189.07 | loss   nan | ppl      nan
# | epoch  12 |   175/  201 batches | lr 0.00 | ms/batch 183.65 | loss   nan | ppl      nan
# | epoch  12 |   200/  201 batches | lr 0.00 | ms/batch 188.45 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 39.25s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  201 batches | lr 0.00 | ms/batch 190.34 | loss   nan | ppl      nan
# | epoch  13 |    50/  201 batches | lr 0.00 | ms/batch 187.11 | loss   nan | ppl      nan
# | epoch  13 |    75/  201 batches | lr 0.00 | ms/batch 184.07 | loss   nan | ppl      nan
# | epoch  13 |   100/  201 batches | lr 0.00 | ms/batch 184.27 | loss   nan | ppl      nan
# | epoch  13 |   125/  201 batches | lr 0.00 | ms/batch 182.42 | loss   nan | ppl      nan
# | epoch  13 |   150/  201 batches | lr 0.00 | ms/batch 184.43 | loss   nan | ppl      nan
# | epoch  13 |   175/  201 batches | lr 0.00 | ms/batch 180.34 | loss   nan | ppl      nan
# | epoch  13 |   200/  201 batches | lr 0.00 | ms/batch 184.23 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 38.39s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  201 batches | lr 0.00 | ms/batch 190.54 | loss   nan | ppl      nan
# | epoch  14 |    50/  201 batches | lr 0.00 | ms/batch 189.90 | loss   nan | ppl      nan
# | epoch  14 |    75/  201 batches | lr 0.00 | ms/batch 188.20 | loss   nan | ppl      nan
# | epoch  14 |   100/  201 batches | lr 0.00 | ms/batch 189.12 | loss   nan | ppl      nan
# | epoch  14 |   125/  201 batches | lr 0.00 | ms/batch 188.58 | loss   nan | ppl      nan
# | epoch  14 |   150/  201 batches | lr 0.00 | ms/batch 183.56 | loss   nan | ppl      nan
# | epoch  14 |   175/  201 batches | lr 0.00 | ms/batch 183.76 | loss   nan | ppl      nan
# | epoch  14 |   200/  201 batches | lr 0.00 | ms/batch 180.06 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 38.59s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  201 batches | lr 0.00 | ms/batch 191.85 | loss   nan | ppl      nan
# | epoch  15 |    50/  201 batches | lr 0.00 | ms/batch 187.54 | loss   nan | ppl      nan
# | epoch  15 |    75/  201 batches | lr 0.00 | ms/batch 189.41 | loss   nan | ppl      nan
# | epoch  15 |   100/  201 batches | lr 0.00 | ms/batch 180.10 | loss   nan | ppl      nan
# | epoch  15 |   125/  201 batches | lr 0.00 | ms/batch 187.73 | loss   nan | ppl      nan
# | epoch  15 |   150/  201 batches | lr 0.00 | ms/batch 183.76 | loss   nan | ppl      nan
# | epoch  15 |   175/  201 batches | lr 0.00 | ms/batch 182.09 | loss   nan | ppl      nan
# | epoch  15 |   200/  201 batches | lr 0.00 | ms/batch 172.72 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 38.38s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  201 batches | lr 0.00 | ms/batch 189.20 | loss   nan | ppl      nan
# | epoch  16 |    50/  201 batches | lr 0.00 | ms/batch 182.50 | loss   nan | ppl      nan
# | epoch  16 |    75/  201 batches | lr 0.00 | ms/batch 178.32 | loss   nan | ppl      nan
# | epoch  16 |   100/  201 batches | lr 0.00 | ms/batch 181.12 | loss   nan | ppl      nan
# | epoch  16 |   125/  201 batches | lr 0.00 | ms/batch 189.13 | loss   nan | ppl      nan
# | epoch  16 |   150/  201 batches | lr 0.00 | ms/batch 184.90 | loss   nan | ppl      nan
# | epoch  16 |   175/  201 batches | lr 0.00 | ms/batch 188.88 | loss   nan | ppl      nan
# | epoch  16 |   200/  201 batches | lr 0.00 | ms/batch 190.31 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 38.41s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  201 batches | lr 0.00 | ms/batch 183.69 | loss   nan | ppl      nan
# | epoch  17 |    50/  201 batches | lr 0.00 | ms/batch 179.76 | loss   nan | ppl      nan
# | epoch  17 |    75/  201 batches | lr 0.00 | ms/batch 188.88 | loss   nan | ppl      nan
# | epoch  17 |   100/  201 batches | lr 0.00 | ms/batch 189.83 | loss   nan | ppl      nan
# | epoch  17 |   125/  201 batches | lr 0.00 | ms/batch 185.76 | loss   nan | ppl      nan
# | epoch  17 |   150/  201 batches | lr 0.00 | ms/batch 181.47 | loss   nan | ppl      nan
# | epoch  17 |   175/  201 batches | lr 0.00 | ms/batch 184.40 | loss   nan | ppl      nan
# | epoch  17 |   200/  201 batches | lr 0.00 | ms/batch 189.92 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 38.70s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  201 batches | lr 0.00 | ms/batch 193.86 | loss   nan | ppl      nan
# | epoch  18 |    50/  201 batches | lr 0.00 | ms/batch 187.04 | loss   nan | ppl      nan
# | epoch  18 |    75/  201 batches | lr 0.00 | ms/batch 186.94 | loss   nan | ppl      nan
# | epoch  18 |   100/  201 batches | lr 0.00 | ms/batch 186.03 | loss   nan | ppl      nan
# | epoch  18 |   125/  201 batches | lr 0.00 | ms/batch 188.05 | loss   nan | ppl      nan
# | epoch  18 |   150/  201 batches | lr 0.00 | ms/batch 185.87 | loss   nan | ppl      nan
# | epoch  18 |   175/  201 batches | lr 0.00 | ms/batch 190.47 | loss   nan | ppl      nan
# | epoch  18 |   200/  201 batches | lr 0.00 | ms/batch 180.85 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 38.71s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  201 batches | lr 0.00 | ms/batch 195.45 | loss   nan | ppl      nan
# | epoch  19 |    50/  201 batches | lr 0.00 | ms/batch 187.86 | loss   nan | ppl      nan
# | epoch  19 |    75/  201 batches | lr 0.00 | ms/batch 181.43 | loss   nan | ppl      nan
# | epoch  19 |   100/  201 batches | lr 0.00 | ms/batch 186.35 | loss   nan | ppl      nan
# | epoch  19 |   125/  201 batches | lr 0.00 | ms/batch 188.39 | loss   nan | ppl      nan
# | epoch  19 |   150/  201 batches | lr 0.00 | ms/batch 186.07 | loss   nan | ppl      nan
# | epoch  19 |   175/  201 batches | lr 0.00 | ms/batch 189.12 | loss   nan | ppl      nan
# | epoch  19 |   200/  201 batches | lr 0.00 | ms/batch 176.89 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 38.95s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  201 batches | lr 0.00 | ms/batch 190.52 | loss   nan | ppl      nan
# | epoch  20 |    50/  201 batches | lr 0.00 | ms/batch 188.14 | loss   nan | ppl      nan
# | epoch  20 |    75/  201 batches | lr 0.00 | ms/batch 187.43 | loss   nan | ppl      nan
# | epoch  20 |   100/  201 batches | lr 0.00 | ms/batch 189.89 | loss   nan | ppl      nan
# | epoch  20 |   125/  201 batches | lr 0.00 | ms/batch 185.64 | loss   nan | ppl      nan
# | epoch  20 |   150/  201 batches | lr 0.00 | ms/batch 186.57 | loss   nan | ppl      nan
# | epoch  20 |   175/  201 batches | lr 0.00 | ms/batch 186.62 | loss   nan | ppl      nan
# | epoch  20 |   200/  201 batches | lr 0.00 | ms/batch 188.85 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 39.02s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  201 batches | lr 0.00 | ms/batch 191.97 | loss   nan | ppl      nan
# | epoch  21 |    50/  201 batches | lr 0.00 | ms/batch 187.48 | loss   nan | ppl      nan
# | epoch  21 |    75/  201 batches | lr 0.00 | ms/batch 188.05 | loss   nan | ppl      nan
# | epoch  21 |   100/  201 batches | lr 0.00 | ms/batch 185.00 | loss   nan | ppl      nan
# | epoch  21 |   125/  201 batches | lr 0.00 | ms/batch 180.26 | loss   nan | ppl      nan
# | epoch  21 |   150/  201 batches | lr 0.00 | ms/batch 186.24 | loss   nan | ppl      nan
# | epoch  21 |   175/  201 batches | lr 0.00 | ms/batch 185.45 | loss   nan | ppl      nan
# | epoch  21 |   200/  201 batches | lr 0.00 | ms/batch 176.75 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 38.55s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  201 batches | lr 0.00 | ms/batch 195.42 | loss   nan | ppl      nan
# | epoch  22 |    50/  201 batches | lr 0.00 | ms/batch 188.80 | loss   nan | ppl      nan
# | epoch  22 |    75/  201 batches | lr 0.00 | ms/batch 189.13 | loss   nan | ppl      nan
# | epoch  22 |   100/  201 batches | lr 0.00 | ms/batch 190.54 | loss   nan | ppl      nan
# | epoch  22 |   125/  201 batches | lr 0.00 | ms/batch 189.02 | loss   nan | ppl      nan
# | epoch  22 |   150/  201 batches | lr 0.00 | ms/batch 186.57 | loss   nan | ppl      nan
# | epoch  22 |   175/  201 batches | lr 0.00 | ms/batch 184.46 | loss   nan | ppl      nan
# | epoch  22 |   200/  201 batches | lr 0.00 | ms/batch 188.74 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 39.09s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  201 batches | lr 0.00 | ms/batch 196.99 | loss   nan | ppl      nan
# | epoch  23 |    50/  201 batches | lr 0.00 | ms/batch 182.96 | loss   nan | ppl      nan
# | epoch  23 |    75/  201 batches | lr 0.00 | ms/batch 184.08 | loss   nan | ppl      nan
# | epoch  23 |   100/  201 batches | lr 0.00 | ms/batch 189.44 | loss   nan | ppl      nan
# | epoch  23 |   125/  201 batches | lr 0.00 | ms/batch 187.93 | loss   nan | ppl      nan
# | epoch  23 |   150/  201 batches | lr 0.00 | ms/batch 187.61 | loss   nan | ppl      nan
# | epoch  23 |   175/  201 batches | lr 0.00 | ms/batch 187.10 | loss   nan | ppl      nan
# | epoch  23 |   200/  201 batches | lr 0.00 | ms/batch 189.51 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 38.91s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  201 batches | lr 0.00 | ms/batch 190.18 | loss   nan | ppl      nan
# | epoch  24 |    50/  201 batches | lr 0.00 | ms/batch 185.68 | loss   nan | ppl      nan
# | epoch  24 |    75/  201 batches | lr 0.00 | ms/batch 186.13 | loss   nan | ppl      nan
# | epoch  24 |   100/  201 batches | lr 0.00 | ms/batch 183.92 | loss   nan | ppl      nan
# | epoch  24 |   125/  201 batches | lr 0.00 | ms/batch 186.46 | loss   nan | ppl      nan
# | epoch  24 |   150/  201 batches | lr 0.00 | ms/batch 184.43 | loss   nan | ppl      nan
# | epoch  24 |   175/  201 batches | lr 0.00 | ms/batch 190.64 | loss   nan | ppl      nan
# | epoch  24 |   200/  201 batches | lr 0.00 | ms/batch 189.00 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 38.97s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  201 batches | lr 0.00 | ms/batch 186.04 | loss   nan | ppl      nan
# | epoch  25 |    50/  201 batches | lr 0.00 | ms/batch 187.05 | loss   nan | ppl      nan
# | epoch  25 |    75/  201 batches | lr 0.00 | ms/batch 184.87 | loss   nan | ppl      nan
# | epoch  25 |   100/  201 batches | lr 0.00 | ms/batch 186.61 | loss   nan | ppl      nan
# | epoch  25 |   125/  201 batches | lr 0.00 | ms/batch 187.44 | loss   nan | ppl      nan
# | epoch  25 |   150/  201 batches | lr 0.00 | ms/batch 186.66 | loss   nan | ppl      nan
# | epoch  25 |   175/  201 batches | lr 0.00 | ms/batch 185.71 | loss   nan | ppl      nan
# | epoch  25 |   200/  201 batches | lr 0.00 | ms/batch 188.32 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 38.62s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  201 batches | lr 0.00 | ms/batch 190.22 | loss   nan | ppl      nan
# | epoch  26 |    50/  201 batches | lr 0.00 | ms/batch 187.41 | loss   nan | ppl      nan
# | epoch  26 |    75/  201 batches | lr 0.00 | ms/batch 187.81 | loss   nan | ppl      nan
# | epoch  26 |   100/  201 batches | lr 0.00 | ms/batch 182.22 | loss   nan | ppl      nan
# | epoch  26 |   125/  201 batches | lr 0.00 | ms/batch 180.53 | loss   nan | ppl      nan
# | epoch  26 |   150/  201 batches | lr 0.00 | ms/batch 189.32 | loss   nan | ppl      nan
# | epoch  26 |   175/  201 batches | lr 0.00 | ms/batch 188.16 | loss   nan | ppl      nan
# | epoch  26 |   200/  201 batches | lr 0.00 | ms/batch 190.56 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 38.78s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  201 batches | lr 0.00 | ms/batch 187.92 | loss   nan | ppl      nan
# | epoch  27 |    50/  201 batches | lr 0.00 | ms/batch 185.38 | loss   nan | ppl      nan
# | epoch  27 |    75/  201 batches | lr 0.00 | ms/batch 189.31 | loss   nan | ppl      nan
# | epoch  27 |   100/  201 batches | lr 0.00 | ms/batch 187.45 | loss   nan | ppl      nan
# | epoch  27 |   125/  201 batches | lr 0.00 | ms/batch 188.06 | loss   nan | ppl      nan
# | epoch  27 |   150/  201 batches | lr 0.00 | ms/batch 188.39 | loss   nan | ppl      nan
# | epoch  27 |   175/  201 batches | lr 0.00 | ms/batch 187.97 | loss   nan | ppl      nan
# | epoch  27 |   200/  201 batches | lr 0.00 | ms/batch 183.34 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 38.93s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  201 batches | lr 0.00 | ms/batch 194.39 | loss   nan | ppl      nan
# | epoch  28 |    50/  201 batches | lr 0.00 | ms/batch 182.18 | loss   nan | ppl      nan
# | epoch  28 |    75/  201 batches | lr 0.00 | ms/batch 186.87 | loss   nan | ppl      nan
# | epoch  28 |   100/  201 batches | lr 0.00 | ms/batch 189.60 | loss   nan | ppl      nan
# | epoch  28 |   125/  201 batches | lr 0.00 | ms/batch 189.37 | loss   nan | ppl      nan
# | epoch  28 |   150/  201 batches | lr 0.00 | ms/batch 185.63 | loss   nan | ppl      nan
# | epoch  28 |   175/  201 batches | lr 0.00 | ms/batch 185.09 | loss   nan | ppl      nan
# | epoch  28 |   200/  201 batches | lr 0.00 | ms/batch 189.55 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 38.96s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/  201 batches | lr 0.00 | ms/batch 191.77 | loss   nan | ppl      nan
# | epoch  29 |    50/  201 batches | lr 0.00 | ms/batch 184.43 | loss   nan | ppl      nan
# | epoch  29 |    75/  201 batches | lr 0.00 | ms/batch 190.59 | loss   nan | ppl      nan
# | epoch  29 |   100/  201 batches | lr 0.00 | ms/batch 192.00 | loss   nan | ppl      nan
# | epoch  29 |   125/  201 batches | lr 0.00 | ms/batch 191.59 | loss   nan | ppl      nan
# | epoch  29 |   150/  201 batches | lr 0.00 | ms/batch 182.13 | loss   nan | ppl      nan
# | epoch  29 |   175/  201 batches | lr 0.00 | ms/batch 181.05 | loss   nan | ppl      nan
# | epoch  29 |   200/  201 batches | lr 0.00 | ms/batch 185.87 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 38.80s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/  201 batches | lr 0.00 | ms/batch 190.30 | loss   nan | ppl      nan
# | epoch  30 |    50/  201 batches | lr 0.00 | ms/batch 185.74 | loss   nan | ppl      nan
# | epoch  30 |    75/  201 batches | lr 0.00 | ms/batch 187.02 | loss   nan | ppl      nan
# | epoch  30 |   100/  201 batches | lr 0.00 | ms/batch 189.71 | loss   nan | ppl      nan
# | epoch  30 |   125/  201 batches | lr 0.00 | ms/batch 188.09 | loss   nan | ppl      nan
# | epoch  30 |   150/  201 batches | lr 0.00 | ms/batch 188.13 | loss   nan | ppl      nan
# | epoch  30 |   175/  201 batches | lr 0.00 | ms/batch 185.81 | loss   nan | ppl      nan
# | epoch  30 |   200/  201 batches | lr 0.00 | ms/batch 179.97 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 38.75s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/  201 batches | lr 0.00 | ms/batch 191.58 | loss   nan | ppl      nan
# | epoch  31 |    50/  201 batches | lr 0.00 | ms/batch 189.02 | loss   nan | ppl      nan
# | epoch  31 |    75/  201 batches | lr 0.00 | ms/batch 183.17 | loss   nan | ppl      nan
# | epoch  31 |   100/  201 batches | lr 0.00 | ms/batch 191.00 | loss   nan | ppl      nan
# | epoch  31 |   125/  201 batches | lr 0.00 | ms/batch 183.90 | loss   nan | ppl      nan
# | epoch  31 |   150/  201 batches | lr 0.00 | ms/batch 183.94 | loss   nan | ppl      nan
# | epoch  31 |   175/  201 batches | lr 0.00 | ms/batch 189.89 | loss   nan | ppl      nan
# | epoch  31 |   200/  201 batches | lr 0.00 | ms/batch 190.95 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 39.09s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/  201 batches | lr 0.00 | ms/batch 188.44 | loss   nan | ppl      nan
# | epoch  32 |    50/  201 batches | lr 0.00 | ms/batch 187.33 | loss   nan | ppl      nan
# | epoch  32 |    75/  201 batches | lr 0.00 | ms/batch 191.34 | loss   nan | ppl      nan
# | epoch  32 |   100/  201 batches | lr 0.00 | ms/batch 189.40 | loss   nan | ppl      nan
# | epoch  32 |   125/  201 batches | lr 0.00 | ms/batch 190.25 | loss   nan | ppl      nan
# | epoch  32 |   150/  201 batches | lr 0.00 | ms/batch 190.41 | loss   nan | ppl      nan
# | epoch  32 |   175/  201 batches | lr 0.00 | ms/batch 191.41 | loss   nan | ppl      nan
# | epoch  32 |   200/  201 batches | lr 0.00 | ms/batch 184.83 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 39.30s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/  201 batches | lr 0.00 | ms/batch 191.78 | loss   nan | ppl      nan
# | epoch  33 |    50/  201 batches | lr 0.00 | ms/batch 187.55 | loss   nan | ppl      nan
# | epoch  33 |    75/  201 batches | lr 0.00 | ms/batch 187.59 | loss   nan | ppl      nan
# | epoch  33 |   100/  201 batches | lr 0.00 | ms/batch 191.17 | loss   nan | ppl      nan
# | epoch  33 |   125/  201 batches | lr 0.00 | ms/batch 182.34 | loss   nan | ppl      nan
# | epoch  33 |   150/  201 batches | lr 0.00 | ms/batch 185.26 | loss   nan | ppl      nan
# | epoch  33 |   175/  201 batches | lr 0.00 | ms/batch 178.85 | loss   nan | ppl      nan
# | epoch  33 |   200/  201 batches | lr 0.00 | ms/batch 185.19 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 38.90s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/  201 batches | lr 0.00 | ms/batch 190.96 | loss   nan | ppl      nan
# | epoch  34 |    50/  201 batches | lr 0.00 | ms/batch 190.29 | loss   nan | ppl      nan
# | epoch  34 |    75/  201 batches | lr 0.00 | ms/batch 186.63 | loss   nan | ppl      nan
# | epoch  34 |   100/  201 batches | lr 0.00 | ms/batch 184.31 | loss   nan | ppl      nan
# | epoch  34 |   125/  201 batches | lr 0.00 | ms/batch 184.72 | loss   nan | ppl      nan
# | epoch  34 |   150/  201 batches | lr 0.00 | ms/batch 191.39 | loss   nan | ppl      nan
# | epoch  34 |   175/  201 batches | lr 0.00 | ms/batch 178.46 | loss   nan | ppl      nan
# | epoch  34 |   200/  201 batches | lr 0.00 | ms/batch 186.34 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 38.65s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/  201 batches | lr 0.00 | ms/batch 192.40 | loss   nan | ppl      nan
# | epoch  35 |    50/  201 batches | lr 0.00 | ms/batch 189.21 | loss   nan | ppl      nan
# | epoch  35 |    75/  201 batches | lr 0.00 | ms/batch 182.01 | loss   nan | ppl      nan
# | epoch  35 |   100/  201 batches | lr 0.00 | ms/batch 186.48 | loss   nan | ppl      nan
# | epoch  35 |   125/  201 batches | lr 0.00 | ms/batch 188.72 | loss   nan | ppl      nan
# | epoch  35 |   150/  201 batches | lr 0.00 | ms/batch 184.10 | loss   nan | ppl      nan
# | epoch  35 |   175/  201 batches | lr 0.00 | ms/batch 184.13 | loss   nan | ppl      nan
# | epoch  35 |   200/  201 batches | lr 0.00 | ms/batch 189.85 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 38.99s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/  201 batches | lr 0.00 | ms/batch 189.25 | loss   nan | ppl      nan
# | epoch  36 |    50/  201 batches | lr 0.00 | ms/batch 187.30 | loss   nan | ppl      nan
# | epoch  36 |    75/  201 batches | lr 0.00 | ms/batch 177.89 | loss   nan | ppl      nan
# | epoch  36 |   100/  201 batches | lr 0.00 | ms/batch 184.77 | loss   nan | ppl      nan
# | epoch  36 |   125/  201 batches | lr 0.00 | ms/batch 183.64 | loss   nan | ppl      nan
# | epoch  36 |   150/  201 batches | lr 0.00 | ms/batch 185.35 | loss   nan | ppl      nan
# | epoch  36 |   175/  201 batches | lr 0.00 | ms/batch 185.08 | loss   nan | ppl      nan
# | epoch  36 |   200/  201 batches | lr 0.00 | ms/batch 185.44 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 38.25s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/  201 batches | lr 0.00 | ms/batch 193.93 | loss   nan | ppl      nan
# | epoch  37 |    50/  201 batches | lr 0.00 | ms/batch 182.86 | loss   nan | ppl      nan
# | epoch  37 |    75/  201 batches | lr 0.00 | ms/batch 187.09 | loss   nan | ppl      nan
# | epoch  37 |   100/  201 batches | lr 0.00 | ms/batch 187.55 | loss   nan | ppl      nan
# | epoch  37 |   125/  201 batches | lr 0.00 | ms/batch 182.60 | loss   nan | ppl      nan
# | epoch  37 |   150/  201 batches | lr 0.00 | ms/batch 183.00 | loss   nan | ppl      nan
# | epoch  37 |   175/  201 batches | lr 0.00 | ms/batch 191.18 | loss   nan | ppl      nan
# | epoch  37 |   200/  201 batches | lr 0.00 | ms/batch 183.97 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 38.84s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/  201 batches | lr 0.00 | ms/batch 189.47 | loss   nan | ppl      nan
# | epoch  38 |    50/  201 batches | lr 0.00 | ms/batch 188.75 | loss   nan | ppl      nan
# | epoch  38 |    75/  201 batches | lr 0.00 | ms/batch 188.70 | loss   nan | ppl      nan
# | epoch  38 |   100/  201 batches | lr 0.00 | ms/batch 185.15 | loss   nan | ppl      nan
# | epoch  38 |   125/  201 batches | lr 0.00 | ms/batch 187.89 | loss   nan | ppl      nan
# | epoch  38 |   150/  201 batches | lr 0.00 | ms/batch 182.62 | loss   nan | ppl      nan
# | epoch  38 |   175/  201 batches | lr 0.00 | ms/batch 189.20 | loss   nan | ppl      nan
# | epoch  38 |   200/  201 batches | lr 0.00 | ms/batch 189.17 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 39.06s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/  201 batches | lr 0.00 | ms/batch 193.17 | loss   nan | ppl      nan
# | epoch  39 |    50/  201 batches | lr 0.00 | ms/batch 190.40 | loss   nan | ppl      nan
# | epoch  39 |    75/  201 batches | lr 0.00 | ms/batch 189.60 | loss   nan | ppl      nan
# | epoch  39 |   100/  201 batches | lr 0.00 | ms/batch 184.35 | loss   nan | ppl      nan
# | epoch  39 |   125/  201 batches | lr 0.00 | ms/batch 187.20 | loss   nan | ppl      nan
# | epoch  39 |   150/  201 batches | lr 0.00 | ms/batch 184.60 | loss   nan | ppl      nan
# | epoch  39 |   175/  201 batches | lr 0.00 | ms/batch 189.09 | loss   nan | ppl      nan
# | epoch  39 |   200/  201 batches | lr 0.00 | ms/batch 187.07 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 39.34s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/  201 batches | lr 0.00 | ms/batch 192.77 | loss   nan | ppl      nan
# | epoch  40 |    50/  201 batches | lr 0.00 | ms/batch 185.80 | loss   nan | ppl      nan
# | epoch  40 |    75/  201 batches | lr 0.00 | ms/batch 187.85 | loss   nan | ppl      nan
# | epoch  40 |   100/  201 batches | lr 0.00 | ms/batch 186.72 | loss   nan | ppl      nan
# | epoch  40 |   125/  201 batches | lr 0.00 | ms/batch 188.34 | loss   nan | ppl      nan
# | epoch  40 |   150/  201 batches | lr 0.00 | ms/batch 188.65 | loss   nan | ppl      nan
# | epoch  40 |   175/  201 batches | lr 0.00 | ms/batch 188.54 | loss   nan | ppl      nan
# | epoch  40 |   200/  201 batches | lr 0.00 | ms/batch 187.83 | loss   nan | ppl      nan
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 39.04s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------

# %%
micmac_lstm3 = make_model(mic_corpus, "LSTM", emsize=200, nhidden=200, nlayers=2, 
                          dropout=0.2, tied=True)

train(micmac_lstm3, mic_corpus, 40, 40, 'data/micmac')
# Out:
# | epoch   1 |    25/  201 batches | lr 40.00 | ms/batch 2152.73 | loss 317.79 | ppl 1038166756649441953915467283222094431980084899390550954873741759396001371466203483903407732082507244125770191068871824168215391988942372864.00
# | epoch   1 |    50/  201 batches | lr 40.00 | ms/batch 1612.45 | loss 377.06 | ppl 56816807207634645192958175526224980349597868443279527008882898665888270148358567135201255700123016188598379780827902296338789716303733266790351961173607273547694080.00
# | epoch   1 |    75/  201 batches | lr 40.00 | ms/batch 1317.60 | loss 321.70 | ppl 51629002721751039823362344667283195154814866251889807350935131341218113024459360950042333338468887090901885476285920959861102318693086396416.00
# | epoch   1 |   100/  201 batches | lr 40.00 | ms/batch 1607.88 | loss 322.86 | ppl 163833260741778198495883880061274661254083733417295731648395513607445875237491318597103361112419078524419065955951703179993792714225381015552.00
# | epoch   1 |   125/  201 batches | lr 40.00 | ms/batch 1599.93 | loss 197.98 | ppl 95832067877234525965156649203338079667009303494180967287349007699866973957095535149056.00
# | epoch   1 |   150/  201 batches | lr 40.00 | ms/batch 1616.96 | loss 351.42 | ppl 417314976291497133216061927711324600475064666960441936216945738983581229614245224743321788210469783490467068875645825914724593978874494391249811565182976.00
# | epoch   1 |   175/  201 batches | lr 40.00 | ms/batch 1767.50 | loss 234.35 | ppl 595846680425281863278610006121818725923971801459979187818954926214325423255721071835610387373241663488.00
# | epoch   1 |   200/  201 batches | lr 40.00 | ms/batch 1806.20 | loss 398.15 | ppl 81774265121084332918913373016595529962084042797367458719959611299053778713458824946155807500226091722284454644860240413802984357169238429357295177417415036943054521126354944.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 364.01s | valid loss 226.85 | valid ppl 330199417874315912521240592706223427856534828197004645395503095172626280823797107887408533771124736.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/  201 batches | lr 40.00 | ms/batch 1442.48 | loss 322.86 | ppl 164722528986262182715276365299499436820647668929950353404692896198994907201201761520136435306566954852442135255325002767718538073369600851968.00
# | epoch   2 |    50/  201 batches | lr 40.00 | ms/batch 1597.54 | loss 259.08 | ppl 32790406127405396407256448761554265227746808842203650762797999103625403487683033134352887801720633126748214525952.00
# | epoch   2 |    75/  201 batches | lr 40.00 | ms/batch 1922.09 | loss 317.42 | ppl 713577035750735842824872183728301763944211439253817501468600122561620563665795121856449908881689399513133912675067910099631960912618848256.00
# | epoch   2 |   100/  201 batches | lr 40.00 | ms/batch 2379.21 | loss 271.22 | ppl 6137719764876730177790699536663873509225821898213427213439516499150678082227613719315155548859768845799986063160115200.00
# | epoch   2 |   125/  201 batches | lr 40.00 | ms/batch 2579.42 | loss 256.11 | ppl 1694592832300310410622509313368759631026964384630763107829501011824857205099725784313096241781942913313603059712.00
# | epoch   2 |   150/  201 batches | lr 40.00 | ms/batch 2335.51 | loss 262.90 | ppl 1499848489406727722008917692974307233336055100055569647646775669700683809412652108092107842714703871834212718870528.00
# | epoch   2 |   175/  201 batches | lr 40.00 | ms/batch 2434.11 | loss 206.64 | ppl 553372322519316133514602032322913849181014712104607858336417051465915682266704770754412544.00
# | epoch   2 |   200/  201 batches | lr 40.00 | ms/batch 2409.58 | loss 130.89 | ppl 701225343004475202944469775573856312915558039921081974784.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 460.91s | valid loss 198.37 | valid ppl 140936093607446093993118136730433108208222434055712978051353227099243461444562933776384.00
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/  201 batches | lr 40.00 | ms/batch 2579.77 | loss 249.68 | ppl 2732433450688281602551030661123673208007092264749832340896131317523096402217069663017786254912269163845124096.00
# | epoch   3 |    50/  201 batches | lr 40.00 | ms/batch 1771.33 | loss 404.64 | ppl 54310011812270785046569014007147842970854920185833795046675664133031087142790218441150485475509625815121333468490635770247553405853893460211935706923047546728709941616980262912.00
# | epoch   3 |    75/  201 batches | lr 40.00 | ms/batch 2075.49 | loss 175.14 | ppl 11573384848414617770221005207469502935952984962640674519750654057595201912832.00
# | epoch   3 |   100/  201 batches | lr 40.00 | ms/batch 2350.86 | loss 102.59 | ppl 356719615009174610270546456511214318841233408.00
# | epoch   3 |   125/  201 batches | lr 40.00 | ms/batch 2310.29 | loss 161.66 | ppl 16218439685027900199208906045855114800877736066011626515001850581745664.00
# | epoch   3 |   150/  201 batches | lr 40.00 | ms/batch 2354.75 | loss 73.35 | ppl 71939512277047736117853614505984.00
# | epoch   3 |   175/  201 batches | lr 40.00 | ms/batch 1919.59 | loss 172.29 | ppl 665207716904305418445403111937036750611784758709752342358477160883075153920.00
# | epoch   3 |   200/  201 batches | lr 40.00 | ms/batch 2315.49 | loss 110.18 | ppl 705445384274898422050759465127812507960550096896.00
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 477.46s | valid loss 32.21 | valid ppl 97444653312024.52
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/  201 batches | lr 40.00 | ms/batch 2218.75 | loss 125.19 | ppl 2341183201318983710716384187888926307755528139627823104.00
# | epoch   4 |    50/  201 batches | lr 40.00 | ms/batch 2401.53 | loss 111.76 | ppl 3455873456834370525727300890755807005081652428800.00
# | epoch   4 |    75/  201 batches | lr 40.00 | ms/batch 2257.81 | loss 99.02 | ppl 10071044920655656919584923028555650132082688.00
# | epoch   4 |   100/  201 batches | lr 40.00 | ms/batch 2401.28 | loss 65.17 | ppl 20155345699868283414696165376.00
# | epoch   4 |   125/  201 batches | lr 40.00 | ms/batch 2458.19 | loss 125.98 | ppl 5176562600762791279409044145483360264480849931895046144.00
# | epoch   4 |   150/  201 batches | lr 40.00 | ms/batch 2478.44 | loss 68.52 | ppl 569960043182694303725053280256.00
# | epoch   4 |   175/  201 batches | lr 40.00 | ms/batch 2530.93 | loss 99.03 | ppl 10239269958825121542247025511948015995191296.00
# | epoch   4 |   200/  201 batches | lr 40.00 | ms/batch 2183.19 | loss 186.56 | ppl 1049235381828649811932017633221674247305447295334530561547518484012773899065360384.00
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 508.16s | valid loss 171.25 | valid ppl 237034348107244554868083296829898625990833609454767657495112006879852625920.00
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/  201 batches | lr 10.00 | ms/batch 2834.23 | loss 105.85 | ppl 9328687579244984787259926668563017259137630208.00
# | epoch   5 |    50/  201 batches | lr 10.00 | ms/batch 2684.62 | loss 70.98 | ppl 6689110881018901102443857182720.00
# | epoch   5 |    75/  201 batches | lr 10.00 | ms/batch 2789.54 | loss 56.56 | ppl 3676924147050028644433920.00
# | epoch   5 |   100/  201 batches | lr 10.00 | ms/batch 2810.14 | loss 50.95 | ppl 13355526119458330378240.00
# | epoch   5 |   125/  201 batches | lr 10.00 | ms/batch 2834.15 | loss 46.62 | ppl 176025920446213029888.00
# | epoch   5 |   150/  201 batches | lr 10.00 | ms/batch 2807.31 | loss 43.96 | ppl 12314678618814898176.00
# | epoch   5 |   175/  201 batches | lr 10.00 | ms/batch 2839.06 | loss 41.68 | ppl 1261873963244106752.00
# | epoch   5 |   200/  201 batches | lr 10.00 | ms/batch 2830.53 | loss 42.16 | ppl 2030886908883510784.00
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 597.51s | valid loss 29.46 | valid ppl 6242308673973.22
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/  201 batches | lr 10.00 | ms/batch 2999.63 | loss 43.71 | ppl 9575686426809905152.00
# | epoch   6 |    50/  201 batches | lr 10.00 | ms/batch 2816.69 | loss 44.86 | ppl 30444187338172821504.00
# | epoch   6 |    75/  201 batches | lr 10.00 | ms/batch 2790.46 | loss 43.72 | ppl 9680022666392582144.00
# | epoch   6 |   100/  201 batches | lr 10.00 | ms/batch 2780.70 | loss 43.96 | ppl 12375295820128950272.00
# | epoch   6 |   125/  201 batches | lr 10.00 | ms/batch 2791.66 | loss 41.27 | ppl 836984289788413568.00
# | epoch   6 |   150/  201 batches | lr 10.00 | ms/batch 2822.17 | loss 39.33 | ppl 120468989022120384.00
# | epoch   6 |   175/  201 batches | lr 10.00 | ms/batch 2818.37 | loss 40.03 | ppl 242253344669262336.00
# | epoch   6 |   200/  201 batches | lr 10.00 | ms/batch 2810.01 | loss 42.96 | ppl 4531353768746909696.00
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 603.00s | valid loss 27.08 | valid ppl 574618889674.10
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/  201 batches | lr 10.00 | ms/batch 2975.32 | loss 42.64 | ppl 3306644714451164160.00
# | epoch   7 |    50/  201 batches | lr 10.00 | ms/batch 2787.68 | loss 41.51 | ppl 1065200287809094144.00
# | epoch   7 |    75/  201 batches | lr 10.00 | ms/batch 2834.02 | loss 39.84 | ppl 199810433063107328.00
# | epoch   7 |   100/  201 batches | lr 10.00 | ms/batch 2902.09 | loss 41.97 | ppl 1687500640383061248.00
# | epoch   7 |   125/  201 batches | lr 10.00 | ms/batch 2920.36 | loss 38.76 | ppl 68352712422473632.00
# | epoch   7 |   150/  201 batches | lr 10.00 | ms/batch 2895.07 | loss 39.42 | ppl 131488537501396016.00
# | epoch   7 |   175/  201 batches | lr 10.00 | ms/batch 2929.96 | loss 39.54 | ppl 149114415495285856.00
# | epoch   7 |   200/  201 batches | lr 10.00 | ms/batch 2917.80 | loss 40.68 | ppl 462397339350241664.00
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 616.93s | valid loss 25.08 | valid ppl 77643828277.43
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/  201 batches | lr 10.00 | ms/batch 3082.13 | loss 38.91 | ppl 79093212558649392.00
# | epoch   8 |    50/  201 batches | lr 10.00 | ms/batch 2998.38 | loss 40.95 | ppl 608608333062615424.00
# | epoch   8 |    75/  201 batches | lr 10.00 | ms/batch 3040.02 | loss 38.52 | ppl 53739649448543336.00
# | epoch   8 |   100/  201 batches | lr 10.00 | ms/batch 3011.23 | loss 40.57 | ppl 414627215166230784.00
# | epoch   8 |   125/  201 batches | lr 10.00 | ms/batch 2948.23 | loss 37.84 | ppl 27265585647369644.00
# | epoch   8 |   150/  201 batches | lr 10.00 | ms/batch 2954.93 | loss 39.77 | ppl 187177053713080480.00
# | epoch   8 |   175/  201 batches | lr 10.00 | ms/batch 2996.34 | loss 38.16 | ppl 37348132142011616.00
# | epoch   8 |   200/  201 batches | lr 10.00 | ms/batch 2983.20 | loss 39.62 | ppl 161162747131050016.00
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 639.24s | valid loss 33.84 | valid ppl 496201119026152.88
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/  201 batches | lr 2.50 | ms/batch 3323.97 | loss 34.01 | ppl 588592622028937.25
# | epoch   9 |    50/  201 batches | lr 2.50 | ms/batch 3140.12 | loss 26.25 | ppl 251703383451.87
# | epoch   9 |    75/  201 batches | lr 2.50 | ms/batch 3155.19 | loss 24.22 | ppl 32937522345.69
# | epoch   9 |   100/  201 batches | lr 2.50 | ms/batch 3138.87 | loss 22.39 | ppl 5311039203.82
# | epoch   9 |   125/  201 batches | lr 2.50 | ms/batch 3132.12 | loss 21.37 | ppl 1900709380.27
# | epoch   9 |   150/  201 batches | lr 2.50 | ms/batch 3140.45 | loss 22.46 | ppl 5686145760.36
# | epoch   9 |   175/  201 batches | lr 2.50 | ms/batch 3150.46 | loss 20.63 | ppl 908218151.77
# | epoch   9 |   200/  201 batches | lr 2.50 | ms/batch 3117.43 | loss 23.17 | ppl 11503279202.78
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 671.42s | valid loss 17.10 | valid ppl 26731133.74
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/  201 batches | lr 2.50 | ms/batch 3285.21 | loss 24.41 | ppl 40067336402.11
# | epoch  10 |    50/  201 batches | lr 2.50 | ms/batch 3149.61 | loss 24.26 | ppl 34413560955.81
# | epoch  10 |    75/  201 batches | lr 2.50 | ms/batch 3120.04 | loss 23.61 | ppl 18020802699.50
# | epoch  10 |   100/  201 batches | lr 2.50 | ms/batch 3134.32 | loss 22.73 | ppl 7435786241.17
# | epoch  10 |   125/  201 batches | lr 2.50 | ms/batch 3129.89 | loss 21.58 | ppl 2348870279.49
# | epoch  10 |   150/  201 batches | lr 2.50 | ms/batch 3140.77 | loss 22.03 | ppl 3711104630.09
# | epoch  10 |   175/  201 batches | lr 2.50 | ms/batch 3130.18 | loss 21.40 | ppl 1964594074.68
# | epoch  10 |   200/  201 batches | lr 2.50 | ms/batch 3149.99 | loss 23.16 | ppl 11472429802.46
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 669.84s | valid loss 17.87 | valid ppl 57460762.84
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/  201 batches | lr 0.62 | ms/batch 3327.39 | loss 21.94 | ppl 3385698781.16
# | epoch  11 |    50/  201 batches | lr 0.62 | ms/batch 3209.84 | loss 21.20 | ppl 1604826167.03
# | epoch  11 |    75/  201 batches | lr 0.62 | ms/batch 3226.64 | loss 21.09 | ppl 1438463152.62
# | epoch  11 |   100/  201 batches | lr 0.62 | ms/batch 3242.16 | loss 20.44 | ppl 756948339.15
# | epoch  11 |   125/  201 batches | lr 0.62 | ms/batch 3204.26 | loss 19.12 | ppl 200979006.20
# | epoch  11 |   150/  201 batches | lr 0.62 | ms/batch 3253.79 | loss 19.05 | ppl 186858555.90
# | epoch  11 |   175/  201 batches | lr 0.62 | ms/batch 3215.85 | loss 18.76 | ppl 141010412.30
# | epoch  11 |   200/  201 batches | lr 0.62 | ms/batch 3230.03 | loss 20.25 | ppl 620986935.86
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 686.81s | valid loss 16.24 | valid ppl 11246550.81
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/  201 batches | lr 0.62 | ms/batch 3389.75 | loss 21.55 | ppl 2296864813.59
# | epoch  12 |    50/  201 batches | lr 0.62 | ms/batch 3235.82 | loss 21.33 | ppl 1838039744.86
# | epoch  12 |    75/  201 batches | lr 0.62 | ms/batch 3228.77 | loss 20.98 | ppl 1289796439.64
# | epoch  12 |   100/  201 batches | lr 0.62 | ms/batch 3228.43 | loss 19.44 | ppl 276232785.44
# | epoch  12 |   125/  201 batches | lr 0.62 | ms/batch 3254.48 | loss 18.54 | ppl 112672850.16
# | epoch  12 |   150/  201 batches | lr 0.62 | ms/batch 3253.81 | loss 18.95 | ppl 169074052.72
# | epoch  12 |   175/  201 batches | lr 0.62 | ms/batch 3234.18 | loss 18.49 | ppl 107174153.03
# | epoch  12 |   200/  201 batches | lr 0.62 | ms/batch 3259.35 | loss 20.05 | ppl 509647685.51
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 691.20s | valid loss 16.21 | valid ppl 10982316.00
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/  201 batches | lr 0.62 | ms/batch 3387.61 | loss 21.05 | ppl 1393331360.50
# | epoch  13 |    50/  201 batches | lr 0.62 | ms/batch 3240.19 | loss 20.81 | ppl 1087058909.49
# | epoch  13 |    75/  201 batches | lr 0.62 | ms/batch 3250.78 | loss 20.50 | ppl 800430912.99
# | epoch  13 |   100/  201 batches | lr 0.62 | ms/batch 3282.47 | loss 19.59 | ppl 321290315.61
# | epoch  13 |   125/  201 batches | lr 0.62 | ms/batch 3271.85 | loss 18.69 | ppl 131482157.22
# | epoch  13 |   150/  201 batches | lr 0.62 | ms/batch 3260.97 | loss 18.39 | ppl 96727934.44
# | epoch  13 |   175/  201 batches | lr 0.62 | ms/batch 3256.43 | loss 18.14 | ppl 75512359.29
# | epoch  13 |   200/  201 batches | lr 0.62 | ms/batch 3248.02 | loss 19.60 | ppl 324186513.46
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 693.85s | valid loss 16.21 | valid ppl 10985223.18
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/  201 batches | lr 0.16 | ms/batch 3386.04 | loss 20.67 | ppl 944656151.34
# | epoch  14 |    50/  201 batches | lr 0.16 | ms/batch 3278.72 | loss 20.75 | ppl 1026309026.31
# | epoch  14 |    75/  201 batches | lr 0.16 | ms/batch 3263.86 | loss 20.85 | ppl 1130341198.73
# | epoch  14 |   100/  201 batches | lr 0.16 | ms/batch 3268.84 | loss 19.60 | ppl 325718452.14
# | epoch  14 |   125/  201 batches | lr 0.16 | ms/batch 3287.18 | loss 18.72 | ppl 135451074.00
# | epoch  14 |   150/  201 batches | lr 0.16 | ms/batch 3306.64 | loss 18.71 | ppl 133707243.20
# | epoch  14 |   175/  201 batches | lr 0.16 | ms/batch 3258.17 | loss 17.85 | ppl 56357789.64
# | epoch  14 |   200/  201 batches | lr 0.16 | ms/batch 3271.38 | loss 19.69 | ppl 356774823.63
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 696.90s | valid loss 16.29 | valid ppl 11917189.84
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/  201 batches | lr 0.04 | ms/batch 3374.19 | loss 21.33 | ppl 1830114320.10
# | epoch  15 |    50/  201 batches | lr 0.04 | ms/batch 3255.10 | loss 21.21 | ppl 1621950656.01
# | epoch  15 |    75/  201 batches | lr 0.04 | ms/batch 3287.29 | loss 20.40 | ppl 720423786.52
# | epoch  15 |   100/  201 batches | lr 0.04 | ms/batch 3249.77 | loss 19.58 | ppl 320262975.64
# | epoch  15 |   125/  201 batches | lr 0.04 | ms/batch 3242.10 | loss 18.35 | ppl 92859309.77
# | epoch  15 |   150/  201 batches | lr 0.04 | ms/batch 3273.10 | loss 19.04 | ppl 186657559.33
# | epoch  15 |   175/  201 batches | lr 0.04 | ms/batch 3290.09 | loss 18.01 | ppl 66485507.20
# | epoch  15 |   200/  201 batches | lr 0.04 | ms/batch 3255.83 | loss 19.52 | ppl 300823210.59
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 694.84s | valid loss 16.29 | valid ppl 11907927.27
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/  201 batches | lr 0.01 | ms/batch 3424.73 | loss 20.89 | ppl 1177450198.06
# | epoch  16 |    50/  201 batches | lr 0.01 | ms/batch 3272.05 | loss 20.91 | ppl 1199976600.52
# | epoch  16 |    75/  201 batches | lr 0.01 | ms/batch 3258.16 | loss 20.25 | ppl 623794175.00
# | epoch  16 |   100/  201 batches | lr 0.01 | ms/batch 3291.17 | loss 19.43 | ppl 275353111.22
# | epoch  16 |   125/  201 batches | lr 0.01 | ms/batch 3286.67 | loss 18.76 | ppl 140248422.92
# | epoch  16 |   150/  201 batches | lr 0.01 | ms/batch 3267.96 | loss 18.58 | ppl 116943945.13
# | epoch  16 |   175/  201 batches | lr 0.01 | ms/batch 3238.54 | loss 18.10 | ppl 72846036.35
# | epoch  16 |   200/  201 batches | lr 0.01 | ms/batch 3260.26 | loss 19.78 | ppl 388637331.87
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 696.42s | valid loss 16.29 | valid ppl 11910954.28
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/  201 batches | lr 0.00 | ms/batch 3414.13 | loss 21.39 | ppl 1949262056.48
# | epoch  17 |    50/  201 batches | lr 0.00 | ms/batch 3255.53 | loss 20.84 | ppl 1126723960.10
# | epoch  17 |    75/  201 batches | lr 0.00 | ms/batch 3248.72 | loss 20.74 | ppl 1016588107.90
# | epoch  17 |   100/  201 batches | lr 0.00 | ms/batch 3258.79 | loss 19.49 | ppl 292260779.88
# | epoch  17 |   125/  201 batches | lr 0.00 | ms/batch 3256.98 | loss 18.54 | ppl 113050905.92
# | epoch  17 |   150/  201 batches | lr 0.00 | ms/batch 3254.73 | loss 18.63 | ppl 123093982.84
# | epoch  17 |   175/  201 batches | lr 0.00 | ms/batch 3247.88 | loss 18.13 | ppl 74499458.43
# | epoch  17 |   200/  201 batches | lr 0.00 | ms/batch 3270.70 | loss 20.04 | ppl 504360015.78
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 694.52s | valid loss 16.29 | valid ppl 11911436.82
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/  201 batches | lr 0.00 | ms/batch 3390.44 | loss 21.12 | ppl 1482037255.54
# | epoch  18 |    50/  201 batches | lr 0.00 | ms/batch 3253.47 | loss 20.81 | ppl 1085232121.76
# | epoch  18 |    75/  201 batches | lr 0.00 | ms/batch 3278.83 | loss 20.22 | ppl 602988288.73
# | epoch  18 |   100/  201 batches | lr 0.00 | ms/batch 3291.99 | loss 20.02 | ppl 493894462.03
# | epoch  18 |   125/  201 batches | lr 0.00 | ms/batch 3258.94 | loss 18.72 | ppl 135110689.06
# | epoch  18 |   150/  201 batches | lr 0.00 | ms/batch 3283.53 | loss 18.32 | ppl 90793886.88
# | epoch  18 |   175/  201 batches | lr 0.00 | ms/batch 3252.00 | loss 18.31 | ppl 89781426.45
# | epoch  18 |   200/  201 batches | lr 0.00 | ms/batch 3262.44 | loss 19.62 | ppl 331647332.33
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 696.16s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/  201 batches | lr 0.00 | ms/batch 3400.18 | loss 21.38 | ppl 1930318204.08
# | epoch  19 |    50/  201 batches | lr 0.00 | ms/batch 3259.38 | loss 20.79 | ppl 1068950171.70
# | epoch  19 |    75/  201 batches | lr 0.00 | ms/batch 3266.16 | loss 20.19 | ppl 585510285.84
# | epoch  19 |   100/  201 batches | lr 0.00 | ms/batch 3249.92 | loss 19.52 | ppl 299425676.25
# | epoch  19 |   125/  201 batches | lr 0.00 | ms/batch 3258.18 | loss 18.69 | ppl 130752332.27
# | epoch  19 |   150/  201 batches | lr 0.00 | ms/batch 3260.80 | loss 18.64 | ppl 124579525.17
# | epoch  19 |   175/  201 batches | lr 0.00 | ms/batch 3276.00 | loss 18.34 | ppl 92594730.34
# | epoch  19 |   200/  201 batches | lr 0.00 | ms/batch 3263.57 | loss 19.36 | ppl 254805096.48
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 694.80s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/  201 batches | lr 0.00 | ms/batch 3395.42 | loss 21.34 | ppl 1862152462.96
# | epoch  20 |    50/  201 batches | lr 0.00 | ms/batch 3283.36 | loss 20.54 | ppl 830545878.17
# | epoch  20 |    75/  201 batches | lr 0.00 | ms/batch 3218.98 | loss 20.80 | ppl 1079021418.70
# | epoch  20 |   100/  201 batches | lr 0.00 | ms/batch 3270.63 | loss 19.49 | ppl 290423748.43
# | epoch  20 |   125/  201 batches | lr 0.00 | ms/batch 3244.61 | loss 18.66 | ppl 127514423.75
# | epoch  20 |   150/  201 batches | lr 0.00 | ms/batch 3258.93 | loss 18.80 | ppl 146323439.80
# | epoch  20 |   175/  201 batches | lr 0.00 | ms/batch 3256.24 | loss 18.34 | ppl 92486997.12
# | epoch  20 |   200/  201 batches | lr 0.00 | ms/batch 3272.46 | loss 19.94 | ppl 455749137.59
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 693.87s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/  201 batches | lr 0.00 | ms/batch 3377.19 | loss 21.37 | ppl 1914410010.29
# | epoch  21 |    50/  201 batches | lr 0.00 | ms/batch 3232.22 | loss 21.06 | ppl 1400532462.91
# | epoch  21 |    75/  201 batches | lr 0.00 | ms/batch 3282.88 | loss 20.77 | ppl 1043539495.03
# | epoch  21 |   100/  201 batches | lr 0.00 | ms/batch 3299.01 | loss 19.37 | ppl 257906088.64
# | epoch  21 |   125/  201 batches | lr 0.00 | ms/batch 3240.50 | loss 18.52 | ppl 110596200.58
# | epoch  21 |   150/  201 batches | lr 0.00 | ms/batch 3255.61 | loss 19.05 | ppl 187520535.15
# | epoch  21 |   175/  201 batches | lr 0.00 | ms/batch 3254.59 | loss 18.02 | ppl 67231364.91
# | epoch  21 |   200/  201 batches | lr 0.00 | ms/batch 3281.75 | loss 19.65 | ppl 341191455.39
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 694.69s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/  201 batches | lr 0.00 | ms/batch 3375.38 | loss 21.63 | ppl 2473051860.07
# | epoch  22 |    50/  201 batches | lr 0.00 | ms/batch 3268.89 | loss 20.81 | ppl 1090824241.59
# | epoch  22 |    75/  201 batches | lr 0.00 | ms/batch 3269.57 | loss 20.66 | ppl 937236595.89
# | epoch  22 |   100/  201 batches | lr 0.00 | ms/batch 3265.71 | loss 19.62 | ppl 332855821.58
# | epoch  22 |   125/  201 batches | lr 0.00 | ms/batch 3290.55 | loss 18.81 | ppl 147106190.45
# | epoch  22 |   150/  201 batches | lr 0.00 | ms/batch 3255.71 | loss 18.45 | ppl 102773982.79
# | epoch  22 |   175/  201 batches | lr 0.00 | ms/batch 3286.69 | loss 18.37 | ppl 94970841.15
# | epoch  22 |   200/  201 batches | lr 0.00 | ms/batch 3244.01 | loss 19.59 | ppl 320953163.79
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 695.46s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/  201 batches | lr 0.00 | ms/batch 3391.32 | loss 21.31 | ppl 1791219466.14
# | epoch  23 |    50/  201 batches | lr 0.00 | ms/batch 3269.07 | loss 21.33 | ppl 1834414139.25
# | epoch  23 |    75/  201 batches | lr 0.00 | ms/batch 3277.30 | loss 20.89 | ppl 1185468364.89
# | epoch  23 |   100/  201 batches | lr 0.00 | ms/batch 3268.62 | loss 19.51 | ppl 298396312.11
# | epoch  23 |   125/  201 batches | lr 0.00 | ms/batch 3254.20 | loss 18.21 | ppl 81041057.03
# | epoch  23 |   150/  201 batches | lr 0.00 | ms/batch 3266.39 | loss 18.40 | ppl 98094793.99
# | epoch  23 |   175/  201 batches | lr 0.00 | ms/batch 3275.27 | loss 18.15 | ppl 76394172.06
# | epoch  23 |   200/  201 batches | lr 0.00 | ms/batch 3260.82 | loss 19.59 | ppl 323333812.80
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 695.61s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/  201 batches | lr 0.00 | ms/batch 3398.81 | loss 20.90 | ppl 1192103980.62
# | epoch  24 |    50/  201 batches | lr 0.00 | ms/batch 3256.52 | loss 20.55 | ppl 838704888.88
# | epoch  24 |    75/  201 batches | lr 0.00 | ms/batch 3257.34 | loss 20.41 | ppl 729747173.51
# | epoch  24 |   100/  201 batches | lr 0.00 | ms/batch 3290.67 | loss 19.65 | ppl 341190427.17
# | epoch  24 |   125/  201 batches | lr 0.00 | ms/batch 3254.04 | loss 18.70 | ppl 132838535.25
# | epoch  24 |   150/  201 batches | lr 0.00 | ms/batch 3299.83 | loss 18.81 | ppl 146993613.22
# | epoch  24 |   175/  201 batches | lr 0.00 | ms/batch 3252.83 | loss 18.31 | ppl 89387918.73
# | epoch  24 |   200/  201 batches | lr 0.00 | ms/batch 3271.55 | loss 19.57 | ppl 315437803.44
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 695.93s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/  201 batches | lr 0.00 | ms/batch 3411.46 | loss 21.67 | ppl 2588380948.75
# | epoch  25 |    50/  201 batches | lr 0.00 | ms/batch 3256.07 | loss 20.77 | ppl 1052673706.40
# | epoch  25 |    75/  201 batches | lr 0.00 | ms/batch 3243.57 | loss 20.78 | ppl 1054300489.74
# | epoch  25 |   100/  201 batches | lr 0.00 | ms/batch 3254.44 | loss 19.55 | ppl 309117088.42
# | epoch  25 |   125/  201 batches | lr 0.00 | ms/batch 3267.04 | loss 18.54 | ppl 112221075.15
# | epoch  25 |   150/  201 batches | lr 0.00 | ms/batch 3264.76 | loss 19.01 | ppl 179780674.67
# | epoch  25 |   175/  201 batches | lr 0.00 | ms/batch 3271.37 | loss 18.23 | ppl 82588520.85
# | epoch  25 |   200/  201 batches | lr 0.00 | ms/batch 3273.06 | loss 19.77 | ppl 384316901.67
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 694.94s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/  201 batches | lr 0.00 | ms/batch 3420.30 | loss 21.36 | ppl 1896145810.03
# | epoch  26 |    50/  201 batches | lr 0.00 | ms/batch 3236.61 | loss 20.89 | ppl 1179659628.21
# | epoch  26 |    75/  201 batches | lr 0.00 | ms/batch 3245.86 | loss 21.01 | ppl 1337510350.17
# | epoch  26 |   100/  201 batches | lr 0.00 | ms/batch 3282.32 | loss 19.75 | ppl 378622927.47
# | epoch  26 |   125/  201 batches | lr 0.00 | ms/batch 3276.36 | loss 18.51 | ppl 109417965.58
# | epoch  26 |   150/  201 batches | lr 0.00 | ms/batch 3263.02 | loss 18.73 | ppl 136171944.07
# | epoch  26 |   175/  201 batches | lr 0.00 | ms/batch 3225.88 | loss 18.55 | ppl 114123664.83
# | epoch  26 |   200/  201 batches | lr 0.00 | ms/batch 3247.27 | loss 19.75 | ppl 379234908.29
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 693.98s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/  201 batches | lr 0.00 | ms/batch 3403.02 | loss 21.43 | ppl 2026812010.88
# | epoch  27 |    50/  201 batches | lr 0.00 | ms/batch 3278.63 | loss 20.68 | ppl 954128628.96
# | epoch  27 |    75/  201 batches | lr 0.00 | ms/batch 3242.24 | loss 20.90 | ppl 1187409525.28
# | epoch  27 |   100/  201 batches | lr 0.00 | ms/batch 3284.45 | loss 19.27 | ppl 234256123.83
# | epoch  27 |   125/  201 batches | lr 0.00 | ms/batch 3251.24 | loss 18.43 | ppl 101322707.60
# | epoch  27 |   150/  201 batches | lr 0.00 | ms/batch 3259.54 | loss 18.86 | ppl 154806392.56
# | epoch  27 |   175/  201 batches | lr 0.00 | ms/batch 3265.29 | loss 18.22 | ppl 82082443.67
# | epoch  27 |   200/  201 batches | lr 0.00 | ms/batch 3295.85 | loss 19.71 | ppl 362778086.11
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 696.14s | valid loss 16.29 | valid ppl 11911448.04
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/  201 batches | lr 0.00 | ms/batch 3381.33 | loss 21.29 | ppl 1757195151.24

# %%
# !command pip install https://github.com/kpu/kenlm/archive/master.zippip install

# %%
# !command pip install nltk
