# %%
# !command python main.py --data ./data/reuters --epochs=20 --model LSTM --log-interval 25
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 143.96 | loss  8.27 | ppl  3908.84
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 127.16 | loss  6.98 | ppl  1079.84
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 124.87 | loss  6.85 | ppl   943.07
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.53s | valid loss  6.49 | valid ppl   660.39
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 137.26 | loss  6.81 | ppl   904.50
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 131.83 | loss  6.43 | ppl   621.09
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 149.96 | loss  6.30 | ppl   542.17
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.82s | valid loss  6.08 | valid ppl   435.09
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model GRU --log-interval 25
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 138.54 | loss  9.80 | ppl 18067.60
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 131.63 | loss  8.56 | ppl  5230.01
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 131.46 | loss  8.11 | ppl  3333.08
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.53s | valid loss  6.83 | valid ppl   923.16
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 135.63 | loss  7.89 | ppl  2668.03
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 129.84 | loss  7.12 | ppl  1236.78
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 133.47 | loss  6.73 | ppl   837.18
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.41s | valid loss  6.14 | valid ppl   465.66
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model RNN_TANH --log-interval 25
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 108.46 | loss 12.76 | ppl 347715.32
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 104.06 | loss 14.42 | ppl 1823528.98
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 102.41 | loss 14.62 | ppl 2246560.90
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 10.39s | valid loss 17.41 | valid ppl 36216046.10
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 97.42 | loss 17.27 | ppl 31717793.23
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 94.36 | loss 13.78 | ppl 962324.00
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 96.55 | loss 14.11 | ppl 1337239.25
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  9.80s | valid loss 13.12 | valid ppl 500523.52
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model RNN_RELU
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 11.55s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 10.22s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 10.04s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  9.95s | valid loss   nan | valid ppl      nan
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model LSTM --log-interval 25
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 370.25 | loss  9.02 | ppl  8284.26
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 295.75 | loss  7.88 | ppl  2641.32
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 292.41 | loss  7.57 | ppl  1947.07
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 30.28s | valid loss  7.24 | valid ppl  1390.48
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 313.31 | loss  7.67 | ppl  2145.42
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 291.18 | loss  7.22 | ppl  1367.39
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 295.44 | loss  7.12 | ppl  1232.37
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 28.64s | valid loss  7.09 | valid ppl  1203.16
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model GRU --log-interval 25
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 264.60 | loss 11.50 | ppl 99103.11
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 257.32 | loss  9.18 | ppl  9699.14
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 257.74 | loss  8.79 | ppl  6537.12
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 24.88s | valid loss  8.10 | valid ppl  3297.20
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 265.53 | loss  8.62 | ppl  5566.52
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 263.02 | loss  7.93 | ppl  2786.47
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 255.50 | loss  7.71 | ppl  2239.60
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 25.06s | valid loss  7.44 | valid ppl  1703.48
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model RNN_TANH --log-interval 25
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 268.72 | loss 17.38 | ppl 35216371.68
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 258.55 | loss 19.65 | ppl 341102480.56
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 278.45 | loss 20.00 | ppl 484894560.50
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 25.64s | valid loss 36.05 | valid ppl 4519565130528858.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 258.76 | loss 21.28 | ppl 1739893412.59
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 252.26 | loss 21.27 | ppl 1734972818.44
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 250.42 | loss 20.98 | ppl 1295517437.28
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model RNN_RELU
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 22.76s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 19.39s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 19.49s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 19.42s | valid loss   nan | valid ppl      nan
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model LSTM --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 261.77 | loss  9.05 | ppl  8479.71
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 275.52 | loss  7.90 | ppl  2693.41
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 278.66 | loss  7.74 | ppl  2290.28
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 26.37s | valid loss  7.36 | valid ppl  1577.19
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 267.81 | loss  7.65 | ppl  2099.32
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 257.83 | loss  7.16 | ppl  1284.87
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 342.39 | loss  7.09 | ppl  1203.86
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 27.91s | valid loss  7.21 | valid ppl  1353.55
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model LSTM --log-interval 25 --tied --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 252.79 | loss  8.94 | ppl  7643.03
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 237.02 | loss  7.96 | ppl  2852.04
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 232.00 | loss  7.81 | ppl  2463.11
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 22.96s | valid loss  7.64 | valid ppl  2081.78
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 238.62 | loss  8.07 | ppl  3204.01
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 225.47 | loss  7.62 | ppl  2041.52
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 249.51 | loss  7.58 | ppl  1950.40
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 23.11s | valid loss  7.56 | valid ppl  1911.89
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model GRU --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 374.72 | loss 13.58 | ppl 788867.68
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 272.11 | loss 10.05 | ppl 23185.59
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 274.90 | loss  8.52 | ppl  5028.43
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 28.91s | valid loss  8.52 | valid ppl  4999.19
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 288.06 | loss  8.43 | ppl  4576.16
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 289.48 | loss  7.93 | ppl  2793.28
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 294.62 | loss  7.65 | ppl  2096.88
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 28.21s | valid loss  7.58 | valid ppl  1953.63
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=20 --model RNN_TANH --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 274.83 | loss 17.37 | ppl 34797606.58
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 241.05 | loss 18.89 | ppl 159494608.27
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 233.22 | loss 19.89 | ppl 435797654.60
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 23.41s | valid loss 41.40 | valid ppl 950476242974398976.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 225.72 | loss 20.78 | ppl 1062736037.44
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 227.61 | loss 13.09 | ppl 483270.19
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 222.12 | loss 13.39 | ppl 653662.38
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model RNN_RELU --tied --lr 5
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 18.85s | valid loss  7.58 | valid ppl  1959.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 19.29s | valid loss  7.19 | valid ppl  1325.34
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 18.51s | valid loss  7.21 | valid ppl  1351.24
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 18.88s | valid loss  7.03 | valid ppl  1124.77
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model LSTM --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 150.75 | loss  8.29 | ppl  3983.02
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 144.51 | loss  7.02 | ppl  1122.16
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 140.61 | loss  6.86 | ppl   952.98
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.49s | valid loss  6.61 | valid ppl   739.58
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 144.14 | loss  6.86 | ppl   951.75
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 146.31 | loss  6.48 | ppl   652.75
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 141.66 | loss  6.35 | ppl   570.78
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 15.05s | valid loss  6.10 | valid ppl   446.02
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=40 --model LSTM --log-interval 25 --tied --lr 5
# Out:
# | epoch   1 |    25/   97 batches | lr 5.00 | ms/batch 151.01 | loss  7.96 | ppl  2859.06
# | epoch   1 |    50/   97 batches | lr 5.00 | ms/batch 138.69 | loss  7.05 | ppl  1151.86
# | epoch   1 |    75/   97 batches | lr 5.00 | ms/batch 146.26 | loss  6.89 | ppl   985.45
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.26s | valid loss  6.69 | valid ppl   807.65
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 5.00 | ms/batch 134.63 | loss  7.06 | ppl  1161.08
# | epoch   2 |    50/   97 batches | lr 5.00 | ms/batch 123.24 | loss  6.78 | ppl   878.67
# | epoch   2 |    75/   97 batches | lr 5.00 | ms/batch 126.88 | loss  6.72 | ppl   831.05
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.03s | valid loss  6.63 | valid ppl   760.71
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model GRU --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 134.01 | loss  9.96 | ppl 21155.40
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 133.84 | loss  8.22 | ppl  3715.29
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 131.01 | loss  8.21 | ppl  3676.40
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.85s | valid loss  7.51 | valid ppl  1819.48
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 320.20 | loss  7.43 | ppl  1690.22
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 138.01 | loss  7.39 | ppl  1618.71
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 138.49 | loss  6.67 | ppl   787.37
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 18.61s | valid loss  6.95 | valid ppl  1046.46
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model RNN_TANH --log-interval 25 --tied
# Out:
# | epoch   1 |    25/   97 batches | lr 20.00 | ms/batch 96.92 | loss 15.22 | ppl 4073871.18
# | epoch   1 |    50/   97 batches | lr 20.00 | ms/batch 88.48 | loss 15.68 | ppl 6466358.50
# | epoch   1 |    75/   97 batches | lr 20.00 | ms/batch 89.08 | loss 16.78 | ppl 19424658.45
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  9.14s | valid loss 12.64 | valid ppl 309529.16
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   97 batches | lr 20.00 | ms/batch 90.56 | loss 13.63 | ppl 831363.13
# | epoch   2 |    50/   97 batches | lr 20.00 | ms/batch 86.39 | loss 12.91 | ppl 404708.18
# | epoch   2 |    75/   97 batches | lr 20.00 | ms/batch 87.13 | loss 14.06 | ppl 1273856.99
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  9.03s | valid loss 18.93 | valid ppl 166284705.67
# ...

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model RNN_RELU --tied
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 10.20s | valid loss   nan | valid ppl      nan
# -----------------------------------------------------------------------------------------
# ^C
# -----------------------------------------------------------------------------------------
# Exiting from training early

# %%
# !command python main.py --data ./data/reuters --epochs=20 --model RNN_RELU --tied --lr 5
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  8.69s | valid loss  6.94 | valid ppl  1029.60
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  8.31s | valid loss  6.33 | valid ppl   562.31
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  8.44s | valid loss  6.08 | valid ppl   436.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  8.46s | valid loss  5.85 | valid ppl   347.33
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 50 --nhid 50
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 149.50 | loss  9.13 | ppl  9257.46
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 146.46 | loss  7.87 | ppl  2605.21
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 145.66 | loss  7.70 | ppl  2214.07
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.59s | valid loss  7.33 | valid ppl  1525.19
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 228.98 | loss  7.67 | ppl  2132.91
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 152.01 | loss  7.16 | ppl  1280.84
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 144.41 | loss  7.12 | ppl  1242.08
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 16.50s | valid loss  7.10 | valid ppl  1216.24
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 50 --nhid 50 --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 145.17 | loss  8.92 | ppl  7505.78
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 136.40 | loss  7.92 | ppl  2750.39
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 139.58 | loss  7.78 | ppl  2391.59
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.63s | valid loss  7.60 | valid ppl  1990.92
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 141.39 | loss  8.07 | ppl  3205.36
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 138.21 | loss  7.63 | ppl  2065.89
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 140.05 | loss  7.60 | ppl  2002.78
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.59s | valid loss  7.51 | valid ppl  1827.11
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 100 --nhid 100
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 174.24 | loss  8.83 | ppl  6856.23
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 172.08 | loss  7.81 | ppl  2475.60
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 175.30 | loss  7.60 | ppl  2004.07
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 16.83s | valid loss  7.20 | valid ppl  1338.23
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 180.01 | loss  7.62 | ppl  2040.98
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 174.48 | loss  7.17 | ppl  1302.23
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 172.87 | loss  7.10 | ppl  1208.85
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 17.00s | valid loss  7.11 | valid ppl  1222.57
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 100 --nhid 100 --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 182.37 | loss  8.91 | ppl  7422.79
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 174.08 | loss  7.94 | ppl  2800.86
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 176.07 | loss  7.79 | ppl  2418.95
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.15s | valid loss  7.71 | valid ppl  2239.57
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 178.10 | loss  8.07 | ppl  3203.95
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 175.33 | loss  7.63 | ppl  2065.64
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 172.51 | loss  7.60 | ppl  1993.50
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 17.06s | valid loss  7.59 | valid ppl  1986.12
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 50 --nhid 50 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 129.90 | loss  9.00 | ppl  8142.27
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 124.94 | loss  7.47 | ppl  1754.58
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 125.44 | loss  7.29 | ppl  1471.64
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.45s | valid loss  7.24 | valid ppl  1392.69
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 130.77 | loss  7.54 | ppl  1884.22
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 50 --nhid 50 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 133.21 | loss  8.89 | ppl  7264.87
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 125.94 | loss  7.88 | ppl  2650.04
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 127.36 | loss  7.53 | ppl  1869.87
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.57s | valid loss  7.37 | valid ppl  1585.09
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 131.85 | loss  7.76 | ppl  2355.15
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 100 --nhid 100 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 158.75 | loss  9.20 | ppl  9853.29
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 157.44 | loss  7.50 | ppl  1804.11
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 159.39 | loss  7.32 | ppl  1515.21
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 15.25s | valid loss  7.11 | valid ppl  1226.55
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 157.18 | loss  7.53 | ppl  1854.46
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 100 --nhid 100 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 179.27 | loss  8.95 | ppl  7741.68
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 162.70 | loss  7.87 | ppl  2614.90
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 175.38 | loss  7.56 | ppl  1911.35
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 16.35s | valid loss  7.29 | valid ppl  1462.26
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 170.74 | loss  7.76 | ppl  2352.17
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 50 --nhid 50
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 149.99 | loss 10.71 | ppl 44721.46
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 141.72 | loss  9.12 | ppl  9123.52
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 141.23 | loss  8.19 | ppl  3609.86
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.96s | valid loss  7.35 | valid ppl  1561.89
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 146.00 | loss  8.13 | ppl  3382.30
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 138.42 | loss  7.53 | ppl  1858.76
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 139.62 | loss  7.37 | ppl  1594.22
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.73s | valid loss  7.53 | valid ppl  1860.50
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 50 --nhid 50 --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 143.02 | loss  8.86 | ppl  7027.48
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 140.48 | loss  7.97 | ppl  2889.83
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 138.86 | loss  7.85 | ppl  2559.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.71s | valid loss  7.72 | valid ppl  2259.55
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 142.59 | loss  8.07 | ppl  3189.55
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 137.50 | loss  7.51 | ppl  1821.99
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 137.16 | loss  7.35 | ppl  1558.05
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 13.52s | valid loss  7.32 | valid ppl  1509.09
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 100 --nhid 100
# Out:
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 177.15 | loss 10.74 | ppl 45972.03
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 171.97 | loss  8.99 | ppl  8061.59
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 169.43 | loss  8.52 | ppl  5038.62
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 16.73s | valid loss 10.07 | valid ppl 23538.83
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 178.96 | loss  8.34 | ppl  4182.63
# | epoch   2 |    50/   93 batches | lr 20.00 | ms/batch 168.77 | loss  7.55 | ppl  1901.76
# | epoch   2 |    75/   93 batches | lr 20.00 | ms/batch 170.73 | loss  7.44 | ppl  1700.59
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 16.65s | valid loss  7.19 | valid ppl  1332.62
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 100 --nhid 100 --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 185.11 | loss  8.95 | ppl  7713.44
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 174.81 | loss  7.98 | ppl  2929.26
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 171.56 | loss  7.85 | ppl  2569.70
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.19s | valid loss  7.60 | valid ppl  1992.98
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 179.18 | loss  8.07 | ppl  3195.36
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 175.28 | loss  7.45 | ppl  1711.77
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 173.78 | loss  7.33 | ppl  1529.92
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 17.09s | valid loss  7.17 | valid ppl  1294.82
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 50 --nhid 50 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 130.17 | loss  9.36 | ppl 11593.99
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 125.64 | loss  8.11 | ppl  3339.60
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 125.50 | loss  7.84 | ppl  2549.90
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.40s | valid loss  7.74 | valid ppl  2293.20
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 131.94 | loss  7.83 | ppl  2515.34
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 50 --nhid 50 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 129.91 | loss  8.83 | ppl  6855.89
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 127.59 | loss  7.71 | ppl  2225.77
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 125.16 | loss  7.50 | ppl  1810.56
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.38s | valid loss  7.20 | valid ppl  1342.07
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 131.29 | loss  7.73 | ppl  2274.23
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 100 --nhid 100 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 159.44 | loss  9.93 | ppl 20524.10
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 154.27 | loss  8.15 | ppl  3471.93
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 153.87 | loss  7.82 | ppl  2494.35
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 15.02s | valid loss  7.75 | valid ppl  2320.59
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 160.08 | loss  7.91 | ppl  2718.51
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 100 --nhid 100 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 164.83 | loss  8.90 | ppl  7352.43
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 157.93 | loss  7.74 | ppl  2287.92
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 155.66 | loss  7.49 | ppl  1793.69
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 15.37s | valid loss  7.37 | valid ppl  1585.25
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 160.50 | loss  7.71 | ppl  2238.52
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 100 --nhid 100 --lr 1.25 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 162.72 | loss  9.63 | ppl 15186.87
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 155.42 | loss  7.98 | ppl  2911.58
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 159.26 | loss  7.78 | ppl  2388.60
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 15.36s | valid loss  7.63 | valid ppl  2067.07
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 162.32 | loss  8.03 | ppl  3077.45
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 75 --nhid 75 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 147.62 | loss  8.92 | ppl  7500.05
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 142.99 | loss  7.90 | ppl  2686.13
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 145.31 | loss  7.57 | ppl  1942.10
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.09s | valid loss  7.30 | valid ppl  1487.42
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 149.19 | loss  7.76 | ppl  2350.30
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 125 --nhid 125 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 180.76 | loss  8.92 | ppl  7494.66
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 173.47 | loss  7.83 | ppl  2523.26
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 175.71 | loss  7.56 | ppl  1926.43
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.05s | valid loss  7.45 | valid ppl  1711.46
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 183.01 | loss  7.75 | ppl  2317.00
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 75 --nhid 75 --lr 1.25 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 153.59 | loss  9.53 | ppl 13736.82
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 144.93 | loss  7.95 | ppl  2823.45
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 146.43 | loss  7.78 | ppl  2395.31
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.31s | valid loss  7.65 | valid ppl  2098.72
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 150.59 | loss  8.05 | ppl  3138.84
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 125 --nhid 125 --lr 1.25 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 182.61 | loss  9.54 | ppl 13843.96
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 175.20 | loss  7.94 | ppl  2795.83
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 173.22 | loss  7.78 | ppl  2383.15
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.00s | valid loss  7.64 | valid ppl  2087.53
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 177.38 | loss  8.05 | ppl  3127.10
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 125 --nhid 125 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 153.23 | loss  8.95 | ppl  7700.29
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 152.68 | loss  7.75 | ppl  2312.17
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 147.68 | loss  7.54 | ppl  1880.29
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.46s | valid loss  7.39 | valid ppl  1614.83
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 148.67 | loss  7.73 | ppl  2276.29
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 75 --nhid 75 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 113.49 | loss  8.86 | ppl  7069.93
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 116.67 | loss  7.74 | ppl  2296.99
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 115.67 | loss  7.52 | ppl  1844.29
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 11.18s | valid loss  7.35 | valid ppl  1549.58
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 121.12 | loss  7.71 | ppl  2223.77
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --emsize 113 --nhid 113 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 140.25 | loss  8.98 | ppl  7956.65
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 136.07 | loss  7.79 | ppl  2410.57
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 134.63 | loss  7.52 | ppl  1847.03
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 13.35s | valid loss  7.32 | valid ppl  1512.00
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 142.19 | loss  7.73 | ppl  2272.31
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --emsize 113 --nhid 113 --lr 5 --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 135.19 | loss  8.94 | ppl  7601.16
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 133.14 | loss  7.84 | ppl  2536.37
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 136.85 | loss  7.52 | ppl  1846.02
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.96s | valid loss  7.29 | valid ppl  1469.48
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 141.65 | loss  7.75 | ppl  2328.95
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 242.25 | loss  8.88 | ppl  7181.73
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 226.36 | loss  7.51 | ppl  1823.21
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 223.76 | loss  7.30 | ppl  1482.91
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 23.08s | valid loss  7.19 | valid ppl  1326.60
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 251.61 | loss  7.54 | ppl  1876.67
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 266.48 | loss 10.83 | ppl 50374.99
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 306.89 | loss  8.07 | ppl  3204.46
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 230.63 | loss  7.82 | ppl  2495.72
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 24.92s | valid loss  7.53 | valid ppl  1859.46
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 227.89 | loss  7.90 | ppl  2705.68
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 195.70 | loss  8.86 | ppl  7030.64
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 187.43 | loss  7.75 | ppl  2320.75
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 186.19 | loss  7.48 | ppl  1764.23
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 18.21s | valid loss  7.23 | valid ppl  1383.89
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 205.40 | loss  7.72 | ppl  2253.43
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --lr 5
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 236.25 | loss  9.14 | ppl  9285.63
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 233.97 | loss  8.06 | ppl  3175.50
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 243.64 | loss  7.91 | ppl  2723.26
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 22.70s | valid loss  7.83 | valid ppl  2525.69
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 241.87 | loss  8.13 | ppl  3395.99
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 233.15 | loss  7.58 | ppl  1965.24
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 230.01 | loss  7.36 | ppl  1576.75
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 22.35s | valid loss  7.16 | valid ppl  1287.43
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 1.25
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 219.73 | loss  9.27 | ppl 10630.35
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 212.69 | loss  7.94 | ppl  2813.29
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 207.35 | loss  7.75 | ppl  2320.36
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 20.36s | valid loss  7.45 | valid ppl  1711.83
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 199.30 | loss  7.87 | ppl  2611.76
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 1.25 --emsize 50 --nhid 50
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 103.89 | loss  9.56 | ppl 14116.34
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 100.59 | loss  7.94 | ppl  2820.52
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 99.96 | loss  7.78 | ppl  2384.77
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  9.83s | valid loss  7.55 | valid ppl  1897.17
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 103.46 | loss  7.90 | ppl  2707.69
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 1.25 --emsize 100 --nhid 100
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 1.25 | ms/batch 128.03 | loss  9.39 | ppl 12024.74
# | epoch   1 |    50/   93 batches | lr 1.25 | ms/batch 126.44 | loss  7.92 | ppl  2744.05
# | epoch   1 |    75/   93 batches | lr 1.25 | ms/batch 121.27 | loss  7.76 | ppl  2337.79
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 12.22s | valid loss  7.49 | valid ppl  1783.36
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 1.25 | ms/batch 127.91 | loss  7.87 | ppl  2619.92
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model LSTM --log-interval 25 --tied --nlayers 1 --lr 5
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 191.36 | loss  9.01 | ppl  8177.94
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 189.59 | loss  7.84 | ppl  2530.77
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 183.54 | loss  7.54 | ppl  1877.55
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 18.18s | valid loss  7.45 | valid ppl  1713.31
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 196.74 | loss  7.74 | ppl  2295.80
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 187.13 | loss  8.97 | ppl  7896.22
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 183.49 | loss  7.72 | ppl  2242.37
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 185.15 | loss  7.52 | ppl  1850.89
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.86s | valid loss  7.24 | valid ppl  1394.08
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 190.91 | loss  7.73 | ppl  2285.98
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 20.00 | ms/batch 186.63 | loss  9.66 | ppl 15726.67
# | epoch   1 |    50/   93 batches | lr 20.00 | ms/batch 177.52 | loss  8.06 | ppl  3158.27
# | epoch   1 |    75/   93 batches | lr 20.00 | ms/batch 170.47 | loss  7.83 | ppl  2515.97
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.14s | valid loss  7.71 | valid ppl  2226.56
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 20.00 | ms/batch 187.58 | loss  7.89 | ppl  2672.40
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --em_weights xavier --out_weights xavier
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 186.61 | loss  9.13 | ppl  9206.57
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 179.32 | loss  7.95 | ppl  2846.43
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 180.31 | loss  7.75 | ppl  2319.42
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 17.58s | valid loss  7.27 | valid ppl  1442.82
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 182.97 | loss  7.78 | ppl  2392.87
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --em_weights xavier --out_weights xavier --hin_weights xavier --hr_weights xavier
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 214.38 | loss  9.10 | ppl  8919.72
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 198.74 | loss  7.96 | ppl  2856.63
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 197.73 | loss  7.56 | ppl  1913.46
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 19.44s | valid loss  7.44 | valid ppl  1709.95
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 202.99 | loss  7.74 | ppl  2297.48
# ...
