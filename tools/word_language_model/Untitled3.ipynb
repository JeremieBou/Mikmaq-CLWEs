# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 223.09 | loss  8.93 | ppl   489.00
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 213.41 | loss  7.74 | ppl   213.62
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 215.67 | loss  7.57 | ppl   189.74
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 20.87s | valid loss  7.25 | valid ppl   151.86
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 219.21 | loss  7.76 | ppl   216.83
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal --em_weights normal --out_weights normal --seed 100
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 245.45 | loss  8.83 | ppl   455.83
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 244.50 | loss  7.68 | ppl   204.60
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 239.04 | loss  7.50 | ppl   181.01
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 23.26s | valid loss  7.35 | valid ppl   163.32
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 248.06 | loss  7.70 | ppl   207.66
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal --em_weights normal --out_weights normal --seed 200
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 221.03 | loss  8.78 | ppl   440.18
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 215.93 | loss  7.67 | ppl   203.97
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 218.42 | loss  7.50 | ppl   180.73
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 21.09s | valid loss  7.25 | valid ppl   151.76
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 224.01 | loss  7.70 | ppl   207.38
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal --em_weights normal --out_weights normal --seed 400
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 213.54 | loss  8.86 | ppl   463.05
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 218.65 | loss  7.69 | ppl   206.81
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 222.85 | loss  7.50 | ppl   180.65
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 21.03s | valid loss  7.33 | valid ppl   161.34
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 224.79 | loss  7.70 | ppl   207.87
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal --em_weights normal --out_weights normal --seed 300
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 225.79 | loss  8.83 | ppl   453.63
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 210.11 | loss  7.69 | ppl   207.20
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 216.65 | loss  7.47 | ppl   177.71
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 21.03s | valid loss  7.29 | valid ppl   156.16
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 224.48 | loss  7.70 | ppl   207.92
# ...

# %%
# !command python main.py --data ./data/micmac --epochs=40 --model GRU --log-interval 25 --tied --nlayers 1 --lr 5 --emsize 200 --nhid 200 --hin_weights normal --hr_weights normal --em_weights normal --out_weights normal --seed 500
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 221.29 | loss  8.87 | ppl   468.58
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 213.53 | loss  7.68 | ppl   205.64
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 214.78 | loss  7.47 | ppl   177.14
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 20.80s | valid loss  7.35 | valid ppl   163.43
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 220.03 | loss  7.70 | ppl   208.19
# ...

# %%
# !python generate.py --data ./data/micmac
# Out:
# | Generated 0/1000 words
# | Generated 100/1000 words
# | Generated 200/1000 words
# | Generated 300/1000 words
# | Generated 400/1000 words
# | Generated 500/1000 words
# | Generated 600/1000 words
# | Generated 700/1000 words
# | Generated 800/1000 words
# | Generated 900/1000 words
