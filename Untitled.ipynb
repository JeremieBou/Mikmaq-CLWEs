# %%
# !command python src/main.py \
    --data data/transformed/micmac \
    --model gru_1_300_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --dropout 0 \
    --save models/rnns/gru_300_1_5_tied.pt
# Out:
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 318.76 | loss  9.05 | ppl  8502.17
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 297.69 | loss  7.64 | ppl  2072.53
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 310.10 | loss  7.47 | ppl  1756.50
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 29.36s | valid loss  7.22 | valid ppl  1367.51
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 323.96 | loss  7.61 | ppl  2023.65
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 299.70 | loss  7.14 | ppl  1265.28
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 296.92 | loss  7.09 | ppl  1203.98
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 29.43s | valid loss  7.09 | valid ppl  1198.04
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac \
    --model gru_1_300_5_tied_normnorm \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --save models/rnns/gru_300_1_5_tied_normnorm.pt

# !command python src/eval_out.py --model models/rnns/gru_200_1_5_tied_normnorm.pt --input data/transformed/micmac > data/eval_out/mm_gru_200_1_5_tied_normnorm.txt 
# !command python src/eval/perplexity_adj.py ../data/eval_out/mm_gru_200_1_5_tied_normnorm.txt 
# !command python src/eval/perplexity_adj2.py ../data/eval_out/mm_gru_200_1_5_tied_normnorm.txt
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 328.49 | loss  8.85 | ppl  7005.10
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 323.10 | loss  7.63 | ppl  2056.38
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 314.01 | loss  7.40 | ppl  1643.39
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 30.52s | valid loss  7.22 | valid ppl  1365.54
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 331.78 | loss  7.60 | ppl  1997.89
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --model gru_1_300_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --dropout 0 \
    --use_fasttext \
    --embedding_model SKIPGRAM \
    --fasttext_save models/embeddings/skipgram \
    --save models/rnns/gru_300_1_5_tied_skipgram.pt
# Out:
# Read 0M words
# Number of words:  1198
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   33566 lr:  0.000000 loss:  2.539841 ETA:   0h 0m
# Starting initializing embeddings
# Finished initializing embeddings
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 317.63 | loss  8.99 | ppl  8058.81
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 310.25 | loss  7.71 | ppl  2241.06
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 307.61 | loss  7.38 | ppl  1604.68
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 29.53s | valid loss  7.24 | valid ppl  1391.83
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 307.76 | loss  7.51 | ppl  1828.05
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 296.15 | loss  7.05 | ppl  1148.84
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --model gru_1_300_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --dropout 0 \
    --use_fasttext \
    --embedding_model SKIPGRAM \
    --fasttext_save models/embeddings/skipgram \
    --save models/rnns/gru_300_1_5_skipgram.pt
# Out:
# Read 0M words
# Number of words:  1198
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   35973 lr:  0.000000 loss:  2.634911 ETA:   0h 0m
# Starting initializing embeddings
# Finished initializing embeddings
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 265.07 | loss  8.97 | ppl  7874.44
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 251.09 | loss  7.92 | ppl  2739.06
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 253.30 | loss  7.48 | ppl  1771.21
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 24.67s | valid loss  7.29 | valid ppl  1471.33
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 258.35 | loss  7.69 | ppl  2179.42
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 252.97 | loss  7.22 | ppl  1359.72
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --model gru_1_300_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --dropout 0 \
    --use_fasttext \
    --embedding_model CBOW \
    --fasttext_save models/embeddings/skipgram \
    --save models/rnns/gru_300_1_5_tied_cbow.pt
# Out:
# Read 0M words
# Number of words:  1198
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   31452 lr:  0.000000 loss:  3.088446 ETA:   0h 0m
# Starting initializing embeddings
# Finished initializing embeddings
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 277.09 | loss  9.48 | ppl 13142.52
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 269.14 | loss  7.79 | ppl  2416.25
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 271.38 | loss  7.62 | ppl  2039.61
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 26.17s | valid loss  7.45 | valid ppl  1718.75
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 279.63 | loss  7.65 | ppl  2098.37
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 272.90 | loss  7.20 | ppl  1341.58
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --model gru_1_300_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --dropout 0 \
    --use_fasttext \
    --embedding_model CBOW \
    --fasttext_save models/embeddings/cbow \
    --save models/rnns/gru_300_1_5_cbow.pt
# Out:
# Read 0M words
# Number of words:  1198
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   29625 lr:  0.000000 loss:  3.244703 ETA:   0h 0m
# Starting initializing embeddings
# Finished initializing embeddings
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 312.74 | loss  8.96 | ppl  7760.38
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 288.91 | loss  7.94 | ppl  2799.92
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 291.56 | loss  7.61 | ppl  2024.79
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 27.89s | valid loss  7.45 | valid ppl  1724.65
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 296.85 | loss  7.73 | ppl  2277.32
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 272.06 | loss  7.26 | ppl  1419.32
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --dropout 0 \
    --use_clwe \
    --clwe_method SIMPLE \
    --panlex_loc data/lexicon/eng-mic2.txt \
    --fasttext_save models/embeddings/wiki.en \
    --save models/rnns/gru_300_1_5_tied_clwe.pt
# Out:
# Starting initializing clwe
# Finished initializing clwe
# ^C

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --dropout 0 \
    --use_clwe \
    --clwe_method RAND \
    --panlex_loc data/lexicon/eng-mic2.txt \
    --fasttext_save models/embeddings/wiki.en \
    --save models/rnns/gru_300_1_5_tied_clwe_rand.pt
# Out:
# Starting initializing clwe
# Finished initializing clwe
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 374.35 | loss  8.58 | ppl  5339.24
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 369.99 | loss  7.59 | ppl  1981.27
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 355.12 | loss  7.43 | ppl  1684.30
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 34.45s | valid loss  7.34 | valid ppl  1544.19
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 364.12 | loss  7.60 | ppl  1989.21
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 427.46 | loss  7.12 | ppl  1230.80
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 325.46 | loss  7.05 | ppl  1158.28
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --dropout 0 \
    --use_clwe \
    --clwe_method RAND_TRANS \
    --panlex_loc data/lexicon/eng-mic2.txt \
    --fasttext_save models/embeddings/wiki.en \
    --save models/rnns/gru_300_1_5_tied_clwe_randtrans.pt
# Out:
# Starting initializing clwe
# Finished initializing clwe
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 394.02 | loss  8.92 | ppl  7477.18
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 385.34 | loss  7.63 | ppl  2053.91
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 387.80 | loss  7.44 | ppl  1694.71
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 37.18s | valid loss  7.18 | valid ppl  1317.76
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 382.44 | loss  7.63 | ppl  2062.85
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 376.34 | loss  7.14 | ppl  1260.26
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 363.03 | loss  7.06 | ppl  1168.25
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --dropout 0 \
    --use_clwe \
    --clwe_method RAND_COMBO \
    --panlex_loc data/lexicon/eng-mic2.txt \
    --fasttext_save models/embeddings/wiki.en \
    --save models/rnns/gru_300_1_5_tied_clwe_randcombo.pt
# Out:
# Starting initializing clwe
# Finished initializing clwe
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 384.85 | loss  8.88 | ppl  7156.87
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 351.26 | loss  7.67 | ppl  2141.89
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 361.25 | loss  7.46 | ppl  1729.34
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 35.02s | valid loss  7.35 | valid ppl  1563.63
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 337.45 | loss  7.65 | ppl  2097.84
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 343.86 | loss  7.14 | ppl  1257.00
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 338.59 | loss  7.08 | ppl  1190.68
# -----------------------------------------------------------------------------------------
# ...

# %%
# !command python src/main.py \
    --data data/transformed/micmac/ \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --nlayers 1 \
    --lr 5 \
    --emsize 300 \
    --nhid 300 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal \
    --dropout 0 \
    --use_clwe \
    --clwe_method RAND2 \
    --panlex_loc data/lexicon/eng-mic2.txt \
    --fasttext_save models/embeddings/wiki.en \
    --save models/rnns/gru_300_1_5_tied_clwe_rand2.pt
# Out:
# Starting initializing clwe
# Finished initializing clwe
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 364.82 | loss  8.64 | ppl  5668.59
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 346.15 | loss  7.63 | ppl  2051.44
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 351.44 | loss  7.40 | ppl  1636.67
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 34.10s | valid loss  7.20 | valid ppl  1337.58
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 357.58 | loss  7.60 | ppl  2007.13
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 364.79 | loss  7.13 | ppl  1243.54
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 420.75 | loss  7.06 | ppl  1159.63
# -----------------------------------------------------------------------------------------
# ...
