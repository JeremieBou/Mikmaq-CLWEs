# %%
# !command python src/main.py \
    --data data/transformed/micmac \
    --model gru_1_200_5_tied \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 200 \
    --nhid 200
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 233.63 | loss  8.97 | ppl   502.90
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 232.28 | loss  7.72 | ppl   210.15
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 230.96 | loss  7.52 | ppl   183.98
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 22.13s | valid loss  7.24 | valid ppl   151.17
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 230.77 | loss  7.73 | ppl   212.98
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 226.32 | loss  7.25 | ppl   152.58
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 232.68 | loss  7.20 | ppl   146.98
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 22.45s | valid loss  7.15 | valid ppl   141.74
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/   93 batches | lr 5.00 | ms/batch 259.14 | loss  7.53 | ppl   184.25
# | epoch   3 |    50/   93 batches | lr 5.00 | ms/batch 218.59 | loss  7.07 | ppl   134.43
# | epoch   3 |    75/   93 batches | lr 5.00 | ms/batch 230.40 | loss  7.04 | ppl   131.99
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 22.53s | valid loss  7.02 | valid ppl   129.83
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/   93 batches | lr 5.00 | ms/batch 249.69 | loss  7.37 | ppl   165.21
# | epoch   4 |    50/   93 batches | lr 5.00 | ms/batch 226.13 | loss  6.94 | ppl   122.83
# | epoch   4 |    75/   93 batches | lr 5.00 | ms/batch 223.41 | loss  6.90 | ppl   119.44
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 22.21s | valid loss  6.96 | valid ppl   124.45
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/   93 batches | lr 5.00 | ms/batch 228.17 | loss  7.21 | ppl   148.39
# | epoch   5 |    50/   93 batches | lr 5.00 | ms/batch 224.67 | loss  6.78 | ppl   110.10
# | epoch   5 |    75/   93 batches | lr 5.00 | ms/batch 220.06 | loss  6.74 | ppl   107.12
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 21.51s | valid loss  6.88 | valid ppl   117.78
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/   93 batches | lr 5.00 | ms/batch 228.68 | loss  7.02 | ppl   129.87
# | epoch   6 |    50/   93 batches | lr 5.00 | ms/batch 221.85 | loss  6.62 | ppl    98.29
# | epoch   6 |    75/   93 batches | lr 5.00 | ms/batch 223.43 | loss  6.58 | ppl    95.46
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 21.47s | valid loss  6.83 | valid ppl   113.66
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/   93 batches | lr 5.00 | ms/batch 390.09 | loss  6.85 | ppl   115.51
# | epoch   7 |    50/   93 batches | lr 5.00 | ms/batch 300.03 | loss  6.45 | ppl    87.66
# | epoch   7 |    75/   93 batches | lr 5.00 | ms/batch 207.24 | loss  6.42 | ppl    85.53
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 26.84s | valid loss  6.82 | valid ppl   112.62
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/   93 batches | lr 5.00 | ms/batch 253.05 | loss  6.68 | ppl   102.57
# | epoch   8 |    50/   93 batches | lr 5.00 | ms/batch 207.00 | loss  6.30 | ppl    78.85
# | epoch   8 |    75/   93 batches | lr 5.00 | ms/batch 200.39 | loss  6.27 | ppl    77.20
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 20.86s | valid loss  6.82 | valid ppl   112.71
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/   93 batches | lr 1.25 | ms/batch 232.61 | loss  6.50 | ppl    90.46
# | epoch   9 |    50/   93 batches | lr 1.25 | ms/batch 228.76 | loss  6.10 | ppl    68.47
# | epoch   9 |    75/   93 batches | lr 1.25 | ms/batch 263.86 | loss  6.06 | ppl    66.91
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 25.02s | valid loss  6.75 | valid ppl   107.74
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/   93 batches | lr 1.25 | ms/batch 367.61 | loss  6.43 | ppl    86.18
# | epoch  10 |    50/   93 batches | lr 1.25 | ms/batch 296.96 | loss  6.04 | ppl    65.95
# | epoch  10 |    75/   93 batches | lr 1.25 | ms/batch 321.63 | loss  6.02 | ppl    64.84
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 30.81s | valid loss  6.75 | valid ppl   107.86
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/   93 batches | lr 0.31 | ms/batch 321.23 | loss  6.38 | ppl    83.51
# | epoch  11 |    50/   93 batches | lr 0.31 | ms/batch 301.92 | loss  5.99 | ppl    63.75
# | epoch  11 |    75/   93 batches | lr 0.31 | ms/batch 313.49 | loss  5.96 | ppl    62.11
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 29.61s | valid loss  6.75 | valid ppl   107.56
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/   93 batches | lr 0.31 | ms/batch 346.68 | loss  6.36 | ppl    82.29
# | epoch  12 |    50/   93 batches | lr 0.31 | ms/batch 297.82 | loss  5.97 | ppl    62.87
# | epoch  12 |    75/   93 batches | lr 0.31 | ms/batch 279.96 | loss  5.95 | ppl    61.65
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 28.88s | valid loss  6.75 | valid ppl   107.65
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/   93 batches | lr 0.08 | ms/batch 307.63 | loss  6.36 | ppl    81.89
# | epoch  13 |    50/   93 batches | lr 0.08 | ms/batch 276.22 | loss  5.96 | ppl    62.34
# | epoch  13 |    75/   93 batches | lr 0.08 | ms/batch 303.18 | loss  5.93 | ppl    61.03
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 28.06s | valid loss  6.75 | valid ppl   107.67
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/   93 batches | lr 0.02 | ms/batch 314.46 | loss  6.34 | ppl    81.29
# | epoch  14 |    50/   93 batches | lr 0.02 | ms/batch 373.02 | loss  5.96 | ppl    62.20
# | epoch  14 |    75/   93 batches | lr 0.02 | ms/batch 329.68 | loss  5.93 | ppl    60.94
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 31.89s | valid loss  6.75 | valid ppl   107.69
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/   93 batches | lr 0.00 | ms/batch 281.74 | loss  6.34 | ppl    81.23
# | epoch  15 |    50/   93 batches | lr 0.00 | ms/batch 223.51 | loss  5.96 | ppl    62.20
# | epoch  15 |    75/   93 batches | lr 0.00 | ms/batch 216.26 | loss  5.93 | ppl    60.80
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 23.45s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/   93 batches | lr 0.00 | ms/batch 281.26 | loss  6.34 | ppl    81.23
# | epoch  16 |    50/   93 batches | lr 0.00 | ms/batch 242.99 | loss  5.96 | ppl    62.13
# | epoch  16 |    75/   93 batches | lr 0.00 | ms/batch 293.64 | loss  5.93 | ppl    60.84
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 25.26s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/   93 batches | lr 0.00 | ms/batch 207.30 | loss  6.34 | ppl    81.09
# | epoch  17 |    50/   93 batches | lr 0.00 | ms/batch 209.30 | loss  5.96 | ppl    62.29
# | epoch  17 |    75/   93 batches | lr 0.00 | ms/batch 245.16 | loss  5.93 | ppl    60.85
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 23.95s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/   93 batches | lr 0.00 | ms/batch 363.40 | loss  6.34 | ppl    81.15
# | epoch  18 |    50/   93 batches | lr 0.00 | ms/batch 310.52 | loss  5.96 | ppl    62.10
# | epoch  18 |    75/   93 batches | lr 0.00 | ms/batch 311.84 | loss  5.93 | ppl    60.90
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 31.15s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/   93 batches | lr 0.00 | ms/batch 317.17 | loss  6.34 | ppl    81.02
# | epoch  19 |    50/   93 batches | lr 0.00 | ms/batch 311.06 | loss  5.95 | ppl    62.03
# | epoch  19 |    75/   93 batches | lr 0.00 | ms/batch 323.12 | loss  5.93 | ppl    60.80
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 30.81s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/   93 batches | lr 0.00 | ms/batch 342.96 | loss  6.34 | ppl    81.00
# | epoch  20 |    50/   93 batches | lr 0.00 | ms/batch 311.45 | loss  5.96 | ppl    62.29
# | epoch  20 |    75/   93 batches | lr 0.00 | ms/batch 315.95 | loss  5.93 | ppl    60.80
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 30.36s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/   93 batches | lr 0.00 | ms/batch 335.89 | loss  6.35 | ppl    81.35
# | epoch  21 |    50/   93 batches | lr 0.00 | ms/batch 290.96 | loss  5.96 | ppl    62.18
# | epoch  21 |    75/   93 batches | lr 0.00 | ms/batch 309.29 | loss  5.93 | ppl    60.79
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 29.40s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/   93 batches | lr 0.00 | ms/batch 330.62 | loss  6.35 | ppl    81.41
# | epoch  22 |    50/   93 batches | lr 0.00 | ms/batch 293.16 | loss  5.96 | ppl    62.05
# | epoch  22 |    75/   93 batches | lr 0.00 | ms/batch 210.20 | loss  5.93 | ppl    60.81
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 25.93s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/   93 batches | lr 0.00 | ms/batch 329.48 | loss  6.34 | ppl    81.00
# | epoch  23 |    50/   93 batches | lr 0.00 | ms/batch 272.21 | loss  5.96 | ppl    62.33
# | epoch  23 |    75/   93 batches | lr 0.00 | ms/batch 215.07 | loss  5.93 | ppl    61.05
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 24.92s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/   93 batches | lr 0.00 | ms/batch 206.11 | loss  6.35 | ppl    81.65
# | epoch  24 |    50/   93 batches | lr 0.00 | ms/batch 213.99 | loss  5.95 | ppl    61.96
# | epoch  24 |    75/   93 batches | lr 0.00 | ms/batch 232.91 | loss  5.93 | ppl    60.84
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 21.27s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/   93 batches | lr 0.00 | ms/batch 334.32 | loss  6.34 | ppl    81.24
# | epoch  25 |    50/   93 batches | lr 0.00 | ms/batch 344.28 | loss  5.96 | ppl    62.26
# | epoch  25 |    75/   93 batches | lr 0.00 | ms/batch 252.64 | loss  5.93 | ppl    60.87
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 27.81s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/   93 batches | lr 0.00 | ms/batch 219.43 | loss  6.34 | ppl    81.10
# | epoch  26 |    50/   93 batches | lr 0.00 | ms/batch 226.37 | loss  5.96 | ppl    62.09
# | epoch  26 |    75/   93 batches | lr 0.00 | ms/batch 223.80 | loss  5.93 | ppl    60.80
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 21.74s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/   93 batches | lr 0.00 | ms/batch 252.28 | loss  6.34 | ppl    81.16
# | epoch  27 |    50/   93 batches | lr 0.00 | ms/batch 203.49 | loss  5.96 | ppl    62.30
# | epoch  27 |    75/   93 batches | lr 0.00 | ms/batch 224.04 | loss  5.92 | ppl    60.71
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 21.93s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/   93 batches | lr 0.00 | ms/batch 222.81 | loss  6.35 | ppl    81.43
# | epoch  28 |    50/   93 batches | lr 0.00 | ms/batch 206.05 | loss  5.96 | ppl    62.44
# | epoch  28 |    75/   93 batches | lr 0.00 | ms/batch 238.80 | loss  5.93 | ppl    61.03
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 22.11s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/   93 batches | lr 0.00 | ms/batch 251.74 | loss  6.34 | ppl    81.25
# | epoch  29 |    50/   93 batches | lr 0.00 | ms/batch 218.04 | loss  5.96 | ppl    62.26
# | epoch  29 |    75/   93 batches | lr 0.00 | ms/batch 213.89 | loss  5.93 | ppl    60.85
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 21.78s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/   93 batches | lr 0.00 | ms/batch 242.17 | loss  6.34 | ppl    81.07
# | epoch  30 |    50/   93 batches | lr 0.00 | ms/batch 208.15 | loss  5.96 | ppl    62.29
# | epoch  30 |    75/   93 batches | lr 0.00 | ms/batch 221.84 | loss  5.92 | ppl    60.75
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 21.51s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/   93 batches | lr 0.00 | ms/batch 245.93 | loss  6.34 | ppl    81.24
# | epoch  31 |    50/   93 batches | lr 0.00 | ms/batch 209.16 | loss  5.96 | ppl    62.25
# | epoch  31 |    75/   93 batches | lr 0.00 | ms/batch 220.90 | loss  5.93 | ppl    60.81
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 21.35s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/   93 batches | lr 0.00 | ms/batch 227.37 | loss  6.34 | ppl    81.09
# | epoch  32 |    50/   93 batches | lr 0.00 | ms/batch 242.95 | loss  5.96 | ppl    62.31
# | epoch  32 |    75/   93 batches | lr 0.00 | ms/batch 206.96 | loss  5.92 | ppl    60.70
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 22.20s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/   93 batches | lr 0.00 | ms/batch 222.98 | loss  6.35 | ppl    81.30
# | epoch  33 |    50/   93 batches | lr 0.00 | ms/batch 215.86 | loss  5.96 | ppl    62.22
# | epoch  33 |    75/   93 batches | lr 0.00 | ms/batch 213.85 | loss  5.93 | ppl    60.84
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 20.94s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/   93 batches | lr 0.00 | ms/batch 234.88 | loss  6.34 | ppl    80.96
# | epoch  34 |    50/   93 batches | lr 0.00 | ms/batch 205.60 | loss  5.96 | ppl    62.17
# | epoch  34 |    75/   93 batches | lr 0.00 | ms/batch 242.84 | loss  5.92 | ppl    60.71
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 21.85s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/   93 batches | lr 0.00 | ms/batch 226.27 | loss  6.34 | ppl    81.26
# | epoch  35 |    50/   93 batches | lr 0.00 | ms/batch 202.93 | loss  5.96 | ppl    62.13
# | epoch  35 |    75/   93 batches | lr 0.00 | ms/batch 199.50 | loss  5.92 | ppl    60.73
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 19.95s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/   93 batches | lr 0.00 | ms/batch 226.28 | loss  6.34 | ppl    81.17
# | epoch  36 |    50/   93 batches | lr 0.00 | ms/batch 200.76 | loss  5.96 | ppl    62.34
# | epoch  36 |    75/   93 batches | lr 0.00 | ms/batch 203.99 | loss  5.93 | ppl    60.97
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 20.13s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/   93 batches | lr 0.00 | ms/batch 206.19 | loss  6.34 | ppl    80.74
# | epoch  37 |    50/   93 batches | lr 0.00 | ms/batch 198.41 | loss  5.96 | ppl    62.09
# | epoch  37 |    75/   93 batches | lr 0.00 | ms/batch 201.23 | loss  5.93 | ppl    60.97
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 19.55s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/   93 batches | lr 0.00 | ms/batch 234.76 | loss  6.34 | ppl    81.12
# | epoch  38 |    50/   93 batches | lr 0.00 | ms/batch 287.54 | loss  5.95 | ppl    62.02
# | epoch  38 |    75/   93 batches | lr 0.00 | ms/batch 228.37 | loss  5.92 | ppl    60.70
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 22.95s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/   93 batches | lr 0.00 | ms/batch 200.51 | loss  6.34 | ppl    81.26
# | epoch  39 |    50/   93 batches | lr 0.00 | ms/batch 210.59 | loss  5.96 | ppl    62.37
# | epoch  39 |    75/   93 batches | lr 0.00 | ms/batch 191.92 | loss  5.92 | ppl    60.56
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 19.13s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/   93 batches | lr 0.00 | ms/batch 201.36 | loss  6.34 | ppl    81.11
# | epoch  40 |    50/   93 batches | lr 0.00 | ms/batch 191.91 | loss  5.96 | ppl    62.15
# | epoch  40 |    75/   93 batches | lr 0.00 | ms/batch 191.97 | loss  5.93 | ppl    61.10
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 18.68s | valid loss  6.75 | valid ppl   107.70
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training | test loss  6.75 | test ppl   853.23
# =========================================================================================

# %%
# !command python src/main.py \
    --data data/transformed/micmac \
    --model gru_1_200_5_tied_normnorm \
    --epochs=40 \
    --model GRU \
    --log-interval 25 \
    --tied \
    --nlayers 1 \
    --lr 5 \
    --emsize 200 \
    --nhid 200 \
    --hin_weights normal \
    --hr_weights normal \
    --em_weights normal \
    --out_weights normal
# Out:
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# | epoch   1 |    25/   93 batches | lr 5.00 | ms/batch 220.64 | loss  8.78 | ppl   438.51
# | epoch   1 |    50/   93 batches | lr 5.00 | ms/batch 217.95 | loss  7.72 | ppl   211.30
# | epoch   1 |    75/   93 batches | lr 5.00 | ms/batch 212.08 | loss  7.50 | ppl   181.26
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 20.90s | valid loss  7.32 | valid ppl   159.80
# -----------------------------------------------------------------------------------------
# | epoch   2 |    25/   93 batches | lr 5.00 | ms/batch 227.32 | loss  7.70 | ppl   207.74
# | epoch   2 |    50/   93 batches | lr 5.00 | ms/batch 198.19 | loss  7.22 | ppl   148.90
# | epoch   2 |    75/   93 batches | lr 5.00 | ms/batch 236.63 | loss  7.17 | ppl   143.57
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 21.11s | valid loss  7.10 | valid ppl   136.76
# -----------------------------------------------------------------------------------------
# | epoch   3 |    25/   93 batches | lr 5.00 | ms/batch 224.98 | loss  7.47 | ppl   177.10
# | epoch   3 |    50/   93 batches | lr 5.00 | ms/batch 248.09 | loss  7.02 | ppl   129.65
# | epoch   3 |    75/   93 batches | lr 5.00 | ms/batch 240.79 | loss  6.98 | ppl   125.93
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 22.68s | valid loss  6.98 | valid ppl   126.51
# -----------------------------------------------------------------------------------------
# | epoch   4 |    25/   93 batches | lr 5.00 | ms/batch 189.17 | loss  7.27 | ppl   154.86
# | epoch   4 |    50/   93 batches | lr 5.00 | ms/batch 190.48 | loss  6.86 | ppl   116.03
# | epoch   4 |    75/   93 batches | lr 5.00 | ms/batch 239.35 | loss  6.80 | ppl   111.69
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 20.33s | valid loss  6.87 | valid ppl   116.98
# -----------------------------------------------------------------------------------------
# | epoch   5 |    25/   93 batches | lr 5.00 | ms/batch 242.89 | loss  7.08 | ppl   135.09
# | epoch   5 |    50/   93 batches | lr 5.00 | ms/batch 221.96 | loss  6.68 | ppl   102.71
# | epoch   5 |    75/   93 batches | lr 5.00 | ms/batch 215.42 | loss  6.63 | ppl    99.10
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 21.43s | valid loss  6.80 | valid ppl   111.18
# -----------------------------------------------------------------------------------------
# | epoch   6 |    25/   93 batches | lr 5.00 | ms/batch 247.79 | loss  6.90 | ppl   119.25
# | epoch   6 |    50/   93 batches | lr 5.00 | ms/batch 231.57 | loss  6.51 | ppl    91.37
# | epoch   6 |    75/   93 batches | lr 5.00 | ms/batch 232.73 | loss  6.47 | ppl    88.44
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 22.22s | valid loss  6.76 | valid ppl   108.31
# -----------------------------------------------------------------------------------------
# | epoch   7 |    25/   93 batches | lr 5.00 | ms/batch 220.99 | loss  6.72 | ppl   105.30
# | epoch   7 |    50/   93 batches | lr 5.00 | ms/batch 232.52 | loss  6.34 | ppl    81.11
# | epoch   7 |    75/   93 batches | lr 5.00 | ms/batch 223.86 | loss  6.29 | ppl    78.51
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 21.99s | valid loss  6.73 | valid ppl   106.09
# -----------------------------------------------------------------------------------------
# | epoch   8 |    25/   93 batches | lr 5.00 | ms/batch 236.60 | loss  6.53 | ppl    92.47
# | epoch   8 |    50/   93 batches | lr 5.00 | ms/batch 207.07 | loss  6.17 | ppl    71.99
# | epoch   8 |    75/   93 batches | lr 5.00 | ms/batch 240.22 | loss  6.13 | ppl    69.98
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 21.44s | valid loss  6.71 | valid ppl   104.89
# -----------------------------------------------------------------------------------------
# | epoch   9 |    25/   93 batches | lr 5.00 | ms/batch 239.05 | loss  6.35 | ppl    81.48
# | epoch   9 |    50/   93 batches | lr 5.00 | ms/batch 205.90 | loss  6.01 | ppl    64.28
# | epoch   9 |    75/   93 batches | lr 5.00 | ms/batch 206.65 | loss  5.97 | ppl    62.48
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 20.66s | valid loss  6.71 | valid ppl   104.40
# -----------------------------------------------------------------------------------------
# | epoch  10 |    25/   93 batches | lr 5.00 | ms/batch 240.68 | loss  6.18 | ppl    72.51
# | epoch  10 |    50/   93 batches | lr 5.00 | ms/batch 236.00 | loss  5.85 | ppl    57.50
# | epoch  10 |    75/   93 batches | lr 5.00 | ms/batch 224.67 | loss  5.80 | ppl    55.82
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 22.12s | valid loss  6.71 | valid ppl   104.41
# -----------------------------------------------------------------------------------------
# | epoch  11 |    25/   93 batches | lr 1.25 | ms/batch 257.61 | loss  5.99 | ppl    63.69
# | epoch  11 |    50/   93 batches | lr 1.25 | ms/batch 239.74 | loss  5.64 | ppl    50.03
# | epoch  11 |    75/   93 batches | lr 1.25 | ms/batch 233.73 | loss  5.59 | ppl    48.17
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 23.38s | valid loss  6.66 | valid ppl   101.37
# -----------------------------------------------------------------------------------------
# | epoch  12 |    25/   93 batches | lr 1.25 | ms/batch 236.63 | loss  5.92 | ppl    60.53
# | epoch  12 |    50/   93 batches | lr 1.25 | ms/batch 220.09 | loss  5.59 | ppl    48.26
# | epoch  12 |    75/   93 batches | lr 1.25 | ms/batch 235.15 | loss  5.55 | ppl    46.70
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 21.66s | valid loss  6.67 | valid ppl   101.67
# -----------------------------------------------------------------------------------------
# | epoch  13 |    25/   93 batches | lr 0.31 | ms/batch 228.26 | loss  5.87 | ppl    58.65
# | epoch  13 |    50/   93 batches | lr 0.31 | ms/batch 210.67 | loss  5.54 | ppl    46.64
# | epoch  13 |    75/   93 batches | lr 0.31 | ms/batch 218.42 | loss  5.48 | ppl    44.68
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 21.17s | valid loss  6.66 | valid ppl   101.45
# -----------------------------------------------------------------------------------------
# | epoch  14 |    25/   93 batches | lr 0.08 | ms/batch 204.08 | loss  5.87 | ppl    58.42
# | epoch  14 |    50/   93 batches | lr 0.08 | ms/batch 188.98 | loss  5.52 | ppl    45.76
# | epoch  14 |    75/   93 batches | lr 0.08 | ms/batch 198.81 | loss  5.47 | ppl    44.45
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 19.07s | valid loss  6.67 | valid ppl   101.53
# -----------------------------------------------------------------------------------------
# | epoch  15 |    25/   93 batches | lr 0.02 | ms/batch 200.03 | loss  5.86 | ppl    57.95
# | epoch  15 |    50/   93 batches | lr 0.02 | ms/batch 262.63 | loss  5.52 | ppl    45.81
# | epoch  15 |    75/   93 batches | lr 0.02 | ms/batch 204.40 | loss  5.46 | ppl    44.10
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 20.88s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  16 |    25/   93 batches | lr 0.00 | ms/batch 212.58 | loss  5.85 | ppl    57.72
# | epoch  16 |    50/   93 batches | lr 0.00 | ms/batch 216.59 | loss  5.52 | ppl    45.80
# | epoch  16 |    75/   93 batches | lr 0.00 | ms/batch 238.23 | loss  5.47 | ppl    44.20
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 20.99s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  17 |    25/   93 batches | lr 0.00 | ms/batch 227.57 | loss  5.86 | ppl    57.89
# | epoch  17 |    50/   93 batches | lr 0.00 | ms/batch 235.37 | loss  5.51 | ppl    45.62
# | epoch  17 |    75/   93 batches | lr 0.00 | ms/batch 232.10 | loss  5.46 | ppl    43.99
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 21.61s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  18 |    25/   93 batches | lr 0.00 | ms/batch 203.43 | loss  5.85 | ppl    57.67
# | epoch  18 |    50/   93 batches | lr 0.00 | ms/batch 195.13 | loss  5.51 | ppl    45.44
# | epoch  18 |    75/   93 batches | lr 0.00 | ms/batch 192.58 | loss  5.46 | ppl    43.91
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 18.89s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  19 |    25/   93 batches | lr 0.00 | ms/batch 206.34 | loss  5.85 | ppl    57.80
# | epoch  19 |    50/   93 batches | lr 0.00 | ms/batch 193.95 | loss  5.52 | ppl    45.83
# | epoch  19 |    75/   93 batches | lr 0.00 | ms/batch 207.97 | loss  5.46 | ppl    43.99
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 19.42s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  20 |    25/   93 batches | lr 0.00 | ms/batch 224.92 | loss  5.85 | ppl    57.64
# | epoch  20 |    50/   93 batches | lr 0.00 | ms/batch 213.78 | loss  5.51 | ppl    45.50
# | epoch  20 |    75/   93 batches | lr 0.00 | ms/batch 227.99 | loss  5.47 | ppl    44.28
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 21.58s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  21 |    25/   93 batches | lr 0.00 | ms/batch 241.98 | loss  5.85 | ppl    57.72
# | epoch  21 |    50/   93 batches | lr 0.00 | ms/batch 210.50 | loss  5.52 | ppl    45.85
# | epoch  21 |    75/   93 batches | lr 0.00 | ms/batch 210.76 | loss  5.47 | ppl    44.24
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 20.86s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  22 |    25/   93 batches | lr 0.00 | ms/batch 240.29 | loss  5.85 | ppl    57.65
# | epoch  22 |    50/   93 batches | lr 0.00 | ms/batch 242.20 | loss  5.52 | ppl    45.82
# | epoch  22 |    75/   93 batches | lr 0.00 | ms/batch 207.42 | loss  5.46 | ppl    43.94
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 22.10s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  23 |    25/   93 batches | lr 0.00 | ms/batch 233.62 | loss  5.85 | ppl    57.50
# | epoch  23 |    50/   93 batches | lr 0.00 | ms/batch 217.30 | loss  5.51 | ppl    45.70
# | epoch  23 |    75/   93 batches | lr 0.00 | ms/batch 190.53 | loss  5.46 | ppl    44.11
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 20.12s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  24 |    25/   93 batches | lr 0.00 | ms/batch 203.84 | loss  5.86 | ppl    58.23
# | epoch  24 |    50/   93 batches | lr 0.00 | ms/batch 208.49 | loss  5.52 | ppl    45.85
# | epoch  24 |    75/   93 batches | lr 0.00 | ms/batch 213.10 | loss  5.46 | ppl    43.98
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 20.06s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  25 |    25/   93 batches | lr 0.00 | ms/batch 193.94 | loss  5.85 | ppl    57.60
# | epoch  25 |    50/   93 batches | lr 0.00 | ms/batch 203.00 | loss  5.52 | ppl    45.77
# | epoch  25 |    75/   93 batches | lr 0.00 | ms/batch 208.88 | loss  5.45 | ppl    43.82
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 19.36s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  26 |    25/   93 batches | lr 0.00 | ms/batch 189.63 | loss  5.86 | ppl    57.92
# | epoch  26 |    50/   93 batches | lr 0.00 | ms/batch 189.39 | loss  5.52 | ppl    45.80
# | epoch  26 |    75/   93 batches | lr 0.00 | ms/batch 219.56 | loss  5.46 | ppl    43.96
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 19.73s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  27 |    25/   93 batches | lr 0.00 | ms/batch 277.41 | loss  5.85 | ppl    57.82
# | epoch  27 |    50/   93 batches | lr 0.00 | ms/batch 281.21 | loss  5.51 | ppl    45.71
# | epoch  27 |    75/   93 batches | lr 0.00 | ms/batch 297.32 | loss  5.46 | ppl    43.91
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 26.15s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  28 |    25/   93 batches | lr 0.00 | ms/batch 217.25 | loss  5.86 | ppl    57.96
# | epoch  28 |    50/   93 batches | lr 0.00 | ms/batch 195.31 | loss  5.51 | ppl    45.67
# | epoch  28 |    75/   93 batches | lr 0.00 | ms/batch 199.88 | loss  5.47 | ppl    44.24
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 19.34s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  29 |    25/   93 batches | lr 0.00 | ms/batch 197.13 | loss  5.85 | ppl    57.77
# | epoch  29 |    50/   93 batches | lr 0.00 | ms/batch 200.45 | loss  5.52 | ppl    45.93
# | epoch  29 |    75/   93 batches | lr 0.00 | ms/batch 190.29 | loss  5.46 | ppl    44.10
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 18.81s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  30 |    25/   93 batches | lr 0.00 | ms/batch 198.22 | loss  5.85 | ppl    57.60
# | epoch  30 |    50/   93 batches | lr 0.00 | ms/batch 209.03 | loss  5.52 | ppl    45.84
# | epoch  30 |    75/   93 batches | lr 0.00 | ms/batch 201.23 | loss  5.47 | ppl    44.20
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 19.42s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  31 |    25/   93 batches | lr 0.00 | ms/batch 203.29 | loss  5.86 | ppl    57.92
# | epoch  31 |    50/   93 batches | lr 0.00 | ms/batch 222.43 | loss  5.51 | ppl    45.70
# | epoch  31 |    75/   93 batches | lr 0.00 | ms/batch 204.50 | loss  5.46 | ppl    44.03
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 19.96s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  32 |    25/   93 batches | lr 0.00 | ms/batch 214.87 | loss  5.85 | ppl    57.72
# | epoch  32 |    50/   93 batches | lr 0.00 | ms/batch 206.34 | loss  5.51 | ppl    45.69
# | epoch  32 |    75/   93 batches | lr 0.00 | ms/batch 201.45 | loss  5.46 | ppl    44.02
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 21.11s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  33 |    25/   93 batches | lr 0.00 | ms/batch 210.83 | loss  5.85 | ppl    57.73
# | epoch  33 |    50/   93 batches | lr 0.00 | ms/batch 284.09 | loss  5.52 | ppl    45.77
# | epoch  33 |    75/   93 batches | lr 0.00 | ms/batch 205.85 | loss  5.47 | ppl    44.18
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 21.84s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  34 |    25/   93 batches | lr 0.00 | ms/batch 215.41 | loss  5.86 | ppl    57.98
# | epoch  34 |    50/   93 batches | lr 0.00 | ms/batch 202.71 | loss  5.52 | ppl    45.75
# | epoch  34 |    75/   93 batches | lr 0.00 | ms/batch 198.81 | loss  5.47 | ppl    44.17
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 19.86s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  35 |    25/   93 batches | lr 0.00 | ms/batch 210.07 | loss  5.86 | ppl    58.05
# | epoch  35 |    50/   93 batches | lr 0.00 | ms/batch 204.50 | loss  5.52 | ppl    45.77
# | epoch  35 |    75/   93 batches | lr 0.00 | ms/batch 201.83 | loss  5.47 | ppl    44.23
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 21.64s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  36 |    25/   93 batches | lr 0.00 | ms/batch 382.71 | loss  5.86 | ppl    57.92
# | epoch  36 |    50/   93 batches | lr 0.00 | ms/batch 380.20 | loss  5.52 | ppl    45.78
# | epoch  36 |    75/   93 batches | lr 0.00 | ms/batch 370.43 | loss  5.47 | ppl    44.24
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 35.71s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  37 |    25/   93 batches | lr 0.00 | ms/batch 357.39 | loss  5.86 | ppl    57.92
# | epoch  37 |    50/   93 batches | lr 0.00 | ms/batch 344.71 | loss  5.52 | ppl    45.79
# | epoch  37 |    75/   93 batches | lr 0.00 | ms/batch 354.86 | loss  5.46 | ppl    44.04
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 33.72s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  38 |    25/   93 batches | lr 0.00 | ms/batch 340.18 | loss  5.85 | ppl    57.71
# | epoch  38 |    50/   93 batches | lr 0.00 | ms/batch 327.28 | loss  5.52 | ppl    45.75
# | epoch  38 |    75/   93 batches | lr 0.00 | ms/batch 311.65 | loss  5.46 | ppl    43.97
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 31.46s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  39 |    25/   93 batches | lr 0.00 | ms/batch 350.23 | loss  5.85 | ppl    57.72
# | epoch  39 |    50/   93 batches | lr 0.00 | ms/batch 319.09 | loss  5.52 | ppl    46.04
# | epoch  39 |    75/   93 batches | lr 0.00 | ms/batch 323.57 | loss  5.47 | ppl    44.20
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 31.00s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# | epoch  40 |    25/   93 batches | lr 0.00 | ms/batch 321.33 | loss  5.85 | ppl    57.51
# | epoch  40 |    50/   93 batches | lr 0.00 | ms/batch 287.76 | loss  5.52 | ppl    45.84
# | epoch  40 |    75/   93 batches | lr 0.00 | ms/batch 300.81 | loss  5.47 | ppl    44.21
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 28.84s | valid loss  6.67 | valid ppl   101.55
# -----------------------------------------------------------------------------------------
# /home/jeremie/anaconda3/envs/pytorch_test/lib/python3.7/site-packages/torch/serialization.py:425: SourceChangeWarning: source code of class 'models.model.RNNModel' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# =========================================================================================
# | End of training | test loss  6.66 | test ppl   783.29
# =========================================================================================
